# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from PC_SL import *

# %%
df_asia = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat")
df_child = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\child.dat")
df_insurance = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\insurance.dat")
df_water = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\Water_1000.dat")
df_alarm = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat")
df_barley = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\barley.dat")
df_hailfinder = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\hailfinder.dat")
df_hepar2 = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\hepar2.dat")
df_andes = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\andes.dat")
df_link = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\link.dat")
df_pathfinder = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\pathfinder.dat")
df_munin2 = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\munin2.dat")

# %%
# %%time
'''
hybrid algorithm
'''

toc = time.time()
'''
restrict phase
'''
j_0 = Gobnilp()
k = PC_SL(df_barley, 1, 0.05)
for i in k:
    j_0.add_forbidden_adjacency((i[0], i[1]))
'''
score phase
'''
#score phase##
j_0.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\barley.dat')
tic = time.time()
print('the time taken to learn the network is:', tic - toc, 'seconds')
# Out:
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# the number of restricted edges is : 957
# **********
# BN has score -508751.6734586516
# **********
# aar_mod<- -24026.105768303023
# aks_m2<-aks_vgt,udb -1824.562852449213
# udb<-ntilg -18984.63109583052
# aks_vgt<-udb -15487.58993197744
# antplnt<-markgrm,saakern -350.10168346396676
# markgrm<-jordinf,partigerm -1289.3314679199611
# saakern<-saamng,tkvs -290.84074906414025
# bgbyg<-slt22 -16441.12563381862
# slt22<-aks_vgt,keraks,srtsize -560.9946318458242
# dg25<-saatid -14998.822044349945
# saatid<-dgv1059 -13903.164089500111
# dgv1059<-aks_m2 -13949.684919452135
# dgv5980<-bgbyg -12562.125586059905
# exptgens<-jordtype -9329.333113128145
# jordtype<-rokap -14579.02206606303
# forfrugt<-exptgens -15908.940024109135
# frspdag<-saatid -13923.670698657079
# jordinf<-frspdag -14322.143303364857
# jordn<-aar_mod,nmin,potnmin -3005.5435152979917
# nmin<-jordtype,nedbarea -8553.887214890448
# potnmin<-forfrugt,jordtype -15575.115250327282
# rokap<- -18900.894791397615
# keraks<-dgv1059 -15151.898736426861
# komm<- -16113.823680518093
# ksort<-aks_vgt,keraks -4610.171875780019
# partigerm<- -22009.942017926973
# mod_nmin<-aar_mod,nmin -173.29600005481916
# nedbarea<- -10995.603945377181
# ngodn<-ngodnn,ngodnt -234.39469062951684
# ngodnn<-jordn,nopt -4693.250448790197
# ngodnt<-exptgens,forfrugt,mod_nmin -465.58338055533386
# nopt<-exptgens -7891.395972769977
# ngtilg<-ngodn,nplac -7639.179490882292
# nplac<- -10995.05383321592
# nprot<-jordn,ngodn -232.84774813612603
# ntilg<-jordn,ngtilg -5373.987612548772
# pesticid<-nopt -21.779633962229127
# protein<-dgv1059,nprot -19550.364149916615
# s2225<-aks_vgt,keraks,srtsize -595.0305724877435
# srtsize<-sort -9780.046025967047
# s2528<-aks_vgt,keraks,srtsize -1445.065457623965
# tkvs<- -22009.846259889477
# saamng<- -23069.609774964418
# sort<-sorttkv -35781.48752393853
# sorttkv<-tkv -16068.106938549303
# tkv<-aks_m2 -15058.287622002019
# spndx<- -57.95870978022867
# srtprot<-sort -9966.030924687555
# **********
# bnlearn modelstring =
# [aar_mod][aks_m2|udb:aks_vgt][udb|ntilg][aks_vgt|udb][antplnt|markgrm:saakern][markgrm|jordinf:partigerm][saakern|tkvs:saamng][bgbyg|slt22][slt22|keraks:srtsize:aks_vgt][dg25|saatid][saatid|dgv1059][dgv1059|aks_m2][dgv5980|bgbyg][exptgens|jordtype][jordtype|rokap][forfrugt|exptgens][frspdag|saatid][jordinf|frspdag][jordn|aar_mod:nmin:potnmin][nmin|nedbarea:jordtype][potnmin|forfrugt:jordtype][rokap][keraks|dgv1059][komm][ksort|keraks:aks_vgt][partigerm][mod_nmin|aar_mod:nmin][nedbarea][ngodn|ngodnn:ngodnt][ngodnn|jordn:nopt][ngodnt|forfrugt:exptgens:mod_nmin][nopt|exptgens][ngtilg|nplac:ngodn][nplac][nprot|jordn:ngodn][ntilg|jordn:ngtilg][pesticid|nopt][protein|dgv1059:nprot][s2225|keraks:srtsize:aks_vgt][srtsize|sort][s2528|keraks:srtsize:aks_vgt][tkvs][saamng][sort|sorttkv][sorttkv|tkv][tkv|aks_m2][spndx][srtprot|sort]
# **********
# CPDAG:
# Vertices: aar_mod,aks_m2,udb,aks_vgt,antplnt,markgrm,saakern,bgbyg,slt22,dg25,saatid,dgv1059,dgv5980,exptgens,jordtype,forfrugt,frspdag,jordinf,jordn,nmin,potnmin,rokap,keraks,komm,ksort,partigerm,mod_nmin,nedbarea,ngodn,ngodnn,ngodnt,nopt,ngtilg,nplac,nprot,ntilg,pesticid,protein,s2225,srtsize,s2528,tkvs,saamng,sort,sorttkv,tkv,spndx,srtprot
# aar_mod->jordn
# aar_mod->mod_nmin
# aks_m2->dgv1059
# aks_m2->tkv
# udb->aks_m2
# udb->aks_vgt
# aks_vgt-aks_m2
# aks_vgt->ksort
# aks_vgt->s2225
# aks_vgt->s2528
# aks_vgt->slt22
# markgrm->antplnt
# saakern->antplnt
# bgbyg->dgv5980
# slt22->bgbyg
# saatid->dg25
# saatid->frspdag
# dgv1059->keraks
# dgv1059->protein
# dgv1059->saatid
# exptgens-forfrugt
# exptgens->ngodnt
# exptgens-nopt
# jordtype-exptgens
# jordtype->nmin
# jordtype->potnmin
# forfrugt->ngodnt
# forfrugt->potnmin
# frspdag->jordinf
# jordinf->markgrm
# jordn->ngodnn
# jordn->nprot
# jordn->ntilg
# nmin->jordn
# nmin->mod_nmin
# potnmin->jordn
# rokap-jordtype
# keraks->ksort
# keraks->s2225
# keraks->s2528
# keraks->slt22
# partigerm->markgrm
# mod_nmin->ngodnt
# nedbarea->nmin
# ngodn->ngtilg
# ngodn->nprot
# ngodnn->ngodn
# ngodnt->ngodn
# nopt->ngodnn
# nopt-pesticid
# ngtilg->ntilg
# nplac->ngtilg
# nprot->protein
# ntilg->udb
# srtsize->s2225
# srtsize->s2528
# srtsize->slt22
# tkvs->saakern
# saamng->saakern
# sort->srtprot
# sort->srtsize
# sorttkv->sort
# tkv->sorttkv
# the time taken to learn the network is: 161.60253143310547 seconds
# CPU times: total: 2min 45s
# Wall time: 2min 41s

# %%
# %%time
toc = time.time()

'''
score-based algorithm
'''
T = Gobnilp()
#score phase##
T.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\hailfinder.dat')
tic = time.time()
print('the time taken to learn the network is:', tic - toc, 'seconds')
# Out:
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0

# %%
def F_score():
    #j_0#
    j_0_frozenset = []
    for i in j_0.adjacency.items():
        if i[1].X >= 1:
            j_0_frozenset.append(i[0])
    hybrid = [list(x) for x in j_0_frozenset]
    ##
    
    T_frozenset = []
    for i in T.adjacency.items():
        if i[1].X >= 1:
            T_frozenset.append(i[0])
    real = [list(x) for x in T_frozenset]
    
    #Finding TP, FP, FN#
    TP = [x for x in hybrid if x in (y for y in real)]
    FP = [x for x in hybrid if x not in (y for y in real)]
    FN = [x for x in real if x not in (y for y in hybrid)]
    
    # F_score#
    F_score = (2 * len(TP)) / (2 * len(TP) + len(FP) + len(FN))
    print('False Positive = ' ,FP)
    print('False Negative = ' ,FN)
    return F_score

# %%
F_score()
# Out:
# False Positive =  [['aar_mod', 'jordn'], ['dgv1059', 'aks_m2'], ['aks_vgt', 's2225'], ['aks_vgt', 'slt22'], ['saakern', 'antplnt'], ['ngodnn', 'jordn'], ['keraks', 'ksort'], ['ngodnt', 'mod_nmin'], ['ngodnn', 'nopt'], ['nprot', 'protein'], ['srtsize', 's2225'], ['srtsize', 'slt22']]
# False Negative =  [['aks_m2', 'saamng'], ['saatid', 'aks_m2'], ['udb', 'aks_vgt'], ['dgv1059', 'rokap']]
# 0.8596491228070176
