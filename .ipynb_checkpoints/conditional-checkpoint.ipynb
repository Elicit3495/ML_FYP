# %%
import pandas as pd
import numpy as np
from pygobnilp.gobnilp import Gobnilp
import pgmpy
import itertools
from pgmpy.estimators.CITests import pearsonr
from pgmpy.estimators.CITests import chi_square
import networkx as nx
import time
import collections

# %%
def csv_format_discrete(csv_file):
    df = pd.read_csv(csv_file, sep="\s+")
    return df.drop([0])

#returns the csv_file in a pandas dataframe, formatted properly, discrete dataset only

# %%
#small network : n <= 20 nodes, medium network: 20 <= n <= 50 , large: 50 <= n <= 100, ... 
df_small = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat")
df_medium = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat")
# df_large = csv_format_discrete(r"")

# %% [markdown]
# ### chi-squared test

# %%
df_small
# Out:
#        One  Two  Three  Four  Five  Six  Seven  Eight
# 1        1    1      0     0     0    1      0      1
# 2        1    0      0     0     0    0      1      0
# 3        0    0      1     0     0    0      1      0
# 4        1    0      1     0     0    0      1      0
# 5        1    0      1     0     0    0      0      1
# ...    ...  ...    ...   ...   ...  ...    ...    ...
# 9996     0    0      1     0     0    0      0      0
# 9997     1    0      1     0     0    0      1      1
# 9998     0    0      0     0     0    0      1      0
# 9999     1    0      0     0     0    0      1      0
# 10000    1    0      1     0     0    0      1      0
#
# [10000 rows x 8 columns]

# %%
#0th order chi2 test
def chi2bool(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    chi2 = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        chi = chi_square(X=i, Y=j, Z=[], data=df, significance_level=rho)
        chi2.append((i,j,chi))
    true_0 = [x for x in chi2 if True in x]
    false_0 = [x for x in chi2 if False in x]
    return true_0, false_0

# %% [markdown]
# ### Pearson's Product Moment Correlation Coefficient

# %%
df_gaus = pd.read_csv(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\gaussian.dat", sep="\s+")
df_gaus
# Out:
#              A          B          C          D         E          F         G
# 0     1.113083   1.932164   7.074806   8.660411  0.881591  24.719501  9.216382
# 1    -0.247948  11.334343  24.347372  23.355432  7.040113  36.812996  3.678833
# 2     1.854508   3.032020  11.086473  11.055891  3.834530  22.017182  2.424513
# 3     0.833911   3.857970  11.224775  11.937471  1.005624  23.285643  6.085473
# 4     0.488614   4.512613  10.000476  12.537179  4.084746  24.537596  5.117575
# ...        ...        ...        ...        ...       ...        ...       ...
# 4995  0.625860   1.587941   5.952431   8.516822  4.894385  16.950123  2.558535
# 4996  0.241723  -0.497071   1.695681   5.563204  7.454081  21.165266  4.867241
# 4997  2.527720  -2.706339   0.984988   1.597447  3.692427  18.808892  5.598200
# 4998  1.484585   1.468603   7.206672   8.486116  2.611856  21.528922  5.106188
# 4999 -0.306881   1.783709   4.603075   8.550474  5.044690  23.063591  6.511988
#
# [5000 rows x 7 columns]

# %%
#0th order chi2 test
def PMCC(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    R_list = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        R = pearsonr(X=i, Y=j, Z=[], data=df, significance_level=rho)
        R_list.append((i,j,R))
    true_0 = [x for x in R_list if True in x]
    false_0 = [x for x in R_list if False in x]
    return true_0, false_0

# %% [markdown]
# ### Sorting Functions

# %%
def create_permutations(my_list):
    '''
    takes in a list, remove extra permutations from the list and only creates a pair of permutations
    '''
    p_permutations = []
    new_list = list(set(tuple(sorted(l[:2])) for l in my_list))
    for items in new_list:
        new_list_0 = list(itertools.permutations(items[:2],2))[1]
        p_permutations.append(new_list_0)
    return new_list + p_permutations

# %%
#given 2 lists, append them together and remove duplicates
def remove_permutations(list_):
    '''
    returns a sorted list without permutation
    '''
    return sorted(list(set(tuple(sorted(l[:2])) for l in list_)))

# %%
def PC_(df, n, rho):
    '''
    Note:
    This function will start from at least 0th order CI
    
    Parameters:
    df (pandas dataframe)
    n an integer, the stopping point of the while loop
    rho (the significance level, only accepts values between 0 and 1 inclusive)
    
    Returns:
    A list which contains every independent X and Y
    '''
    N = 3
    v = list(df)
    # remove_list = [x for x in p_permute]
    remove_list = create_permutations([x[:2] for x in chi2bool(df, rho)[0]])
    #x[:2] for 0th order and its permutations, so we can later remove it 
    empty_list = []
    while N <= n:
        list_permutations = [x for x in itertools.permutations(v, N) if x[:2] not in remove_list]
        p_1, p_2, p_3 = [x[:1] for x in list_permutations], [x[1:2] for x in list_permutations], [x[2:] for x in list_permutations]
        for i,j,k in zip(p_1, p_2, p_3):
            chi2 = chi_square(X=i[0], Y=j[0], Z=k, data=df, significance_level=rho)
            empty_list.append((i[0],j[0],k,chi2))
        true_list = create_permutations([x[:2] for x in empty_list if True in x])
        #create_permutations ensures only 1 set of permutations of (X,Y) and (Y,X) and removes dupes
        remove_list = remove_list + create_permutations(true_list)
        remove_list = create_permutations(remove_list)
        N += 1
        
    return remove_permutations(remove_list) #returns 1 set of permutations

#ON MEDIUM SIZED NETWORKS:
#1st order CI takes 2minutes to run
#2nd order CI 9-15minutes to run
#nP5 takes ??? minutes to run
#nP6 not doable

# %% [markdown]
# ### graph

# %%
def Graph(df):
    G = nx.Graph()
    v = list(df)
    for i in v:
        G.add_node(i)
    k = list(itertools.combinations(v,2))
    for i,j in k:
        G.add_edge(i,j)
#     print(G)
    return(G)

# %%
g = Graph(df_medium)
print(g)
nx.draw(g, with_labels = True)
# Out:
# Graph with 37 nodes and 666 edges

# %%
def PC_0(df, rho, G):
    '''
    finds 0th order conditional independencies (CI) between each node, if True then remove an edge 
    '''
    v = list(df)
    for i in v:
        G.add_node(i)
    k = list(itertools.combinations(v,2))
    for i,j in k:
        G.add_edge(i,j)
    ind_0 = [x[:2] for x in chi2bool(df, rho)[0]]
    for i,j in ind_0:
        G.remove_edge(i,j)
#     print(G)
    return(G)

# %%
# %%time
g_0 = PC_0(df_medium, 0.05, g)
print(g_0)
nx.draw(g_0, with_labels = True)
# Out:
# Graph with 37 nodes and 265 edges
# CPU times: total: 1.75 s
# Wall time: 1.78 s

# %%
find_adjacency_XY(g_0)
# Out:
# [('PULMEMBOLUS', 'PAP', ['SHUNT', 'SAO2'], 2),
#  ('PULMEMBOLUS',
#   'SHUNT',
#   ['PAP',
#    'SAO2',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL'],
#   13),
#  ('PULMEMBOLUS',
#   'SAO2',
#   ['PAP',
#    'SHUNT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'FIO2',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   23),
#  ('PAP',
#   'SHUNT',
#   ['PULMEMBOLUS',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL'],
#   13),
#  ('KINKEDTUBE',
#   'VENTLUNG',
#   ['VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('KINKEDTUBE',
#   'VENTALV',
#   ['VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('KINKEDTUBE',
#   'PVSAT',
#   ['VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'FIO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('KINKEDTUBE',
#   'SAO2',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'PULMEMBOLUS',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'FIO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   22),
#  ('KINKEDTUBE',
#   'ARTCO2',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   22),
#  ('KINKEDTUBE',
#   'EXPCO2',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   20),
#  ('KINKEDTUBE',
#   'PRESS',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HRBP',
#    'HRSAT'],
#   18),
#  ('KINKEDTUBE',
#   'MINVOL',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   20),
#  ('INTUBATION',
#   'VENTLUNG',
#   ['SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'SHUNT',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'PAP',
#    'ERRCAUTER'],
#   15),
#  ('INTUBATION',
#   'VENTALV',
#   ['VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY'],
#   23),
#  ('INTUBATION',
#   'PVSAT',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'SAO2',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CO',
#    'BP',
#    'HRBP'],
#   22),
#  ('INTUBATION',
#   'ARTCO2',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY'],
#   22),
#  ('INTUBATION',
#   'CATECHOL',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'HR',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'HREKG',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'HRBP'],
#   22),
#  ('INTUBATION',
#   'EXPCO2',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CO',
#    'BP',
#    'HRBP'],
#   20),
#  ('INTUBATION',
#   'PRESS',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'HRBP'],
#   18),
#  ('INTUBATION',
#   'MINVOL',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CO',
#    'BP',
#    'HRBP'],
#   20),
#  ('INTUBATION',
#   'HRSAT',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'TPR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('MINVOLSET',
#   'VENTMACH',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   16),
#  ('MINVOLSET',
#   'VENTTUBE',
#   ['VENTMACH',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'LVFAILURE'],
#   19),
#  ('MINVOLSET',
#   'VENTLUNG',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME'],
#   21),
#  ('MINVOLSET',
#   'VENTALV',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'HISTORY'],
#   23),
#  ('MINVOLSET',
#   'PVSAT',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   21),
#  ('MINVOLSET',
#   'SAO2',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   22),
#  ('MINVOLSET',
#   'ARTCO2',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   22),
#  ('MINVOLSET',
#   'CATECHOL',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   20),
#  ('MINVOLSET',
#   'HR',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   21),
#  ('MINVOLSET',
#   'HREKG',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('MINVOLSET',
#   'CO',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   25),
#  ('MINVOLSET',
#   'BP',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   26),
#  ('MINVOLSET',
#   'EXPCO2',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('MINVOLSET',
#   'PRESS',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('MINVOLSET',
#   'HRBP',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   20),
#  ('MINVOLSET',
#   'MINVOL',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('MINVOLSET',
#   'HRSAT',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'INTUBATION',
#    'DISCONNECT',
#    'TPR',
#    'ERRCAUTER'],
#   20),
#  ('VENTMACH',
#   'VENTTUBE',
#   ['MINVOLSET',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'LVFAILURE'],
#   19),
#  ('VENTMACH',
#   'VENTLUNG',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME'],
#   21),
#  ('VENTMACH',
#   'VENTALV',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'HISTORY'],
#   23),
#  ('VENTMACH',
#   'PVSAT',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   21),
#  ('VENTMACH',
#   'SAO2',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   22),
#  ('VENTMACH',
#   'ARTCO2',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   22),
#  ('VENTMACH',
#   'CATECHOL',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   20),
#  ('VENTMACH',
#   'HR',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   21),
#  ('VENTMACH',
#   'HREKG',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('VENTMACH',
#   'CO',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   25),
#  ('VENTMACH',
#   'BP',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   26),
#  ('VENTMACH',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('VENTMACH',
#   'PRESS',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('VENTMACH',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   20),
#  ('VENTMACH',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('VENTMACH',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'INTUBATION',
#    'DISCONNECT',
#    'TPR',
#    'ERRCAUTER'],
#   20),
#  ('DISCONNECT',
#   'VENTTUBE',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH'],
#   20),
#  ('DISCONNECT',
#   'VENTLUNG',
#   ['VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'STROKEVOLUME'],
#   24),
#  ('DISCONNECT',
#   'VENTALV',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'STROKEVOLUME'],
#   24),
#  ('DISCONNECT',
#   'PVSAT',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'FIO2'],
#   24),
#  ('DISCONNECT',
#   'SAO2',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'FIO2'],
#   25),
#  ('DISCONNECT',
#   'ARTCO2',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'STROKEVOLUME'],
#   24),
#  ('DISCONNECT',
#   'TPR',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS'],
#   19),
#  ('DISCONNECT',
#   'CATECHOL',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'ANAPHYLAXIS'],
#   22),
#  ('DISCONNECT',
#   'HR',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'ANAPHYLAXIS'],
#   23),
#  ('DISCONNECT',
#   'HREKG',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'ERRCAUTER'],
#   24),
#  ('DISCONNECT',
#   'LVFAILURE',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   22),
#  ('DISCONNECT',
#   'CO',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   25),
#  ('DISCONNECT',
#   'BP',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'ANAPHYLAXIS',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   26),
#  ('DISCONNECT',
#   'EXPCO2',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT'],
#   23),
#  ('DISCONNECT',
#   'PRESS',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT'],
#   23),
#  ('DISCONNECT',
#   'HRBP',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'ANAPHYLAXIS',
#    'ERRLOWOUTPUT'],
#   22),
#  ('DISCONNECT',
#   'MINVOL',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT'],
#   23),
#  ('DISCONNECT',
#   'HISTORY',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   22),
#  ('DISCONNECT',
#   'HRSAT',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'ERRCAUTER'],
#   22),
#  ('VENTTUBE',
#   'VENTLUNG',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'STROKEVOLUME'],
#   23),
#  ('VENTTUBE',
#   'VENTALV',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   24),
#  ('VENTTUBE',
#   'PVSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'FIO2'],
#   23),
#  ('VENTTUBE',
#   'SAO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'FIO2'],
#   24),
#  ('VENTTUBE',
#   'ARTCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   24),
#  ('VENTTUBE',
#   'TPR',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS'],
#   20),
#  ('VENTTUBE',
#   'CATECHOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'ANAPHYLAXIS'],
#   21),
#  ('VENTTUBE',
#   'HR',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'SHUNT',
#    'ANAPHYLAXIS'],
#   22),
#  ('VENTTUBE',
#   'HREKG',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'ERRCAUTER'],
#   23),
#  ('VENTTUBE',
#   'LVFAILURE',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   24),
#  ('VENTTUBE',
#   'CO',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   25),
#  ('VENTTUBE',
#   'BP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   26),
#  ('VENTTUBE',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   22),
#  ('VENTTUBE',
#   'PRESS',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   22),
#  ('VENTTUBE',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'ERRLOWOUTPUT'],
#   21),
#  ('VENTTUBE',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   22),
#  ('VENTTUBE',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'INTUBATION',
#    'ERRCAUTER'],
#   21),
#  ('VENTLUNG',
#   'SHUNT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'PAP',
#    'ERRCAUTER'],
#   24),
#  ('VENTLUNG',
#   'VENTALV',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVFAILURE',
#    'HISTORY'],
#   23),
#  ('VENTLUNG',
#   'PVSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'FIO2'],
#   22),
#  ('VENTLUNG',
#   'SAO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'FIO2'],
#   23),
#  ('VENTLUNG',
#   'ARTCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'HISTORY'],
#   22),
#  ('VENTLUNG',
#   'CATECHOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('VENTLUNG',
#   'HR',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('VENTLUNG',
#   'HREKG',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   24),
#  ('VENTLUNG',
#   'STROKEVOLUME',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'HISTORY',
#    'PCWP'],
#   27),
#  ('VENTLUNG',
#   'CO',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'HISTORY',
#    'PCWP'],
#   28),
#  ('VENTLUNG',
#   'BP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'HISTORY',
#    'PCWP'],
#   29),
#  ('VENTLUNG',
#   'EXPCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   21),
#  ('VENTLUNG',
#   'PRESS',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   21),
#  ('VENTLUNG',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   24),
#  ('VENTLUNG',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('VENTLUNG',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'TPR',
#    'ERRCAUTER'],
#   23),
#  ('SHUNT',
#   'VENTALV',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   26),
#  ('SHUNT',
#   'PVSAT',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'SAO2',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'ARTCO2',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   25),
#  ('SHUNT',
#   'HR',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'ERRCAUTER',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT'],
#   14),
#  ('SHUNT',
#   'HREKG',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'EXPCO2',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   23),
#  ('SHUNT',
#   'PRESS',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('SHUNT',
#   'MINVOL',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'PVSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'FIO2'],
#   24),
#  ('VENTALV',
#   'SAO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'FIO2'],
#   25),
#  ('VENTALV',
#   'ARTCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'CATECHOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   25),
#  ('VENTALV',
#   'HR',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   25),
#  ('VENTALV',
#   'HREKG',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   26),
#  ('VENTALV',
#   'LVFAILURE',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   26),
#  ('VENTALV',
#   'STROKEVOLUME',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   27),
#  ('VENTALV',
#   'CO',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   28),
#  ('VENTALV',
#   'BP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   29),
#  ('VENTALV',
#   'EXPCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'PRESS',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   26),
#  ('VENTALV',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'HISTORY',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   26),
#  ('VENTALV',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'TPR',
#    'ERRCAUTER'],
#   25),
#  ('FIO2',
#   'PVSAT',
#   ['SAO2',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   21),
#  ('FIO2',
#   'SAO2',
#   ['PVSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   22),
#  ('PVSAT',
#   'SAO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS'],
#   22),
#  ('PVSAT',
#   'ARTCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   23),
#  ('PVSAT',
#   'CATECHOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('PVSAT',
#   'HR',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('PVSAT',
#   'HREKG',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   24),
#  ('PVSAT',
#   'CO',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   29),
#  ('PVSAT',
#   'BP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   30),
#  ('PVSAT',
#   'EXPCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
# ...
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ERRLOWOUTPUT'],
#   23),
#  ('HREKG',
#   'MINVOL',
#   ['INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE'],
#   23),
#  ('HREKG',
#   'HRSAT',
#   ['INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL'],
#   22),
#  ('HYPOVOLEMIA',
#   'LVEDVOLUME',
#   ['CVP', 'STROKEVOLUME', 'CO', 'BP', 'PCWP', 'LVFAILURE', 'HISTORY'],
#   7),
#  ('HYPOVOLEMIA',
#   'CVP',
#   ['LVEDVOLUME', 'STROKEVOLUME', 'CO', 'BP', 'PCWP', 'LVFAILURE', 'HISTORY'],
#   7),
#  ('HYPOVOLEMIA',
#   'STROKEVOLUME',
#   ['LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'PCWP',
#    'VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'LVFAILURE',
#    'HISTORY'],
#   10),
#  ('HYPOVOLEMIA',
#   'CO',
#   ['LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   24),
#  ('HYPOVOLEMIA',
#   'BP',
#   ['LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   25),
#  ('HYPOVOLEMIA',
#   'PCWP',
#   ['LVEDVOLUME', 'CVP', 'STROKEVOLUME', 'CO', 'BP', 'LVFAILURE', 'HISTORY'],
#   7),
#  ('LVFAILURE',
#   'LVEDVOLUME',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'HYPOVOLEMIA'],
#   10),
#  ('LVFAILURE',
#   'CVP',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'HYPOVOLEMIA'],
#   10),
#  ('LVFAILURE',
#   'STROKEVOLUME',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'VENTLUNG',
#    'ARTCO2',
#    'HYPOVOLEMIA'],
#   12),
#  ('LVFAILURE',
#   'CO',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('LVFAILURE',
#   'BP',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('LVFAILURE',
#   'HISTORY',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PCWP',
#    'ARTCO2'],
#   10),
#  ('LVFAILURE',
#   'PCWP',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'HYPOVOLEMIA'],
#   10),
#  ('LVEDVOLUME',
#   'CVP',
#   ['HYPOVOLEMIA', 'LVFAILURE', 'STROKEVOLUME', 'CO', 'BP', 'HISTORY', 'PCWP'],
#   7),
#  ('LVEDVOLUME',
#   'STROKEVOLUME',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'VENTLUNG',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('LVEDVOLUME',
#   'CO',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('LVEDVOLUME',
#   'BP',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('LVEDVOLUME',
#   'HISTORY',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PCWP',
#    'DISCONNECT',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('LVEDVOLUME',
#   'PCWP',
#   ['HYPOVOLEMIA', 'LVFAILURE', 'CVP', 'STROKEVOLUME', 'CO', 'BP', 'HISTORY'],
#   7),
#  ('CVP',
#   'STROKEVOLUME',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'VENTLUNG',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('CVP',
#   'CO',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('CVP',
#   'BP',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('CVP',
#   'HISTORY',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PCWP',
#    'DISCONNECT',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('CVP',
#   'PCWP',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY'],
#   7),
#  ('STROKEVOLUME',
#   'CO',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'PVSAT',
#    'SAO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('STROKEVOLUME',
#   'BP',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'PVSAT',
#    'SAO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('STROKEVOLUME',
#   'HISTORY',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'PCWP',
#    'DISCONNECT'],
#   11),
#  ('STROKEVOLUME',
#   'PCWP',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'HISTORY'],
#   10),
#  ('CO',
#   'BP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'ANAPHYLAXIS'],
#   25),
#  ('CO',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   28),
#  ('CO',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'ANAPHYLAXIS',
#    'ERRLOWOUTPUT',
#    'PRESS'],
#   27),
#  ('CO',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   28),
#  ('CO',
#   'HISTORY',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PCWP'],
#   24),
#  ('CO',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'PCWP',
#    'INTUBATION',
#    'ERRCAUTER',
#    'PRESS'],
#   27),
#  ('CO',
#   'PCWP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   24),
#  ('BP',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   29),
#  ('BP',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'ERRLOWOUTPUT',
#    'PRESS'],
#   27),
#  ('BP',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   29),
#  ('BP',
#   'HISTORY',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PCWP'],
#   25),
#  ('BP',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'PCWP',
#    'INTUBATION',
#    'ERRCAUTER',
#    'PRESS'],
#   28),
#  ('BP',
#   'PCWP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   25),
#  ('EXPCO2',
#   'PRESS',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   20),
#  ('EXPCO2',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   23),
#  ('EXPCO2',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'HRSAT'],
#   20),
#  ('EXPCO2',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('ERRLOWOUTPUT',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT'],
#   20),
#  ('PRESS',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CO',
#    'BP',
#    'ERRLOWOUTPUT'],
#   23),
#  ('PRESS',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'HRSAT',
#    'CO',
#    'BP'],
#   20),
#  ('PRESS',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'TPR',
#    'ERRCAUTER',
#    'CO',
#    'BP'],
#   22),
#  ('HRBP',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'ERRLOWOUTPUT',
#    'PRESS',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   23),
#  ('HRBP',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'ERRLOWOUTPUT',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'ERRCAUTER'],
#   22),
#  ('MINVOL',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('HISTORY',
#   'PCWP',
#   ['DISCONNECT',
#    'VENTALV',
#    'ARTCO2',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HYPOVOLEMIA'],
#   10)]

# %% [markdown]
# ### adjacency finder

# %%
def find_adjacency_XY(graph):    
    test_list = []
    graph_list = list(graph.edges)
    for i,j in graph_list:
        test_list.append((i, j, list(graph.edges(i)), list(graph.edges(j))))
    n = 0
    N = len(test_list)
    edge_XY = []
    while n < N:
        ##
        adjacent_X = []
        adjacent_Y = []
        X, Y = test_list[n][0], test_list[n][1]
        k_X, k_Y = test_list[n][2], test_list[n][3]
        edge_X = [x for x in k_X if x[1] != Y]
        edge_Y = [x for x in k_Y if x[1] not in (y[1] for y in k_X) and x[1] != X]
        for x in edge_X:
            adjacent_X.append(x[1])
        for y in edge_Y:
            adjacent_Y.append(y[1])
        adjacent_XY = adjacent_X + adjacent_Y
        len_XY = len(adjacent_XY)
        edge_XY.append((X, Y, adjacent_XY, len_XY))
#         print(edge_XY)
        n += 1
    return edge_XY

# %%
adj = find_adjacency_XY(g_0)
adj
# Out:
# [('PULMEMBOLUS', 'PAP', ['SHUNT', 'SAO2'], 2),
#  ('PULMEMBOLUS',
#   'SHUNT',
#   ['PAP',
#    'SAO2',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL'],
#   13),
#  ('PULMEMBOLUS',
#   'SAO2',
#   ['PAP',
#    'SHUNT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'FIO2',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   23),
#  ('PAP',
#   'SHUNT',
#   ['PULMEMBOLUS',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL'],
#   13),
#  ('KINKEDTUBE',
#   'VENTLUNG',
#   ['VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('KINKEDTUBE',
#   'VENTALV',
#   ['VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('KINKEDTUBE',
#   'PVSAT',
#   ['VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'FIO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('KINKEDTUBE',
#   'SAO2',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'PULMEMBOLUS',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'FIO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   22),
#  ('KINKEDTUBE',
#   'ARTCO2',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   22),
#  ('KINKEDTUBE',
#   'EXPCO2',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   20),
#  ('KINKEDTUBE',
#   'PRESS',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'MINVOL',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HRBP',
#    'HRSAT'],
#   18),
#  ('KINKEDTUBE',
#   'MINVOL',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'EXPCO2',
#    'PRESS',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   20),
#  ('INTUBATION',
#   'VENTLUNG',
#   ['SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'SHUNT',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'PAP',
#    'ERRCAUTER'],
#   15),
#  ('INTUBATION',
#   'VENTALV',
#   ['VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY'],
#   23),
#  ('INTUBATION',
#   'PVSAT',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'SAO2',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CO',
#    'BP',
#    'HRBP'],
#   22),
#  ('INTUBATION',
#   'ARTCO2',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY'],
#   22),
#  ('INTUBATION',
#   'CATECHOL',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'HR',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('INTUBATION',
#   'HREKG',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'HRBP'],
#   22),
#  ('INTUBATION',
#   'EXPCO2',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CO',
#    'BP',
#    'HRBP'],
#   20),
#  ('INTUBATION',
#   'PRESS',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'HRBP'],
#   18),
#  ('INTUBATION',
#   'MINVOL',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'HRSAT',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CO',
#    'BP',
#    'HRBP'],
#   20),
#  ('INTUBATION',
#   'HRSAT',
#   ['VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'TPR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'HRBP'],
#   21),
#  ('MINVOLSET',
#   'VENTMACH',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   16),
#  ('MINVOLSET',
#   'VENTTUBE',
#   ['VENTMACH',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'LVFAILURE'],
#   19),
#  ('MINVOLSET',
#   'VENTLUNG',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME'],
#   21),
#  ('MINVOLSET',
#   'VENTALV',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'HISTORY'],
#   23),
#  ('MINVOLSET',
#   'PVSAT',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   21),
#  ('MINVOLSET',
#   'SAO2',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   22),
#  ('MINVOLSET',
#   'ARTCO2',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   22),
#  ('MINVOLSET',
#   'CATECHOL',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   20),
#  ('MINVOLSET',
#   'HR',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   21),
#  ('MINVOLSET',
#   'HREKG',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('MINVOLSET',
#   'CO',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   25),
#  ('MINVOLSET',
#   'BP',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   26),
#  ('MINVOLSET',
#   'EXPCO2',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('MINVOLSET',
#   'PRESS',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('MINVOLSET',
#   'HRBP',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   20),
#  ('MINVOLSET',
#   'MINVOL',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('MINVOLSET',
#   'HRSAT',
#   ['VENTMACH',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'INTUBATION',
#    'DISCONNECT',
#    'TPR',
#    'ERRCAUTER'],
#   20),
#  ('VENTMACH',
#   'VENTTUBE',
#   ['MINVOLSET',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'LVFAILURE'],
#   19),
#  ('VENTMACH',
#   'VENTLUNG',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME'],
#   21),
#  ('VENTMACH',
#   'VENTALV',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'HISTORY'],
#   23),
#  ('VENTMACH',
#   'PVSAT',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   21),
#  ('VENTMACH',
#   'SAO2',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'FIO2'],
#   22),
#  ('VENTMACH',
#   'ARTCO2',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   22),
#  ('VENTMACH',
#   'CATECHOL',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   20),
#  ('VENTMACH',
#   'HR',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   21),
#  ('VENTMACH',
#   'HREKG',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('VENTMACH',
#   'CO',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   25),
#  ('VENTMACH',
#   'BP',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   26),
#  ('VENTMACH',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('VENTMACH',
#   'PRESS',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('VENTMACH',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'DISCONNECT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   20),
#  ('VENTMACH',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'DISCONNECT',
#    'SHUNT'],
#   20),
#  ('VENTMACH',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'INTUBATION',
#    'DISCONNECT',
#    'TPR',
#    'ERRCAUTER'],
#   20),
#  ('DISCONNECT',
#   'VENTTUBE',
#   ['VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH'],
#   20),
#  ('DISCONNECT',
#   'VENTLUNG',
#   ['VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'STROKEVOLUME'],
#   24),
#  ('DISCONNECT',
#   'VENTALV',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'STROKEVOLUME'],
#   24),
#  ('DISCONNECT',
#   'PVSAT',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'FIO2'],
#   24),
#  ('DISCONNECT',
#   'SAO2',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'FIO2'],
#   25),
#  ('DISCONNECT',
#   'ARTCO2',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'STROKEVOLUME'],
#   24),
#  ('DISCONNECT',
#   'TPR',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS'],
#   19),
#  ('DISCONNECT',
#   'CATECHOL',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'ANAPHYLAXIS'],
#   22),
#  ('DISCONNECT',
#   'HR',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'ANAPHYLAXIS'],
#   23),
#  ('DISCONNECT',
#   'HREKG',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'ERRCAUTER'],
#   24),
#  ('DISCONNECT',
#   'LVFAILURE',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   22),
#  ('DISCONNECT',
#   'CO',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   25),
#  ('DISCONNECT',
#   'BP',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'ANAPHYLAXIS',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   26),
#  ('DISCONNECT',
#   'EXPCO2',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT'],
#   23),
#  ('DISCONNECT',
#   'PRESS',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT'],
#   23),
#  ('DISCONNECT',
#   'HRBP',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'MINVOLSET',
#    'VENTMACH',
#    'ANAPHYLAXIS',
#    'ERRLOWOUTPUT'],
#   22),
#  ('DISCONNECT',
#   'MINVOL',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HISTORY',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'SHUNT'],
#   23),
#  ('DISCONNECT',
#   'HISTORY',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'PCWP'],
#   22),
#  ('DISCONNECT',
#   'HRSAT',
#   ['VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'ERRCAUTER'],
#   22),
#  ('VENTTUBE',
#   'VENTLUNG',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'STROKEVOLUME'],
#   23),
#  ('VENTTUBE',
#   'VENTALV',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   24),
#  ('VENTTUBE',
#   'PVSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'FIO2'],
#   23),
#  ('VENTTUBE',
#   'SAO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'FIO2'],
#   24),
#  ('VENTTUBE',
#   'ARTCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   24),
#  ('VENTTUBE',
#   'TPR',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS'],
#   20),
#  ('VENTTUBE',
#   'CATECHOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'ANAPHYLAXIS'],
#   21),
#  ('VENTTUBE',
#   'HR',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'SHUNT',
#    'ANAPHYLAXIS'],
#   22),
#  ('VENTTUBE',
#   'HREKG',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'INTUBATION',
#    'SHUNT',
#    'ANAPHYLAXIS',
#    'ERRCAUTER'],
#   23),
#  ('VENTTUBE',
#   'LVFAILURE',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   24),
#  ('VENTTUBE',
#   'CO',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   25),
#  ('VENTTUBE',
#   'BP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   26),
#  ('VENTTUBE',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   22),
#  ('VENTTUBE',
#   'PRESS',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   22),
#  ('VENTTUBE',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'ERRLOWOUTPUT'],
#   21),
#  ('VENTTUBE',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   22),
#  ('VENTTUBE',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'INTUBATION',
#    'ERRCAUTER'],
#   21),
#  ('VENTLUNG',
#   'SHUNT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'PAP',
#    'ERRCAUTER'],
#   24),
#  ('VENTLUNG',
#   'VENTALV',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVFAILURE',
#    'HISTORY'],
#   23),
#  ('VENTLUNG',
#   'PVSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'FIO2'],
#   22),
#  ('VENTLUNG',
#   'SAO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'FIO2'],
#   23),
#  ('VENTLUNG',
#   'ARTCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'HISTORY'],
#   22),
#  ('VENTLUNG',
#   'CATECHOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('VENTLUNG',
#   'HR',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('VENTLUNG',
#   'HREKG',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   24),
#  ('VENTLUNG',
#   'STROKEVOLUME',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'HISTORY',
#    'PCWP'],
#   27),
#  ('VENTLUNG',
#   'CO',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'HISTORY',
#    'PCWP'],
#   28),
#  ('VENTLUNG',
#   'BP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'HISTORY',
#    'PCWP'],
#   29),
#  ('VENTLUNG',
#   'EXPCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   21),
#  ('VENTLUNG',
#   'PRESS',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   21),
#  ('VENTLUNG',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   24),
#  ('VENTLUNG',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('VENTLUNG',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'TPR',
#    'ERRCAUTER'],
#   23),
#  ('SHUNT',
#   'VENTALV',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   26),
#  ('SHUNT',
#   'PVSAT',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'SAO2',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'FIO2',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'ARTCO2',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   25),
#  ('SHUNT',
#   'HR',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'ERRCAUTER',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT'],
#   14),
#  ('SHUNT',
#   'HREKG',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   24),
#  ('SHUNT',
#   'EXPCO2',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'PRESS',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   23),
#  ('SHUNT',
#   'PRESS',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'MINVOL',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'HRBP',
#    'HRSAT'],
#   21),
#  ('SHUNT',
#   'MINVOL',
#   ['PULMEMBOLUS',
#    'PAP',
#    'INTUBATION',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'ERRCAUTER',
#    'HREKG',
#    'EXPCO2',
#    'PRESS',
#    'KINKEDTUBE',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'CATECHOL',
#    'CO',
#    'BP',
#    'HRBP',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'PVSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'FIO2'],
#   24),
#  ('VENTALV',
#   'SAO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PULMEMBOLUS',
#    'FIO2'],
#   25),
#  ('VENTALV',
#   'ARTCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'CATECHOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   25),
#  ('VENTALV',
#   'HR',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   25),
#  ('VENTALV',
#   'HREKG',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   26),
#  ('VENTALV',
#   'LVFAILURE',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   26),
#  ('VENTALV',
#   'STROKEVOLUME',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   27),
#  ('VENTALV',
#   'CO',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   28),
#  ('VENTALV',
#   'BP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   29),
#  ('VENTALV',
#   'EXPCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'PRESS',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   26),
#  ('VENTALV',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HISTORY',
#    'HRSAT'],
#   23),
#  ('VENTALV',
#   'HISTORY',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'LVEDVOLUME',
#    'CVP',
#    'PCWP'],
#   26),
#  ('VENTALV',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'TPR',
#    'ERRCAUTER'],
#   25),
#  ('FIO2',
#   'PVSAT',
#   ['SAO2',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   21),
#  ('FIO2',
#   'SAO2',
#   ['PVSAT',
#    'PULMEMBOLUS',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   22),
#  ('PVSAT',
#   'SAO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PULMEMBOLUS'],
#   22),
#  ('PVSAT',
#   'ARTCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'STROKEVOLUME',
#    'HISTORY'],
#   23),
#  ('PVSAT',
#   'CATECHOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('PVSAT',
#   'HR',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR'],
#   23),
#  ('PVSAT',
#   'HREKG',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRCAUTER'],
#   24),
#  ('PVSAT',
#   'CO',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   29),
#  ('PVSAT',
#   'BP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'HISTORY',
#    'PCWP'],
#   30),
#  ('PVSAT',
#   'EXPCO2',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'FIO2',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
# ...
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ERRLOWOUTPUT'],
#   23),
#  ('HREKG',
#   'MINVOL',
#   ['INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'HRSAT',
#    'KINKEDTUBE'],
#   23),
#  ('HREKG',
#   'HRSAT',
#   ['INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'ERRCAUTER',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'MINVOL'],
#   22),
#  ('HYPOVOLEMIA',
#   'LVEDVOLUME',
#   ['CVP', 'STROKEVOLUME', 'CO', 'BP', 'PCWP', 'LVFAILURE', 'HISTORY'],
#   7),
#  ('HYPOVOLEMIA',
#   'CVP',
#   ['LVEDVOLUME', 'STROKEVOLUME', 'CO', 'BP', 'PCWP', 'LVFAILURE', 'HISTORY'],
#   7),
#  ('HYPOVOLEMIA',
#   'STROKEVOLUME',
#   ['LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'PCWP',
#    'VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'LVFAILURE',
#    'HISTORY'],
#   10),
#  ('HYPOVOLEMIA',
#   'CO',
#   ['LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   24),
#  ('HYPOVOLEMIA',
#   'BP',
#   ['LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'LVFAILURE',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   25),
#  ('HYPOVOLEMIA',
#   'PCWP',
#   ['LVEDVOLUME', 'CVP', 'STROKEVOLUME', 'CO', 'BP', 'LVFAILURE', 'HISTORY'],
#   7),
#  ('LVFAILURE',
#   'LVEDVOLUME',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'HYPOVOLEMIA'],
#   10),
#  ('LVFAILURE',
#   'CVP',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'HYPOVOLEMIA'],
#   10),
#  ('LVFAILURE',
#   'STROKEVOLUME',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'VENTLUNG',
#    'ARTCO2',
#    'HYPOVOLEMIA'],
#   12),
#  ('LVFAILURE',
#   'CO',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('LVFAILURE',
#   'BP',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'VENTLUNG',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('LVFAILURE',
#   'HISTORY',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PCWP',
#    'ARTCO2'],
#   10),
#  ('LVFAILURE',
#   'PCWP',
#   ['DISCONNECT',
#    'VENTTUBE',
#    'VENTALV',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'HYPOVOLEMIA'],
#   10),
#  ('LVEDVOLUME',
#   'CVP',
#   ['HYPOVOLEMIA', 'LVFAILURE', 'STROKEVOLUME', 'CO', 'BP', 'HISTORY', 'PCWP'],
#   7),
#  ('LVEDVOLUME',
#   'STROKEVOLUME',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'VENTLUNG',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('LVEDVOLUME',
#   'CO',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('LVEDVOLUME',
#   'BP',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('LVEDVOLUME',
#   'HISTORY',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PCWP',
#    'DISCONNECT',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('LVEDVOLUME',
#   'PCWP',
#   ['HYPOVOLEMIA', 'LVFAILURE', 'CVP', 'STROKEVOLUME', 'CO', 'BP', 'HISTORY'],
#   7),
#  ('CVP',
#   'STROKEVOLUME',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CO',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'VENTLUNG',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('CVP',
#   'CO',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('CVP',
#   'BP',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('CVP',
#   'HISTORY',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'PCWP',
#    'DISCONNECT',
#    'VENTALV',
#    'ARTCO2'],
#   10),
#  ('CVP',
#   'PCWP',
#   ['HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HISTORY'],
#   7),
#  ('STROKEVOLUME',
#   'CO',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'BP',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'PVSAT',
#    'SAO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   24),
#  ('STROKEVOLUME',
#   'BP',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'HISTORY',
#    'PCWP',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'PVSAT',
#    'SAO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   25),
#  ('STROKEVOLUME',
#   'HISTORY',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'PCWP',
#    'DISCONNECT'],
#   11),
#  ('STROKEVOLUME',
#   'PCWP',
#   ['VENTLUNG',
#    'VENTALV',
#    'ARTCO2',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'CO',
#    'BP',
#    'HISTORY'],
#   10),
#  ('CO',
#   'BP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'ANAPHYLAXIS'],
#   25),
#  ('CO',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   28),
#  ('CO',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'ANAPHYLAXIS',
#    'ERRLOWOUTPUT',
#    'PRESS'],
#   27),
#  ('CO',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   28),
#  ('CO',
#   'HISTORY',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PCWP'],
#   24),
#  ('CO',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'PCWP',
#    'INTUBATION',
#    'ERRCAUTER',
#    'PRESS'],
#   27),
#  ('CO',
#   'PCWP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'BP',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   24),
#  ('BP',
#   'EXPCO2',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   29),
#  ('BP',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'ERRLOWOUTPUT',
#    'PRESS'],
#   27),
#  ('BP',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'HISTORY',
#    'HRSAT',
#    'PCWP',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT',
#    'PRESS'],
#   29),
#  ('BP',
#   'HISTORY',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HRSAT',
#    'PCWP'],
#   25),
#  ('BP',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'PCWP',
#    'INTUBATION',
#    'ERRCAUTER',
#    'PRESS'],
#   28),
#  ('BP',
#   'PCWP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'HYPOVOLEMIA',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'HISTORY',
#    'HRSAT'],
#   25),
#  ('EXPCO2',
#   'PRESS',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'HRBP',
#    'MINVOL',
#    'HRSAT'],
#   20),
#  ('EXPCO2',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'ERRLOWOUTPUT'],
#   23),
#  ('EXPCO2',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'HRSAT'],
#   20),
#  ('EXPCO2',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'PRESS',
#    'HRBP',
#    'MINVOL',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('ERRLOWOUTPUT',
#   'HRBP',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'MINVOL',
#    'HRSAT'],
#   20),
#  ('PRESS',
#   'HRBP',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'MINVOL',
#    'HRSAT',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CO',
#    'BP',
#    'ERRLOWOUTPUT'],
#   23),
#  ('PRESS',
#   'MINVOL',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'HRSAT',
#    'CO',
#    'BP'],
#   20),
#  ('PRESS',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'EXPCO2',
#    'HRBP',
#    'MINVOL',
#    'TPR',
#    'ERRCAUTER',
#    'CO',
#    'BP'],
#   22),
#  ('HRBP',
#   'MINVOL',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'ERRLOWOUTPUT',
#    'PRESS',
#    'HRSAT',
#    'KINKEDTUBE',
#    'INTUBATION',
#    'SHUNT'],
#   23),
#  ('HRBP',
#   'HRSAT',
#   ['MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'ANAPHYLAXIS',
#    'TPR',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'ERRLOWOUTPUT',
#    'PRESS',
#    'MINVOL',
#    'INTUBATION',
#    'ERRCAUTER'],
#   22),
#  ('MINVOL',
#   'HRSAT',
#   ['KINKEDTUBE',
#    'INTUBATION',
#    'MINVOLSET',
#    'VENTMACH',
#    'DISCONNECT',
#    'VENTTUBE',
#    'VENTLUNG',
#    'SHUNT',
#    'VENTALV',
#    'PVSAT',
#    'SAO2',
#    'ARTCO2',
#    'CATECHOL',
#    'HR',
#    'HREKG',
#    'CO',
#    'BP',
#    'EXPCO2',
#    'PRESS',
#    'HRBP',
#    'TPR',
#    'ERRCAUTER'],
#   22),
#  ('HISTORY',
#   'PCWP',
#   ['DISCONNECT',
#    'VENTALV',
#    'ARTCO2',
#    'LVFAILURE',
#    'LVEDVOLUME',
#    'CVP',
#    'STROKEVOLUME',
#    'CO',
#    'BP',
#    'HYPOVOLEMIA'],
#   10)]

# %% [markdown]
# ### obtaining combinations and data preprocessing

# %%
def get_combinations(this_list, N_0):
    '''
    get combinations of ONE list in ('One', 'Two', ['Three', 'Six', 'Seven', 'Eight'], 4) format
    '''
    adjacency = this_list[2]
    len_adjacency = len(adjacency)
    n = 1
    combinations = []
    while n <= N_0:
        k = list(itertools.combinations(adjacency, n))
        combinations.append(k)
        n += 1
    return [x for x in combinations if x != []]

# %%
def combinations_adjacents(adj, N):
    '''
    adj = output from find_adjacency_XY
    N = stopping point for how many combinations you want
    output: obtains the combinations of n=1,2,...N of the whole list in an unordered manner (see open_list)
    '''
    len_adjacents = len(adj)
    n = 0
    combinations = []
    while n < len_adjacents:
        k = get_combinations(adj[n], N)
        combinations.append((adj[n][0], adj[n][1], k))
        n += 1
    combinations = [x for x in combinations if x != []]
    return combinations

# %%
def open_list(lists):
    '''
    lists = output from combinations_adjacents, the whole thing
    all this function does is concatenates the adjacents of different combinations together
    '''
    n = 0
    N = len(lists)
    output = []
    while n < N:
        t = list(itertools.chain.from_iterable(lists[n][2]))
        output.append((lists[n][0], lists[n][1], t))
        n += 1
    return output

# %%
# %%time
combinations = combinations_adjacents(adj, 3)
opened = open_list(combinations)
# Out:
# CPU times: total: 3.88 s
# Wall time: 3.89 s

# %%
chi2_list(combinations[1], df_medium, 0.05)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [148], line 1
# ----> 1 chi2_list(combinations[1], df_medium, 0.05)
#
# Cell In [147], line 11, in chi2_list(this_list, df, rho)
#       9 output = []
#      10 while n < N:
# ---> 11     chi2 = chi_square(X=x, Y=y, Z=this_list[2][n], data=df, significance_level=rho)
#      12     if chi2 == True:
#      13         output.append(chi2)
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:95, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      35 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      36     r"""
#      37     Chi-square conditional independence test.
#      38     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      93     False
#      94     """
# ---> 95     return power_divergence(
#      96         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      97     )
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:548, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     546 chi = 0
#     547 dof = 0
# --> 548 for z_state, df in data.groupby(Z):
#     549     try:
#     550         c, _, d, _ = stats.chi2_contingency(
#     551             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     552         )
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7721, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7716 axis = self._get_axis_number(axis)
#    7718 # https://github.com/python/mypy/issues/7642
#    7719 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720 # "Union[bool, NoDefault]"; expected "bool"
# -> 7721 return DataFrameGroupBy(
#    7722     obj=self,
#    7723     keys=by,
#    7724     axis=axis,
#    7725     level=level,
#    7726     as_index=as_index,
#    7727     sort=sort,
#    7728     group_keys=group_keys,
#    7729     squeeze=squeeze,  # type: ignore[arg-type]
#    7730     observed=observed,
#    7731     dropna=dropna,
#    7732 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: ('PAP',)

# %% [markdown]
# ### chi2 test

# %%
def chi2_list(this_list, df, rho):
    '''
    performs chi2 test on 1 list in open_list format
    '''
    n = 0
    N = len(this_list[2])
    x = this_list[0]
    y = this_list[1]
    output = []
    while n < N:
        chi2 = chi_square(X=x, Y=y, Z=this_list[2][n], data=df, significance_level=rho)
        if chi2 == True:
            output.append(chi2)
            break
        n += 1
    return output

# %%
def PC_2(opened, df, rho):
    '''
    takes in the output from open_list()
    '''
    n = 0
    N = len(opened)
    output = []
    while n < N:
        chi2 = chi2_list(opened[n], df, rho)
        if True in chi2:
            output.append((opened[n][0], opened[n][1], opened[n][2][n], chi2))            
#             print(opened[n][0], opened[n][1], opened[n][2][n], chi2)
        n += 1
    return output

# %%
# %%time
# opened[n][2][n]
ind = PC_2(opened, df_medium, 0.05)
print(ind)
# opened[2][n][n]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# Cell In [136], line 9, in PC_2(opened, df, rho)
#       7 output = []
#       8 while n < N:
# ----> 9     chi2 = chi2_list(opened[n], df, rho)
#      10     if True in chi2:
#      11         output.append((opened[n][0], opened[n][1], opened[n][2][n], chi2))
#
# Cell In [135], line 11, in chi2_list(this_list, df, rho)
#       9 output = []
#      10 while n < N:
# ---> 11     chi2 = chi_square(X=x, Y=y, Z=this_list[2][n], data=df, significance_level=rho)
#      12     if chi2 == True:
#      13         output.append(chi2)
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:95, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      35 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      36     r"""
#      37     Chi-square conditional independence test.
#      38     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      93     False
#      94     """
# ---> 95     return power_divergence(
#      96         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      97     )
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:551, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     548 for z_state, df in data.groupby(Z):
#     549     try:
#     550         c, _, d, _ = stats.chi2_contingency(
# --> 551             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     552         )
#     553         chi += c
#     554         dof += d
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4157, in Series.unstack(self, level, fill_value)
#    4114 """
#    4115 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4116
#    (...)
#    4153 b    2    4
#    4154 """
#    4155 from pandas.core.reshape.reshape import unstack
# -> 4157 return unstack(self, level, fill_value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:491, in unstack(obj, level, fill_value)
#     489 if is_1d_only_ea_dtype(obj.dtype):
#     490     return _unstack_extension_series(obj, level, fill_value)
# --> 491 unstacker = _Unstacker(
#     492     obj.index, level=level, constructor=obj._constructor_expanddim
#     493 )
#     494 return unstacker.get_result(
#     495     obj._values, value_columns=None, fill_value=fill_value
#     496 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     133 if num_cells > np.iinfo(np.int32).max:
#     134     warnings.warn(
#     135         f"The following operation may generate {num_cells} cells "
#     136         f"in the resulting pandas object.",
#     137         PerformanceWarning,
#     138     )
# --> 140 self._make_selectors()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:180, in _Unstacker._make_selectors(self)
#     177 remaining_labels = self.sorted_labels[:-1]
#     178 level_sizes = tuple(len(x) for x in new_levels)
# --> 180 comp_index, obs_ids = get_compressed_ids(remaining_labels, level_sizes)
#     181 ngroups = len(obs_ids)
#     183 comp_index = ensure_platform_int(comp_index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\sorting.py:215, in get_compressed_ids(labels, sizes)
#     197 """
#     198 Group_index is offsets into cartesian product of all possible labels. This
#     199 space can be huge, so this function compresses it, by computing offsets
#    (...)
#     212     obs_group_ids
#     213 """
#     214 ids = get_group_index(labels, sizes, sort=True, xnull=False)
# --> 215 return compress_group_index(ids, sort=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\sorting.py:678, in compress_group_index(group_index, sort)
#     675 comp_ids, obs_group_ids = table.get_labels_groupby(group_index)
#     677 if sort and len(obs_group_ids) > 0:
# --> 678     obs_group_ids, comp_ids = _reorder_by_uniques(obs_group_ids, comp_ids)
#     680 return ensure_int64(comp_ids), ensure_int64(obs_group_ids)
#
# File ~\anaconda3\lib\site-packages\pandas\core\sorting.py:707, in _reorder_by_uniques(uniques, labels)
#     704 mask = labels < 0
#     706 # move labels to right locations (ie, unsort ascending labels)
# --> 707 labels = reverse_indexer.take(labels)
#     708 np.putmask(labels, mask, -1)
#     710 # sort observed ids
#
# KeyboardInterrupt:

# %%
for i in ind:
    print(i)
#     g_0.remove_edge(i[0], i[1])
# Out:
# ('One', 'Six', ('Seven',), [True])
# ('One', 'Seven', ('Eight',), [True])
# ('One', 'Eight', ('Five',), [True])
# ('Two', 'Three', ('One', 'Six'), [True])
# ('Two', 'Seven', ('One', 'Eight'), [True])
# ('Two', 'Eight', ('One', 'Five'), [True])
# ('Three', 'Five', ('One', 'Eight'), [True])
# ('Three', 'Six', ('Two', 'Seven'), [True])
# ('Three', 'Seven', ('Two', 'Eight'), [True])
# ('Five', 'Seven', ('Six', 'Eight'), [True])
# ('Five', 'Eight', ('Six', 'One'), [True])
# ('Seven', 'Eight', ('One', 'Three', 'Six'), [True])

# %%
nx.draw(g_0, with_labels=True)

# %% [markdown]
# ### small network

# %%
m = Gobnilp()
m.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-21
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -22466.396546491495
# **********
# Eight<-Six,Three -4150.291729106073
# Six<-Five,Two -5.611578690688475
# Three<- -6901.1493808303785
# Five<-Four -633.8404777927353
# Four<- -527.7536882896093
# One<-Three -6460.081285708176
# Seven<-Six -1881.452188461728
# Two<-One -1906.2162176121055
# **********
# bnlearn modelstring =
# [Eight|Six:Three][Six|Five:Two][Three][Five|Four][Four][One|Three][Seven|Six][Two|One]
# **********
# CPDAG:
# Vertices: Eight,Six,Three,Five,Four,One,Seven,Two
# Six->Eight
# Six->Seven
# Three->Eight
# Three-One
# Five->Six
# Four-Five
# One-Two
# Two->Six
