# %%
import pandas as pd
# from tabulate import tabulate
import numpy as np
from pygobnilp.gobnilp import Gobnilp
# import bnlearn as bn
import pgmpy
import itertools
from scipy.stats import chi2_contingency #check for independence between 2 variables
from scipy.stats import power_divergence
from pgmpy.estimators.CITests import log_likelihood
from pgmpy.estimators.CITests import chi_square
# from pgmpy.factors.continuous.discretize import BaseDiscretizer

# %%
def csv_format_discrete(csv_file):
    df = pd.read_csv(csv_file, sep="\s+")
    return df.drop([0])

#returns the csv_file in a pandas dataframe, formatted properly, discrete dataset only

# %%
df = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\discrete.dat")
df
df_test = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat")
df_test
# Out:
#        PULMEMBOLUS  PAP  KINKEDTUBE  INTUBATION  MINVOLSET  VENTMACH  \
# 1                1    1           0           1          2         2
# 2                0    2           0           1          2         2
# 3                0    2           0           2          2         2
# 4                0    2           0           1          2         2
# 5                0    2           0           1          2         2
# ...            ...  ...         ...         ...        ...       ...
# 9996             0    2           1           1          2         2
# 9997             0    0           0           1          2         2
# 9998             0    2           0           0          0         0
# 9999             0    2           0           1          2         2
# 10000            0    2           0           1          2         2
#
#        DISCONNECT  VENTTUBE  VENTLUNG  SHUNT  ...  CO  BP  EXPCO2  \
# 1               1         3         3      0  ...   1   1       1
# 2               0         1         3      1  ...   0   0       1
# 3               0         1         1      0  ...   0   0       2
# 4               0         1         3      1  ...   1   1       1
# 5               0         1         3      1  ...   0   0       1
# ...           ...       ...       ...    ...  ...  ..  ..     ...
# 9996            0         1         3      1  ...   1   1       1
# 9997            0         1         3      1  ...   0   0       1
# 9998            0         0         2      1  ...   0   0       2
# 9999            0         1         3      1  ...   1   1       1
# 10000           0         1         3      1  ...   0   1       1
#
#        ERRLOWOUTPUT  PRESS  HRBP  MINVOL  HISTORY  HRSAT  PCWP
# 1                 0      0     0       3        0      0     2
# 2                 1      1     2       3        0      0     2
# 3                 0      0     0       1        0      0     2
# 4                 0      0     0       3        1      2     1
# 5                 0      1     1       3        0      1     1
# ...             ...    ...   ...     ...      ...    ...   ...
# 9996              0      1     0       3        0      0     0
# 9997              0      2     0       3        0      0     2
# 9998              0      0     0       3        0      0     2
# 9999              0      1     0       3        0      0     0
# 10000             0      1     0       1        0      0     2
#
# [10000 rows x 37 columns]

# %% [markdown]
# ### chi-squared test

# %%
#0th order chi2 test
def chi2bool(df):
#returns a tuple(chi2, p_value, dof) if boolean = false
#the null hypothesis is that they are independent of each other
#if true, the p_value is higher than the significance test, we do not reject the null hypothesis
#if false, the p_value is lower than the significance test, we reject the null hypothesis
    v = list(df)
    empty = []
    empty_1 = []
    empty_2 = []
    empty_3 = []
    empty_4 = []
    itertools_combinations = list(itertools.combinations(v, 2)) #finds every possible combination of list(df)
    for i in itertools_combinations:
        empty_1.append(i[0])
        empty_2.append(i[1])
        
    total_number_of_combinations = len(empty_1)
    
    for t in range(len(itertools_combinations)):
        empty.append(itertools_combinations[t])
        
    for value in range(len(empty_1)):
        empty_3.append(value)
        
    for x,y,i,j in zip(empty_1, empty_2, empty, empty_3):
        chisquare = chi_square(X=x, Y=y, Z=[], data=df, significance_level=0.05, boolean=True) #returns chi, p_value, dof
        empty_4.append([j, i , chisquare])
        
    return empty_4

# %%
def chi2val(df):
#returns a tuple(chi2, p_value, dof) if boolean = false
#the null hypothesis is that they are independent of each other
#if true, the p_value is higher than the significance test, we do not reject the null hypothesis
#if false, the p_value is lower than the significance test, we reject the null hypothesis
    v = list(df)
    empty = []
    empty_1 = []
    empty_2 = []
    empty_3 = []
    empty_4 = []
    itertools_combinations = list(itertools.combinations(v, 2)) #finds every possible combination of list(df)
    for i in itertools_combinations:
        empty_1.append(i[0])
        empty_2.append(i[1])
        
    total_number_of_combinations = len(empty_1)
    
    for t in range(len(itertools_combinations)):
        empty.append(itertools_combinations[t])
        
    for value in range(len(empty_1)):
        empty_3.append(value)
        
    for x,y,i,j in zip(empty_1, empty_2, empty, empty_3):
        chisquare = chi_square(X=x, Y=y, Z=[], data=df, significance_level=0.05, boolean=False) #returns chi, p_value, dof
        empty_4.append([j, i , chisquare])
        
    return empty_4

# %% [markdown]
# ### log-likelihood tests

# %%
def g2val(df):
#returns a tuple(chi2, p_value, dof) if boolean = false
#the null hypothesis is that they are independent of each other
#if true, the p_value is higher than the significance test, we do not reject the null hypothesis
#if false, the p_value is lower than the significance test, we reject the null hypothesis
    v = list(df)
    empty = []
    empty_1 = []
    empty_2 = []
    empty_3 = []
    empty_4 = []
    itertools_combinations = list(itertools.combinations(v, 2)) #finds every possible combination of list(df)
    for i in itertools_combinations:
        empty_1.append(i[0])
        empty_2.append(i[1])
        
    total_number_of_combinations = len(empty_1)
    
    for t in range(len(itertools_combinations)):
        empty.append(itertools_combinations[t])
        
    for value in range(len(empty_1)):
        empty_3.append(value)
        
    for x,y,i,j in zip(empty_1, empty_2, empty, empty_3):
        g2 = log_likelihood(X=x, Y=y, Z=[], significance_level=0.05, boolean=True, data=df) 
        empty_4.append([j, i , g2])
        
    return empty_4

# %% [markdown]
# ### Sorting Functions

# %%
def sortReturn(data):
    #just a sorting function
    true_list = []
    false_list = []
    for i in data:
        if True in i:
            true_list.append(i)
        if False in i:
            false_list.append(i)
    return true_list, false_list

# %%
#returns a list with a tuple of combinations of false
def false2tuple(data):
    empty = []
    false_list_of_tuples = []
    new_df = pd.DataFrame(data)
    newer_df = new_df[1]
    return newer_df

# %%
#given 2 lists, append them together and remove duplicates
def remove_dupes(list_1, list_2):
    for i in list_2:
        list_1.append(i)
    remove_dupes = list(set(list_1))
    return remove_dupes

# %% [markdown]
# ### CONDITIONAL MAIN CODE

# %%
#returns TRUE/FALSE Xs and Ys in a tuple of (X,Y)
def conditional_sort(df):
    output_false = []
    output_true = []
    my_list = [x for x in chi2bool(df) if False in x]
    my_list_2 = [x for x in chi2bool(df) if True in x]
    for i,j in zip(my_list, my_list_2):
        output_true.append(j[1])
        output_false.append(i[1])
    return output_true, output_false

# %%
#returns permutations of x,y,z where x,y does not repeat e.g (a,b,c), (b,a,c)
def conditional_permute(df):
    a = conditional_sort(df)[1] #obtains the list of false outputs, false output means dependent
    k = list(itertools.permutations(df,3))
    permute_list = []
    for i in a:
        permute = list(itertools.permutations(i))
        permute_list.append(permute[1]) #returns a list of permuted items from a
    for items in permute_list:
        a.append(items) #adds all possible permutations to a 
    my_list = [x for x in k if all(x[:2] != y[:2] for y in a)] #checks if all elements in x[:2] != y[:2]
    my_list_2 = [x[:2] for x in my_list]
    a0 = list(tuple(sorted(l)) for l in my_list_2)
    output = [x for x in my_list if x[:2] in a0] #the three lines fixes all the permutations 
    return output

# %%
def conditional_1st_order(df):
    b0 = conditional_permute(df)
    b_100 = []
    for i,j,k in b0:
        chi2 = chi_square(X=i, Y=j, Z=[k], data=df_test, significance_level=0.05)
        b_100.append((i,j,k, chi2))
    b_100_true = [x for x in b_100 if True in x]
    b_100_false = [x for x in b_100 if False in x]
    return b_100_true, b_100_false

# %%
def PC_algorithm(n, df):

# %%
cond_0 = chi2bool(df_test)
true_list_0 = [x[1] for x in cond_0 if True in x]

# %%
cond_1 = conditional_1st_order(df_test)

# %%
true_list_1 = [x[:2] for x in cond_1[0]]
true_list = true_list_0 + true_list_1
len(true_list), len(true_list_0), len(true_list_1)
# Out:
# (13286, 401, 12885)

# %%
chi2_ind = list(set(true_list))
len(chi2_ind)
# Out:
# 648

# %%
v = list(df)

# %%
u = [x[:2] for x in k]
len(u)
# Out:
# 30

# %%
k = list(itertools.permutations(v, 2))
t = [x for x in k if x[:2] not in chi2_ind]
t
# Out:
# [('A', 'B'),
#  ('A', 'C'),
#  ('A', 'D'),
#  ('A', 'E'),
#  ('A', 'F'),
#  ('B', 'A'),
#  ('B', 'C'),
#  ('B', 'D'),
#  ('B', 'E'),
#  ('B', 'F'),
#  ('C', 'A'),
#  ('C', 'B'),
#  ('C', 'D'),
#  ('C', 'E'),
#  ('C', 'F'),
#  ('D', 'A'),
#  ('D', 'B'),
#  ('D', 'C'),
#  ('D', 'E'),
#  ('D', 'F'),
#  ('E', 'A'),
#  ('E', 'B'),
#  ('E', 'C'),
#  ('E', 'D'),
#  ('E', 'F'),
#  ('F', 'A'),
#  ('F', 'B'),
#  ('F', 'C'),
#  ('F', 'D'),
#  ('F', 'E')]

# %%
chi2_ind
# Out:
# [('BP', 'KINKEDTUBE'),
#  ('PAP', 'CVP'),
#  ('HISTORY', 'PVSAT'),
#  ('PAP', 'TPR'),
#  ('HISTORY', 'HRBP'),
#  ('ERRCAUTER', 'LVFAILURE'),
#  ('KINKEDTUBE', 'LVEDVOLUME'),
#  ('SAO2', 'LVEDVOLUME'),
#  ('HYPOVOLEMIA', 'SAO2'),
#  ('LVFAILURE', 'PAP'),
#  ('PULMEMBOLUS', 'LVEDVOLUME'),
#  ('HISTORY', 'VENTLUNG'),
#  ('INSUFFANESTH', 'HR'),
#  ('HISTORY', 'SAO2'),
#  ('HREKG', 'HISTORY'),
#  ('INTUBATION', 'HISTORY'),
#  ('PAP', 'HR'),
#  ('PAP', 'DISCONNECT'),
#  ('ERRCAUTER', 'INTUBATION'),
#  ('TPR', 'STROKEVOLUME'),
#  ('ERRCAUTER', 'VENTALV'),
#  ('PULMEMBOLUS', 'PRESS'),
#  ('CO', 'PAP'),
#  ('ERRCAUTER', 'FIO2'),
#  ('FIO2', 'MINVOL'),
#  ('DISCONNECT', 'SHUNT'),
#  ('DISCONNECT', 'ERRCAUTER'),
#  ('HRSAT', 'PCWP'),
#  ('ERRLOWOUTPUT', 'MINVOL'),
#  ('ANAPHYLAXIS', 'MINVOL'),
#  ('SHUNT', 'CVP'),
#  ('HREKG', 'HYPOVOLEMIA'),
#  ('INTUBATION', 'HYPOVOLEMIA'),
#  ('ERRCAUTER', 'VENTMACH'),
#  ('VENTALV', 'CVP'),
#  ('HYPOVOLEMIA', 'PAP'),
#  ('PCWP', 'SHUNT'),
#  ('TPR', 'HISTORY'),
#  ('LVEDVOLUME', 'PVSAT'),
#  ('SHUNT', 'TPR'),
#  ('HISTORY', 'PAP'),
#  ('INTUBATION', 'ERRLOWOUTPUT'),
#  ('HRBP', 'INSUFFANESTH'),
#  ('DISCONNECT', 'LVEDVOLUME'),
#  ('LVEDVOLUME', 'HRBP'),
#  ('FIO2', 'HRSAT'),
#  ('INTUBATION', 'VENTTUBE'),
#  ('HRBP', 'LVFAILURE'),
#  ('PULMEMBOLUS', 'CO'),
#  ('LVEDVOLUME', 'VENTLUNG'),
#  ('INTUBATION', 'MINVOLSET'),
#  ('ERRLOWOUTPUT', 'HRSAT'),
#  ('ANAPHYLAXIS', 'HRSAT'),
#  ('LVEDVOLUME', 'SAO2'),
#  ('LVEDVOLUME', 'EXPCO2'),
#  ('LVFAILURE', 'PULMEMBOLUS'),
#  ('KINKEDTUBE', 'CVP'),
#  ('TPR', 'HYPOVOLEMIA'),
#  ('LVEDVOLUME', 'ERRLOWOUTPUT'),
#  ('SAO2', 'CVP'),
#  ('PULMEMBOLUS', 'CVP'),
#  ('KINKEDTUBE', 'TPR'),
#  ('HISTORY', 'INSUFFANESTH'),
#  ('PCWP', 'PRESS'),
#  ('VENTMACH', 'PCWP'),
#  ('INSUFFANESTH', 'PVSAT'),
#  ('PULMEMBOLUS', 'TPR'),
#  ('HRBP', 'PULMEMBOLUS'),
#  ('CVP', 'VENTTUBE'),
#  ('CO', 'ERRCAUTER'),
#  ('HRBP', 'KINKEDTUBE'),
#  ('INSUFFANESTH', 'HRBP'),
#  ('PAP', 'PVSAT'),
#  ('CATECHOL', 'PCWP'),
#  ('INSUFFANESTH', 'VENTLUNG'),
#  ('PAP', 'HRBP'),
#  ('INSUFFANESTH', 'CATECHOL'),
#  ('INSUFFANESTH', 'SAO2'),
#  ('PULMEMBOLUS', 'HR'),
#  ('PULMEMBOLUS', 'DISCONNECT'),
#  ('PAP', 'VENTLUNG'),
#  ('STROKEVOLUME', 'PRESS'),
#  ('MINVOLSET', 'STROKEVOLUME'),
#  ('PAP', 'CATECHOL'),
#  ('SHUNT', 'STROKEVOLUME'),
#  ('HYPOVOLEMIA', 'PULMEMBOLUS'),
#  ('PAP', 'EXPCO2'),
#  ('HYPOVOLEMIA', 'KINKEDTUBE'),
#  ('VENTLUNG', 'ANAPHYLAXIS'),
#  ('HISTORY', 'PULMEMBOLUS'),
#  ('PAP', 'ERRLOWOUTPUT'),
#  ('INSUFFANESTH', 'BP'),
#  ('CVP', 'SHUNT'),
#  ('CATECHOL', 'PAP'),
#  ('HISTORY', 'KINKEDTUBE'),
#  ('HRSAT', 'SHUNT'),
#  ('CVP', 'ERRCAUTER'),
#  ('FIO2', 'STROKEVOLUME'),
#  ('DISCONNECT', 'CVP'),
#  ('CO', 'PRESS'),
#  ('ARTCO2', 'PCWP'),
#  ('PAP', 'BP'),
#  ('LVFAILURE', 'MINVOL'),
#  ('VENTTUBE', 'ANAPHYLAXIS'),
#  ('ERRLOWOUTPUT', 'STROKEVOLUME'),
#  ('MINVOLSET', 'HISTORY'),
#  ('STROKEVOLUME', 'MINVOL'),
#  ('PAP', 'MINVOLSET'),
#  ('SHUNT', 'HISTORY'),
#  ('VENTLUNG', 'INSUFFANESTH'),
#  ('HRSAT', 'LVEDVOLUME'),
#  ('KINKEDTUBE', 'STROKEVOLUME'),
#  ('PCWP', 'TPR'),
#  ('SAO2', 'STROKEVOLUME'),
#  ('TPR', 'LVEDVOLUME'),
#  ('FIO2', 'PCWP'),
#  ('VENTTUBE', 'INSUFFANESTH'),
#  ('ERRLOWOUTPUT', 'PCWP'),
#  ('ANAPHYLAXIS', 'PCWP'),
#  ('LVFAILURE', 'HRSAT'),
#  ('ARTCO2', 'PAP'),
#  ('INSUFFANESTH', 'ANAPHYLAXIS'),
#  ('STROKEVOLUME', 'HRSAT'),
#  ('CVP', 'PRESS'),
#  ('MINVOLSET', 'HYPOVOLEMIA'),
#  ('INTUBATION', 'VENTMACH'),
#  ('SHUNT', 'HYPOVOLEMIA'),
#  ('TPR', 'PRESS'),
#  ('VENTALV', 'HYPOVOLEMIA'),
#  ('KINKEDTUBE', 'HISTORY'),
#  ('INTUBATION', 'CO'),
#  ('ARTCO2', 'ANAPHYLAXIS'),
#  ('HR', 'ERRLOWOUTPUT'),
#  ('SAO2', 'HISTORY'),
#  ('VENTMACH', 'SHUNT'),
#  ('HYPOVOLEMIA', 'MINVOL'),
#  ('LVEDVOLUME', 'VENTALV'),
#  ('SHUNT', 'ERRLOWOUTPUT'),
#  ('VENTMACH', 'ERRCAUTER'),
#  ('HISTORY', 'MINVOL'),
#  ('INSUFFANESTH', 'ARTCO2'),
#  ('PULMEMBOLUS', 'PVSAT'),
#  ('FIO2', 'HYPOVOLEMIA'),
#  ('CATECHOL', 'SHUNT'),
#  ('SHUNT', 'VENTTUBE'),
#  ('PAP', 'INSUFFANESTH'),
#  ('ERRCAUTER', 'SAO2'),
#  ('CATECHOL', 'ERRCAUTER'),
#  ('PAP', 'ARTCO2'),
#  ('INSUFFANESTH', 'LVFAILURE'),
#  ('MINVOL', 'TPR'),
#  ('ERRLOWOUTPUT', 'HYPOVOLEMIA'),
#  ('PULMEMBOLUS', 'HRBP'),
#  ('VENTMACH', 'LVEDVOLUME'),
#  ('ANAPHYLAXIS', 'HYPOVOLEMIA'),
#  ('LVEDVOLUME', 'VENTMACH'),
#  ('PAP', 'LVFAILURE'),
#  ('DISCONNECT', 'STROKEVOLUME'),
#  ('HYPOVOLEMIA', 'HRSAT'),
#  ('PULMEMBOLUS', 'VENTLUNG'),
#  ('PULMEMBOLUS', 'CATECHOL'),
#  ('KINKEDTUBE', 'HYPOVOLEMIA'),
#  ('FIO2', 'VENTTUBE'),
#  ('SAO2', 'HYPOVOLEMIA'),
#  ('CATECHOL', 'LVEDVOLUME'),
#  ('HISTORY', 'HRSAT'),
#  ('PVSAT', 'ANAPHYLAXIS'),
#  ('ERRCAUTER', 'BP'),
#  ('PULMEMBOLUS', 'EXPCO2'),
#  ('ERRLOWOUTPUT', 'VENTTUBE'),
#  ('KINKEDTUBE', 'ERRLOWOUTPUT'),
#  ('PAP', 'INTUBATION'),
#  ('PULMEMBOLUS', 'ERRLOWOUTPUT'),
#  ('INSUFFANESTH', 'PULMEMBOLUS'),
#  ('INTUBATION', 'DISCONNECT'),
#  ('MINVOLSET', 'SHUNT'),
#  ('PAP', 'VENTALV'),
#  ('INSUFFANESTH', 'KINKEDTUBE'),
#  ('KINKEDTUBE', 'VENTTUBE'),
#  ('ARTCO2', 'ERRCAUTER'),
#  ('PULMEMBOLUS', 'BP'),
#  ('KINKEDTUBE', 'MINVOLSET'),
#  ('TPR', 'CVP'),
#  ('CVP', 'TPR'),
#  ('PVSAT', 'INSUFFANESTH'),
#  ('PAP', 'FIO2'),
#  ('ARTCO2', 'PULMEMBOLUS'),
#  ('ERRCAUTER', 'PAP'),
#  ('HR', 'INSUFFANESTH'),
#  ('FIO2', 'SHUNT'),
#  ('MINVOLSET', 'LVEDVOLUME'),
#  ('FIO2', 'ERRCAUTER'),
#  ('EXPCO2', 'INSUFFANESTH'),
#  ('PAP', 'VENTMACH'),
#  ('ERRLOWOUTPUT', 'SHUNT'),
#  ('PCWP', 'PVSAT'),
#  ('HR', 'LVFAILURE'),
#  ('ANAPHYLAXIS', 'SHUNT'),
#  ('CVP', 'HR'),
#  ('ANAPHYLAXIS', 'ERRCAUTER'),
#  ('SHUNT', 'LVFAILURE'),
#  ('BP', 'SHUNT'),
#  ('EXPCO2', 'LVFAILURE'),
#  ('BP', 'ERRCAUTER'),
#  ('HISTORY', 'HREKG'),
#  ('KINKEDTUBE', 'SHUNT'),
#  ('FIO2', 'LVEDVOLUME'),
#  ('DISCONNECT', 'ERRLOWOUTPUT'),
#  ('ERRCAUTER', 'INSUFFANESTH'),
#  ('ERRLOWOUTPUT', 'LVEDVOLUME'),
#  ('ANAPHYLAXIS', 'LVEDVOLUME'),
#  ('HRBP', 'PCWP'),
#  ('VENTMACH', 'CVP'),
#  ('DISCONNECT', 'MINVOLSET'),
#  ('VENTMACH', 'TPR'),
#  ('EXPCO2', 'PULMEMBOLUS'),
#  ('PULMEMBOLUS', 'INSUFFANESTH'),
#  ('FIO2', 'PRESS'),
#  ('PULMEMBOLUS', 'ARTCO2'),
#  ('SHUNT', 'FIO2'),
#  ('MINVOL', 'HISTORY'),
#  ('CATECHOL', 'CVP'),
#  ('EXPCO2', 'FIO2'),
#  ('ERRLOWOUTPUT', 'PRESS'),
#  ('PCWP', 'VENTTUBE'),
#  ('ANAPHYLAXIS', 'PRESS'),
#  ('PULMEMBOLUS', 'LVFAILURE'),
#  ('HRSAT', 'STROKEVOLUME'),
#  ('BP', 'PRESS'),
#  ('HRBP', 'PAP'),
#  ('SHUNT', 'VENTMACH'),
#  ('HYPOVOLEMIA', 'HISTORY'),
#  ('SHUNT', 'CO'),
#  ('ERRCAUTER', 'PULMEMBOLUS'),
#  ('INSUFFANESTH', 'HRSAT'),
#  ('KINKEDTUBE', 'INTUBATION'),
#  ('INTUBATION', 'HRBP'),
#  ('ERRCAUTER', 'KINKEDTUBE'),
#  ('PULMEMBOLUS', 'INTUBATION'),
#  ('STROKEVOLUME', 'VENTTUBE'),
#  ('PULMEMBOLUS', 'VENTALV'),
#  ('FIO2', 'CO'),
#  ('MINVOLSET', 'CVP'),
#  ('CO', 'ERRLOWOUTPUT'),
#  ('PULMEMBOLUS', 'FIO2'),
#  ('MINVOLSET', 'TPR'),
#  ('CVP', 'PVSAT'),
#  ('HREKG', 'ERRLOWOUTPUT'),
#  ('VENTALV', 'TPR'),
#  ('KINKEDTUBE', 'VENTMACH'),
#  ('CVP', 'HRBP'),
#  ('KINKEDTUBE', 'CO'),
#  ('INTUBATION', 'BP'),
#  ('PULMEMBOLUS', 'VENTMACH'),
#  ('FIO2', 'CVP'),
#  ('LVFAILURE', 'SHUNT'),
#  ('CVP', 'VENTLUNG'),
#  ('VENTMACH', 'STROKEVOLUME'),
#  ('FIO2', 'TPR'),
#  ('ANAPHYLAXIS', 'CVP'),
#  ('MINVOLSET', 'DISCONNECT'),
#  ('TPR', 'VENTLUNG'),
#  ('HYPOVOLEMIA', 'VENTTUBE'),
#  ('ERRLOWOUTPUT', 'TPR'),
#  ('INSUFFANESTH', 'HREKG'),
#  ('HYPOVOLEMIA', 'MINVOLSET'),
#  ('CVP', 'EXPCO2'),
#  ('HRSAT', 'HYPOVOLEMIA'),
#  ('CATECHOL', 'STROKEVOLUME'),
#  ('VENTLUNG', 'PCWP'),
#  ('TPR', 'EXPCO2'),
#  ('DISCONNECT', 'INTUBATION'),
#  ('CVP', 'ERRLOWOUTPUT'),
#  ('PAP', 'HREKG'),
#  ('TPR', 'ERRLOWOUTPUT'),
#  ('SAO2', 'TPR'),
#  ('FIO2', 'HR'),
#  ('ERRCAUTER', 'MINVOL'),
#  ('CO', 'SHUNT'),
#  ('VENTMACH', 'HISTORY'),
#  ('VENTTUBE', 'PCWP'),
#  ('ERRLOWOUTPUT', 'HR'),
#  ('DISCONNECT', 'FIO2'),
#  ('CVP', 'MINVOLSET'),
#  ('INTUBATION', 'ANAPHYLAXIS'),
#  ('PRESS', 'PULMEMBOLUS'),
#  ('PCWP', 'VENTALV'),
#  ('HRBP', 'LVEDVOLUME'),
#  ('CATECHOL', 'HISTORY'),
#  ('KINKEDTUBE', 'HR'),
#  ('KINKEDTUBE', 'DISCONNECT'),
#  ('LVFAILURE', 'PRESS'),
#  ('HYPOVOLEMIA', 'SHUNT'),
#  ('DISCONNECT', 'VENTMACH'),
#  ('LVEDVOLUME', 'PAP'),
#  ('HISTORY', 'SHUNT'),
#  ('PAP', 'SAO2'),
#  ('HREKG', 'INSUFFANESTH'),
#  ('VENTLUNG', 'HYPOVOLEMIA'),
#  ('INTUBATION', 'INSUFFANESTH'),
#  ('INSUFFANESTH', 'PCWP'),
#  ('PCWP', 'VENTMACH'),
#  ('VENTMACH', 'HYPOVOLEMIA'),
#  ('HREKG', 'LVFAILURE'),
#  ('INTUBATION', 'LVFAILURE'),
#  ('PAP', 'PCWP'),
#  ('VENTMACH', 'ERRLOWOUTPUT'),
#  ('ANAPHYLAXIS', 'KINKEDTUBE'),
#  ('CATECHOL', 'HYPOVOLEMIA'),
#  ('CO', 'INTUBATION'),
#  ('ANAPHYLAXIS', 'STROKEVOLUME'),
#  ('CATECHOL', 'ERRLOWOUTPUT'),
#  ('PVSAT', 'STROKEVOLUME'),
#  ('INSUFFANESTH', 'PAP'),
#  ('HYPOVOLEMIA', 'PRESS'),
#  ('HREKG', 'PULMEMBOLUS'),
#  ('INTUBATION', 'PULMEMBOLUS'),
#  ('HISTORY', 'PRESS'),
#  ('SHUNT', 'HRBP'),
#  ('HRSAT', 'LVFAILURE'),
#  ('FIO2', 'HISTORY'),
#  ('INTUBATION', 'KINKEDTUBE'),
#  ('INTUBATION', 'FIO2'),
#  ('TPR', 'LVFAILURE'),
#  ('ERRLOWOUTPUT', 'HISTORY'),
#  ('SHUNT', 'CATECHOL'),
#  ('ANAPHYLAXIS', 'HISTORY'),
#  ('PVSAT', 'PCWP'),
#  ('LVFAILURE', 'TPR'),
#  ('ARTCO2', 'HYPOVOLEMIA'),
#  ('PAP', 'ANAPHYLAXIS'),
#  ('VENTLUNG', 'ERRCAUTER'),
#  ('STROKEVOLUME', 'TPR'),
#  ('ERRLOWOUTPUT', 'PVSAT'),
#  ('FIO2', 'HRBP'),
#  ('CVP', 'INTUBATION'),
#  ('ANAPHYLAXIS', 'PVSAT'),
#  ('PULMEMBOLUS', 'HREKG'),
#  ('HR', 'PCWP'),
#  ('MINVOLSET', 'ERRLOWOUTPUT'),
#  ('CVP', 'VENTALV'),
#  ('FIO2', 'VENTLUNG'),
#  ('LVEDVOLUME', 'PULMEMBOLUS'),
#  ('VENTALV', 'ERRLOWOUTPUT'),
#  ('EXPCO2', 'PCWP'),
#  ('VENTTUBE', 'SHUNT'),
#  ('FIO2', 'CATECHOL'),
#  ('ERRCAUTER', 'STROKEVOLUME'),
#  ('TPR', 'VENTALV'),
#  ('VENTTUBE', 'ERRCAUTER'),
#  ('SHUNT', 'BP'),
#  ('CVP', 'FIO2'),
#  ('ERRLOWOUTPUT', 'VENTLUNG'),
#  ('VENTLUNG', 'LVEDVOLUME'),
#  ('FIO2', 'EXPCO2'),
#  ('KINKEDTUBE', 'HRBP'),
#  ('FIO2', 'ERRLOWOUTPUT'),
#  ('ERRLOWOUTPUT', 'EXPCO2'),
#  ('ANAPHYLAXIS', 'EXPCO2'),
#  ('KINKEDTUBE', 'CATECHOL'),
#  ('CVP', 'VENTMACH'),
#  ('VENTTUBE', 'LVEDVOLUME'),
#  ('ANAPHYLAXIS', 'ERRLOWOUTPUT'),
#  ('PVSAT', 'HYPOVOLEMIA'),
#  ('ERRCAUTER', 'PCWP'),
#  ('TPR', 'VENTMACH'),
#  ('HR', 'PAP'),
#  ('BP', 'ERRLOWOUTPUT'),
#  ('FIO2', 'MINVOLSET'),
#  ('INSUFFANESTH', 'SHUNT'),
#  ('HYPOVOLEMIA', 'TPR'),
#  ('EXPCO2', 'PAP'),
#  ('INSUFFANESTH', 'ERRCAUTER'),
#  ('LVEDVOLUME', 'PRESS'),
#  ('ANAPHYLAXIS', 'VENTTUBE'),
#  ('SAO2', 'ERRLOWOUTPUT'),
#  ('ERRLOWOUTPUT', 'MINVOLSET'),
#  ('HISTORY', 'TPR'),
#  ('ANAPHYLAXIS', 'MINVOLSET'),
#  ('PAP', 'ERRCAUTER'),
#  ('PULMEMBOLUS', 'PCWP'),
#  ('KINKEDTUBE', 'BP'),
#  ('SHUNT', 'ANAPHYLAXIS'),
#  ('VENTALV', 'ANAPHYLAXIS'),
#  ('INSUFFANESTH', 'LVEDVOLUME'),
#  ('PAP', 'KINKEDTUBE'),
#  ('LVEDVOLUME', 'MINVOL'),
#  ('MINVOLSET', 'INSUFFANESTH'),
#  ('ARTCO2', 'LVEDVOLUME'),
#  ('ERRCAUTER', 'HYPOVOLEMIA'),
#  ('SHUNT', 'INSUFFANESTH'),
#  ('VENTALV', 'INSUFFANESTH'),
#  ('HRBP', 'STROKEVOLUME'),
#  ('CVP', 'DISCONNECT'),
#  ('INSUFFANESTH', 'PRESS'),
#  ('MINVOLSET', 'LVFAILURE'),
#  ('KINKEDTUBE', 'ANAPHYLAXIS'),
#  ('PVSAT', 'ERRCAUTER'),
#  ('SAO2', 'ANAPHYLAXIS'),
#  ('ERRCAUTER', 'VENTTUBE'),
#  ('FIO2', 'ARTCO2'),
#  ('PCWP', 'VENTLUNG'),
#  ('PULMEMBOLUS', 'ANAPHYLAXIS'),
#  ('VENTLUNG', 'CVP'),
#  ('PCWP', 'SAO2'),
#  ('LVEDVOLUME', 'HRSAT'),
#  ('LVFAILURE', 'PVSAT'),
#  ('HR', 'ERRCAUTER'),
#  ('FIO2', 'LVFAILURE'),
#  ('ANAPHYLAXIS', 'ARTCO2'),
#  ('VENTLUNG', 'TPR'),
#  ('HRBP', 'HISTORY'),
#  ('PRESS', 'PCWP'),
#  ('HR', 'PULMEMBOLUS'),
#  ('PVSAT', 'LVEDVOLUME'),
#  ('STROKEVOLUME', 'HRBP'),
#  ('KINKEDTUBE', 'INSUFFANESTH'),
#  ('ANAPHYLAXIS', 'LVFAILURE'),
#  ('ERRLOWOUTPUT', 'LVFAILURE'),
#  ('VENTTUBE', 'CVP'),
#  ('SAO2', 'INSUFFANESTH'),
#  ('INSUFFANESTH', 'MINVOL'),
#  ('HR', 'KINKEDTUBE'),
#  ('MINVOLSET', 'FIO2'),
#  ('HR', 'LVEDVOLUME'),
#  ('VENTALV', 'FIO2'),
#  ('PAP', 'MINVOL'),
#  ('KINKEDTUBE', 'LVFAILURE'),
#  ('FIO2', 'INTUBATION'),
#  ('SAO2', 'LVFAILURE'),
#  ('EXPCO2', 'LVEDVOLUME'),
#  ('LVFAILURE', 'EXPCO2'),
#  ('FIO2', 'VENTALV'),
#  ('ERRLOWOUTPUT', 'INTUBATION'),
#  ('STROKEVOLUME', 'EXPCO2'),
#  ('ANAPHYLAXIS', 'INTUBATION'),
#  ('DISCONNECT', 'PAP'),
#  ('LVFAILURE', 'ERRLOWOUTPUT'),
#  ('ERRLOWOUTPUT', 'VENTALV'),
#  ('BP', 'INTUBATION'),
#  ('STROKEVOLUME', 'ERRLOWOUTPUT'),
#  ('VENTMACH', 'DISCONNECT'),
#  ('ANAPHYLAXIS', 'VENTALV'),
#  ('HRBP', 'HYPOVOLEMIA'),
#  ('INSUFFANESTH', 'CVP'),
#  ('ERRLOWOUTPUT', 'FIO2'),
#  ('HYPOVOLEMIA', 'PVSAT'),
#  ('ANAPHYLAXIS', 'FIO2'),
#  ('LVFAILURE', 'MINVOLSET'),
#  ('DISCONNECT', 'ANAPHYLAXIS'),
#  ('PULMEMBOLUS', 'ERRCAUTER'),
#  ('PAP', 'HRSAT'),
#  ('INSUFFANESTH', 'TPR'),
#  ('ERRCAUTER', 'LVEDVOLUME'),
#  ('BP', 'FIO2'),
#  ('KINKEDTUBE', 'PULMEMBOLUS'),
#  ('FIO2', 'VENTMACH'),
#  ('HYPOVOLEMIA', 'HRBP'),
#  ('CVP', 'HREKG'),
#  ('ARTCO2', 'CVP'),
#  ('KINKEDTUBE', 'FIO2'),
#  ('ERRLOWOUTPUT', 'VENTMACH'),
#  ('ANAPHYLAXIS', 'VENTMACH'),
#  ('PULMEMBOLUS', 'KINKEDTUBE'),
#  ('HYPOVOLEMIA', 'VENTLUNG'),
#  ('ARTCO2', 'TPR'),
#  ('MINVOL', 'PCWP'),
#  ('ANAPHYLAXIS', 'CO'),
#  ('DISCONNECT', 'INSUFFANESTH'),
#  ('HREKG', 'PCWP'),
#  ('INTUBATION', 'PCWP'),
#  ('HYPOVOLEMIA', 'EXPCO2'),
#  ('ERRCAUTER', 'PRESS'),
#  ('HISTORY', 'HYPOVOLEMIA'),
#  ('HYPOVOLEMIA', 'ERRLOWOUTPUT'),
#  ('CVP', 'SAO2'),
#  ('VENTTUBE', 'STROKEVOLUME'),
#  ('MINVOL', 'PAP'),
#  ('PVSAT', 'CVP'),
#  ('HREKG', 'STROKEVOLUME'),
#  ('HISTORY', 'VENTTUBE'),
#  ('HRBP', 'SHUNT'),
#  ('HREKG', 'PAP'),
#  ('HISTORY', 'MINVOLSET'),
#  ('INTUBATION', 'PAP'),
#  ('PVSAT', 'TPR'),
#  ('VENTLUNG', 'HISTORY'),
#  ('HR', 'CVP'),
#  ('SHUNT', 'HRSAT'),
#  ('TPR', 'PCWP'),
#  ('DISCONNECT', 'PULMEMBOLUS'),
#  ('ERRCAUTER', 'CO'),
#  ('DISCONNECT', 'KINKEDTUBE'),
#  ('ANAPHYLAXIS', 'DISCONNECT'),
#  ('EXPCO2', 'TPR'),
#  ('VENTTUBE', 'HISTORY'),
#  ('INSUFFANESTH', 'STROKEVOLUME'),
#  ('PCWP', 'PULMEMBOLUS'),
#  ('PULMEMBOLUS', 'MINVOL'),
#  ('PAP', 'STROKEVOLUME'),
#  ('CO', 'INSUFFANESTH'),
#  ('CVP', 'PAP'),
#  ('HRSAT', 'PAP'),
#  ('ERRCAUTER', 'CVP'),
#  ('ERRCAUTER', 'TPR'),
#  ('KINKEDTUBE', 'HRSAT'),
#  ('VENTLUNG', 'ERRLOWOUTPUT'),
#  ('INSUFFANESTH', 'HISTORY'),
#  ('HYPOVOLEMIA', 'INSUFFANESTH'),
#  ('HRBP', 'INTUBATION'),
#  ('PULMEMBOLUS', 'HRSAT'),
#  ('VENTTUBE', 'HYPOVOLEMIA'),
#  ('PAP', 'HISTORY'),
#  ('HYPOVOLEMIA', 'LVFAILURE'),
#  ('LVEDVOLUME', 'VENTTUBE'),
#  ('VENTTUBE', 'ERRLOWOUTPUT'),
#  ('LVFAILURE', 'VENTMACH'),
#  ('LVEDVOLUME', 'MINVOLSET'),
#  ('ERRCAUTER', 'HR'),
#  ('STROKEVOLUME', 'VENTMACH'),
#  ('CVP', 'INSUFFANESTH'),
#  ('INTUBATION', 'ERRCAUTER'),
#  ('HRSAT', 'INSUFFANESTH'),
#  ('CO', 'PULMEMBOLUS'),
#  ('MINVOL', 'PULMEMBOLUS'),
#  ('CO', 'KINKEDTUBE'),
#  ('CO', 'FIO2'),
#  ('FIO2', 'HREKG'),
#  ('HYPOVOLEMIA', 'INTUBATION'),
#  ('HR', 'STROKEVOLUME'),
#  ('HREKG', 'KINKEDTUBE'),
#  ('INSUFFANESTH', 'HYPOVOLEMIA'),
#  ('INSUFFANESTH', 'EXPCO2'),
#  ('ERRLOWOUTPUT', 'HREKG'),
#  ('HYPOVOLEMIA', 'VENTALV'),
#  ('EXPCO2', 'STROKEVOLUME'),
#  ('HISTORY', 'INTUBATION'),
#  ('HREKG', 'LVEDVOLUME'),
#  ('INTUBATION', 'LVEDVOLUME'),
#  ('INSUFFANESTH', 'ERRLOWOUTPUT'),
#  ('PAP', 'HYPOVOLEMIA'),
#  ('KINKEDTUBE', 'HREKG'),
#  ('LVEDVOLUME', 'SHUNT'),
#  ('PVSAT', 'HISTORY'),
#  ('INSUFFANESTH', 'VENTTUBE'),
#  ('VENTMACH', 'ANAPHYLAXIS'),
#  ('ARTCO2', 'ERRLOWOUTPUT'),
#  ('INSUFFANESTH', 'MINVOLSET'),
#  ('MINVOLSET', 'PCWP'),
#  ('TPR', 'ERRCAUTER'),
#  ('SHUNT', 'PCWP'),
#  ('HYPOVOLEMIA', 'VENTMACH'),
#  ('HR', 'HISTORY'),
#  ('PAP', 'VENTTUBE'),
#  ('VENTALV', 'PCWP'),
#  ('CVP', 'PULMEMBOLUS'),
#  ('HRSAT', 'PULMEMBOLUS'),
#  ('EXPCO2', 'HISTORY'),
#  ('CVP', 'KINKEDTUBE'),
#  ('HISTORY', 'VENTMACH'),
#  ('HRSAT', 'KINKEDTUBE'),
#  ('ANAPHYLAXIS', 'VENTLUNG'),
#  ('ERRLOWOUTPUT', 'SAO2'),
#  ('PRESS', 'TPR'),
#  ('ANAPHYLAXIS', 'SAO2'),
#  ('VENTMACH', 'INSUFFANESTH'),
#  ('VENTLUNG', 'LVFAILURE'),
#  ('PULMEMBOLUS', 'STROKEVOLUME'),
#  ('FIO2', 'BP'),
#  ('VENTMACH', 'LVFAILURE'),
#  ('MINVOLSET', 'PAP'),
#  ('CATECHOL', 'INSUFFANESTH'),
#  ('ERRCAUTER', 'HISTORY'),
#  ('PVSAT', 'ERRLOWOUTPUT'),
#  ('HR', 'HYPOVOLEMIA'),
#  ('KINKEDTUBE', 'PCWP'),
#  ('SAO2', 'PCWP'),
#  ('CATECHOL', 'LVFAILURE'),
#  ('EXPCO2', 'HYPOVOLEMIA'),
#  ('ERRCAUTER', 'PVSAT'),
#  ('MINVOLSET', 'ANAPHYLAXIS'),
#  ('PULMEMBOLUS', 'HISTORY'),
#  ('ERRCAUTER', 'HRBP'),
#  ('EXPCO2', 'ERRLOWOUTPUT'),
#  ('FIO2', 'PAP'),
#  ('VENTLUNG', 'FIO2'),
#  ('ERRLOWOUTPUT', 'PAP'),
#  ('ERRCAUTER', 'VENTLUNG'),
#  ('ANAPHYLAXIS', 'PAP'),
#  ('PAP', 'LVEDVOLUME'),
#  ('HISTORY', 'HR'),
#  ('VENTMACH', 'FIO2'),
#  ('BP', 'PAP'),
#  ('HREKG', 'CVP'),
#  ('INTUBATION', 'CVP'),
#  ('FIO2', 'ANAPHYLAXIS'),
#  ('ARTCO2', 'INSUFFANESTH'),
#  ('VENTTUBE', 'FIO2'),
#  ('ERRCAUTER', 'EXPCO2'),
#  ('CVP', 'MINVOL'),
#  ('KINKEDTUBE', 'PAP'),
#  ('CATECHOL', 'PULMEMBOLUS'),
#  ('INTUBATION', 'TPR'),
#  ('TPR', 'MINVOL'),
#  ('CATECHOL', 'KINKEDTUBE'),
#  ('ERRCAUTER', 'ERRLOWOUTPUT'),
#  ('CATECHOL', 'FIO2'),
#  ('ARTCO2', 'LVFAILURE'),
#  ('PRESS', 'STROKEVOLUME'),
#  ('INSUFFANESTH', 'INTUBATION'),
#  ('PULMEMBOLUS', 'HYPOVOLEMIA'),
#  ('PAP', 'PRESS'),
#  ('FIO2', 'INSUFFANESTH'),
#  ('INSUFFANESTH', 'VENTALV'),
#  ('ERRCAUTER', 'MINVOLSET'),
#  ('ERRLOWOUTPUT', 'INSUFFANESTH'),
#  ('CVP', 'HRSAT'),
#  ('DISCONNECT', 'PCWP'),
#  ('ANAPHYLAXIS', 'INSUFFANESTH'),
#  ('MINVOLSET', 'ERRCAUTER'),
#  ('BP', 'INSUFFANESTH'),
#  ('LVFAILURE', 'HRBP'),
#  ('LVEDVOLUME', 'TPR'),
#  ('VENTALV', 'ERRCAUTER'),
#  ('PULMEMBOLUS', 'VENTTUBE'),
#  ('PULMEMBOLUS', 'MINVOLSET'),
#  ('MINVOLSET', 'PULMEMBOLUS'),
#  ('PRESS', 'HISTORY'),
#  ('LVFAILURE', 'VENTLUNG'),
#  ('ARTCO2', 'FIO2'),
#  ('INSUFFANESTH', 'VENTMACH'),
#  ('LVFAILURE', 'SAO2'),
#  ('PVSAT', 'LVFAILURE'),
#  ('INSUFFANESTH', 'CO'),
#  ('SHUNT', 'LVEDVOLUME'),
#  ('VENTALV', 'LVEDVOLUME'),
#  ('PAP', 'CO'),
#  ('FIO2', 'PULMEMBOLUS'),
#  ('FIO2', 'KINKEDTUBE'),
#  ('ERRLOWOUTPUT', 'PULMEMBOLUS'),
#  ('MINVOL', 'STROKEVOLUME'),
#  ('DISCONNECT', 'HYPOVOLEMIA'),
#  ('ANAPHYLAXIS', 'PULMEMBOLUS'),
#  ('KINKEDTUBE', 'ERRCAUTER'),
#  ('ERRLOWOUTPUT', 'KINKEDTUBE'),
#  ('SAO2', 'ERRCAUTER'),
#  ('BP', 'PULMEMBOLUS'),
#  ('INTUBATION', 'STROKEVOLUME')]

# %%
len(v)
# Out:
# 37

# %%
N = 3
n = 3
v = list(df_test)
while N <= n:
    my_list = [x for x in itertools.permutations(v, N) if x[:2] not in chi2_ind]
#         print(i[0], i[1], i[2:N])
    phi = chi_square(X=i, Y=i[1], Z=i[2:N], data=my_list, significance_level=0.05)
#         print(chi2)
    N += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [59], line 8
#       5     my_list = [x for x in itertools.permutations(v, N) if x[:2] not in chi2_ind]
#       6     for i in my_list:
#       7 #         print(i[0], i[1], i[2:N])
# ----> 8         the_list = chi_square(X=i[0], Y=i[1], Z=i[2:N], data=my_list, significance_level=0.05)
#       9 #         print(chi2)
#      10     N += 1
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:95, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      35 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      36     r"""
#      37     Chi-square conditional independence test.
#      38     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      93     False
#      94     """
# ---> 95     return power_divergence(
#      96         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      97     )
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:548, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     546 chi = 0
#     547 dof = 0
# --> 548 for z_state, df in data.groupby(Z):
#     549     try:
#     550         c, _, d, _ = stats.chi2_contingency(
#     551             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     552         )
#
# AttributeError: 'list' object has no attribute 'groupby'

# %% [markdown]
# ### Dead functions which i may or may not remove

# %%
#returns combinations of Zs
def conditional_combine_1(df):
    first_empty = []
    second_empty = []
    my_list = conditional_sort_2(df)
    for i in my_list:
        first_empty.append(i[0])
        second_empty.append(i[1])
    list_df = list(df)
    v = list(itertools.combinations(list_df, 2))
    for i,j,k in zip(first_empty, second_empty, v):
        chi_square(X=i, Y=j, Z=k, data=df)
    return chi_square
