# %%
import pandas as pd
import numpy as np
from pygobnilp.gobnilp import Gobnilp
import pgmpy
import itertools
from pgmpy.estimators.CITests import pearsonr
from pgmpy.estimators.CITests import chi_square
import networkx as nx
import time
import collections

# %%
def csv_format_discrete(csv_file):
    df = pd.read_csv(csv_file, sep="\s+")
    return df.drop([0])

#returns the csv_file in a pandas dataframe, formatted properly, discrete dataset only

# %%
#small network : n <= 20 nodes, medium network: 20 <= n <= 50 , large: 50 <= n <= 100, ... 
df_small = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat")
df_medium = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat")
# df_large = csv_format_discrete(r"")

# %% [markdown]
# ### chi-squared test

# %%
df_small
# Out:
#        One  Two  Three  Four  Five  Six  Seven  Eight
# 1        1    1      0     0     0    1      0      1
# 2        1    0      0     0     0    0      1      0
# 3        0    0      1     0     0    0      1      0
# 4        1    0      1     0     0    0      1      0
# 5        1    0      1     0     0    0      0      1
# ...    ...  ...    ...   ...   ...  ...    ...    ...
# 9996     0    0      1     0     0    0      0      0
# 9997     1    0      1     0     0    0      1      1
# 9998     0    0      0     0     0    0      1      0
# 9999     1    0      0     0     0    0      1      0
# 10000    1    0      1     0     0    0      1      0
#
# [10000 rows x 8 columns]

# %%
#0th order chi2 test
def chi2bool(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    chi2 = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        chi = chi_square(X=i, Y=j, Z=[], data=df, significance_level=rho)
        chi2.append((i,j,chi))
    true_0 = [x for x in chi2 if True in x]
    false_0 = [x for x in chi2 if False in x]
    return true_0, false_0

# %% [markdown]
# ### Pearson's Product Moment Correlation Coefficient

# %%
df_gaus = pd.read_csv(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\gaussian.dat", sep="\s+")
df_gaus
# Out:
#              A          B          C          D         E          F         G
# 0     1.113083   1.932164   7.074806   8.660411  0.881591  24.719501  9.216382
# 1    -0.247948  11.334343  24.347372  23.355432  7.040113  36.812996  3.678833
# 2     1.854508   3.032020  11.086473  11.055891  3.834530  22.017182  2.424513
# 3     0.833911   3.857970  11.224775  11.937471  1.005624  23.285643  6.085473
# 4     0.488614   4.512613  10.000476  12.537179  4.084746  24.537596  5.117575
# ...        ...        ...        ...        ...       ...        ...       ...
# 4995  0.625860   1.587941   5.952431   8.516822  4.894385  16.950123  2.558535
# 4996  0.241723  -0.497071   1.695681   5.563204  7.454081  21.165266  4.867241
# 4997  2.527720  -2.706339   0.984988   1.597447  3.692427  18.808892  5.598200
# 4998  1.484585   1.468603   7.206672   8.486116  2.611856  21.528922  5.106188
# 4999 -0.306881   1.783709   4.603075   8.550474  5.044690  23.063591  6.511988
#
# [5000 rows x 7 columns]

# %%
#0th order chi2 test
def PMCC(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    R_list = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        R = pearsonr(X=i, Y=j, Z=[], data=df, significance_level=rho)
        R_list.append((i,j,R))
    true_0 = [x for x in R_list if True in x]
    false_0 = [x for x in R_list if False in x]
    return true_0, false_0

# %% [markdown]
# ### Sorting Functions

# %%
def create_permutations(my_list):
    '''
    takes in a list, remove extra permutations from the list and only creates a pair of permutations
    '''
    p_permutations = []
    new_list = list(set(tuple(sorted(l[:2])) for l in my_list))
    for items in new_list:
        new_list_0 = list(itertools.permutations(items[:2],2))[1]
        p_permutations.append(new_list_0)
    return new_list + p_permutations

# %%
#given 2 lists, append them together and remove duplicates
def remove_permutations(list_):
    '''
    returns a sorted list without permutation
    '''
    return sorted(list(set(tuple(sorted(l[:2])) for l in list_)))

# %%
def PC_(df, n, rho):
    '''
    Note:
    This function will start from at least 0th order CI
    
    Parameters:
    df (pandas dataframe)
    n an integer, the stopping point of the while loop
    rho (the significance level, only accepts values between 0 and 1 inclusive)
    
    Returns:
    A list which contains every independent X and Y
    '''
    N = 3
    v = list(df)
    # remove_list = [x for x in p_permute]
    remove_list = create_permutations([x[:2] for x in chi2bool(df, rho)[0]])
    #x[:2] for 0th order and its permutations, so we can later remove it 
    empty_list = []
    while N <= n:
        list_permutations = [x for x in itertools.permutations(v, N) if x[:2] not in remove_list]
        p_1, p_2, p_3 = [x[:1] for x in list_permutations], [x[1:2] for x in list_permutations], [x[2:] for x in list_permutations]
        for i,j,k in zip(p_1, p_2, p_3):
            chi2 = chi_square(X=i[0], Y=j[0], Z=k, data=df, significance_level=rho)
            empty_list.append((i[0],j[0],k,chi2))
        true_list = create_permutations([x[:2] for x in empty_list if True in x])
        #create_permutations ensures only 1 set of permutations of (X,Y) and (Y,X) and removes dupes
        remove_list = remove_list + create_permutations(true_list)
        remove_list = create_permutations(remove_list)
        N += 1
        
    return remove_permutations(remove_list) #returns 1 set of permutations

#ON MEDIUM SIZED NETWORKS:
#1st order CI takes 2minutes to run
#2nd order CI 9-15minutes to run
#nP5 takes ??? minutes to run
#nP6 not doable

# %% [markdown]
# ### graph

# %%
def Graph(df):
    G = nx.Graph()
    v = list(df)
    for i in v:
        G.add_node(i)
    k = list(itertools.combinations(v,2))
    for i,j in k:
        G.add_edge(i,j)
#     print(G)
    return(G)

# %%
g = Graph(df_medium)
print(g)
nx.draw(g, with_labels = True)
# Out:
# Graph with 37 nodes and 666 edges

# %%
def PC_0(df, rho, G):
    '''
    finds 0th order conditional independencies (CI) between each node, if True then remove an edge 
    '''
    v = list(df)
    for i in v:
        G.add_node(i)
    k = list(itertools.combinations(v,2))
    for i,j in k:
        G.add_edge(i,j)
    ind_0 = [x[:2] for x in chi2bool(df, rho)[0]]
    for i,j in ind_0:
        G.remove_edge(i,j)
#     print(G)
    return(G, ind_0)

# %%
# %%time
g_0 = PC_0(df_medium, 0.05, g)[0]
print(g_0)
nx.draw(g_0, with_labels = True)
# Out:
# Graph with 37 nodes and 265 edges
# CPU times: total: 938 ms
# Wall time: 916 ms

# %% [markdown]
# ### adjacency finder

# %%
def find_adjacency_XY(graph):    
    test_list = []
    graph_list = list(graph.edges)
    for i,j in graph_list:
        test_list.append((i, j, list(graph.edges(i)), list(graph.edges(j))))
    n = 0
    N = len(test_list)
    edge_XY = []
    while n < N:
        ##
        adjacent_X = []
        adjacent_Y = []
        X, Y = test_list[n][0], test_list[n][1]
        k_X, k_Y = test_list[n][2], test_list[n][3]
        edge_X = [x for x in k_X if x[1] != Y]
        edge_Y = [x for x in k_Y if x[1] not in (y[1] for y in k_X) and x[1] != X]
        for x in edge_X:
            adjacent_X.append(x[1])
        for y in edge_Y:
            adjacent_Y.append(y[1])
        adjacent_XY = adjacent_X + adjacent_Y
        len_XY = len(adjacent_XY)
        edge_XY.append((X, Y, adjacent_XY, len_XY))
#         print(edge_XY)
        n += 1
    return edge_XY

# %%
adj = find_adjacency_XY(g_0)

# %% [markdown]
# ### obtaining combinations and data preprocessing

# %%
adj[1][0], adj[1][2][1], adj[1][2][0]
# Out:
# ('PULMEMBOLUS', 'SAO2', 'PAP')

# %%
def get_combinations(this_list, N_0, rho):
    '''
    probably the main function of everything
    given a list in the form
    '''
    adjacency = this_list[2]
    len_adjacency = len(adjacency)
    n = 1
    combinations = []
    while n <= N_0:
        k = list(itertools.combinations(adjacency, n))
        t = list(list(x) for x in k)
        for i in t:
            chi2 = chi_square(X=this_list[0], Y=this_list[1], Z=i, data=df_medium, significance_level=rho)
            if chi2 == True:
                combinations.append((this_list[0], this_list[1], i, chi2))
                return combinations
        n += 1

# %%
def combinations_adjacents(adj, N, rho):
    '''
    one of the main functions
    adj = output from find_adjacency_XY
    N = stopping point for how many combinations you want
    output: obtains the combinations of n=1,2,...N of the whole list in an unordered manner (see open_list)
    '''
    len_adjacents = len(adj)
    combinations = []
    for i in range(len_adjacents):
        t = get_combinations(adj[i], N, rho)
        combinations.append(t)
    return combinations

# %%
def open_list(lists):
    '''
    5/4 update: this function has become kind of redundant, do not use 
    lists = output from combinations_adjacents, the whole thing
    all this function does is concatenates the adjacents of different combinations together
    '''
    n = 0
    N = len(lists)
    output = []
    while n < N:
        t = list(itertools.chain.from_iterable(lists[n][2]))
        output.append((lists[n][0], lists[n][1], t))
        n += 1
    return output

# %% [markdown]
# ### chi2 test

# %%
def chi2_list(this_list, df, rho):
    '''
    update 5/4, this function has become kind of redundant as well
    performs chi2 test on 1 list in open_list format
    '''
    n = 0
    N = len(this_list[2])
    x = this_list[0]
    y = this_list[1]
    output = []
    while n < N:
        chi2 = chi_square(X=x, Y=y, Z=this_list[2][n], data=df, significance_level=rho)
        if chi2 == True:
            output.append(chi2)
            break
        n += 1
    return output

# %%
def PC_final(graph, adj, N, df, rho):
    '''
    graph = nx.graph
    adj = output from find_adjacency_XY
    N = order of conditional independence
    df = dataframe
    rho = significance_level
    '''
    X_Y = []
    combinations_chi2 = combinations_adjacents(adj, N, rho)
    for i in combinations_chi2:
        if i != None:
            for j in i:
                X_Y.append((j[0], j[1]))
    for i in X_Y:
        graph.remove_edge(i[0], i[1])
    return graph, X_Y

# %%
X_Y = []
combinations_chi2 = combinations_adjacents(adj, 1, 0.05)
for i in combinations_chi2:
    if i != None:
        for j in i:
            X_Y.append((j[0], j[1]))
# for i in X_Y:
#     graph.remove_edge(i[0], i[1])
# return graph, X_Y

# %%
g = Graph(df_medium)
g_0 = PC_0(df_medium, 0.05, g)[0]

# %%
new_g = PC_final(g_0, adj, 1, df_medium, 0.05)[0]

# %%
# %%time
g = Graph(df_medium) #initializes the graph
g_0 = PC_0(df_medium, 0.05, g)[0] #0th order CI
new_g = PC_final(g_0, adj, 1, df_medium, 0.05)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3
#
# Cell In [29], line 10, in PC_final(graph, adj, N, df, rho)
#       2 '''
#       3 graph = nx.graph
#       4 adj = output from find_adjacency_XY
#    (...)
#       7 rho = significance_level
#       8 '''
#       9 X_Y = []
# ---> 10 combinations_chi2 = combinations_adjacents(adj, N, rho)
#      11 for i in combinations_chi2:
#      12     if i != None:
#
# Cell In [20], line 11, in combinations_adjacents(adj, N, rho)
#       9 combinations = []
#      10 for i in range(len_adjacents):
# ---> 11     t = get_combinations(adj[i], N, rho)
#      12     combinations.append(t)
#      13 return combinations
#
# Cell In [19], line 14, in get_combinations(this_list, N_0, rho)
#      12 t = list(list(x) for x in k)
#      13 for i in t:
# ---> 14     chi2 = chi_square(X=this_list[0], Y=this_list[1], Z=i, data=df_medium, significance_level=rho)
#      15     if chi2 == True:
#      16         combinations.append((this_list[0], this_list[1], i, chi2))
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:95, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      35 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      36     r"""
#      37     Chi-square conditional independence test.
#      38     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      93     False
#      94     """
# ---> 95     return power_divergence(
#      96         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      97     )
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:548, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     546 chi = 0
#     547 dof = 0
# --> 548 for z_state, df in data.groupby(Z):
#     549     try:
#     550         c, _, d, _ = stats.chi2_contingency(
#     551             df.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     552         )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:708, in BaseGrouper.get_iterator(self, data, axis)
#     706 splitter = self._get_splitter(data, axis=axis)
#     707 keys = self.group_keys_seq
# --> 708 for key, group in zip(keys, splitter):
#     709     yield key, group.__finalize__(data, method="groupby")
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:1230, in DataSplitter.__iter__(self)
#    1225 if self.ngroups == 0:
#    1226     # we are inside a generator, rather than raise StopIteration
#    1227     # we merely return signal the end
#    1228     return
# -> 1230 starts, ends = lib.generate_slices(self.slabels, self.ngroups)
#    1232 for start, end in zip(starts, ends):
#    1233     yield self._chop(sdata, slice(start, end))
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:1215, in DataSplitter.slabels(self)
#    1212 @cache_readonly
#    1213 def slabels(self) -> npt.NDArray[np.intp]:
#    1214     # Sorted labels
# -> 1215     return self.labels.take(self._sort_idx)
#
# KeyboardInterrupt:

# %%
# %%time
ind = PC_0(df_medium, 0.05, g_0)[1] + PC_final(g_0, adj, 1, df_medium, 0.05)[1]
# Out:
# CPU times: total: 15.3 s
# Wall time: 15.3 s

# %%
ind
# Out:
# [('PULMEMBOLUS', 'KINKEDTUBE'),
#  ('PULMEMBOLUS', 'INTUBATION'),
#  ('PULMEMBOLUS', 'MINVOLSET'),
#  ('PULMEMBOLUS', 'VENTMACH'),
#  ('PULMEMBOLUS', 'DISCONNECT'),
#  ('PULMEMBOLUS', 'VENTTUBE'),
#  ('PULMEMBOLUS', 'VENTLUNG'),
#  ('PULMEMBOLUS', 'VENTALV'),
#  ('PULMEMBOLUS', 'FIO2'),
#  ('PULMEMBOLUS', 'PVSAT'),
#  ('PULMEMBOLUS', 'INSUFFANESTH'),
#  ('PULMEMBOLUS', 'ARTCO2'),
#  ('PULMEMBOLUS', 'ANAPHYLAXIS'),
#  ('PULMEMBOLUS', 'TPR'),
#  ('PULMEMBOLUS', 'CATECHOL'),
#  ('PULMEMBOLUS', 'HR'),
#  ('PULMEMBOLUS', 'ERRCAUTER'),
#  ('PULMEMBOLUS', 'HREKG'),
#  ('PULMEMBOLUS', 'HYPOVOLEMIA'),
#  ('PULMEMBOLUS', 'LVFAILURE'),
#  ('PULMEMBOLUS', 'LVEDVOLUME'),
#  ('PULMEMBOLUS', 'CVP'),
#  ('PULMEMBOLUS', 'STROKEVOLUME'),
#  ('PULMEMBOLUS', 'CO'),
#  ('PULMEMBOLUS', 'BP'),
#  ('PULMEMBOLUS', 'EXPCO2'),
#  ('PULMEMBOLUS', 'ERRLOWOUTPUT'),
#  ('PULMEMBOLUS', 'PRESS'),
#  ('PULMEMBOLUS', 'HRBP'),
#  ('PULMEMBOLUS', 'MINVOL'),
#  ('PULMEMBOLUS', 'HISTORY'),
#  ('PULMEMBOLUS', 'HRSAT'),
#  ('PULMEMBOLUS', 'PCWP'),
#  ('PAP', 'KINKEDTUBE'),
#  ('PAP', 'INTUBATION'),
#  ('PAP', 'MINVOLSET'),
#  ('PAP', 'VENTMACH'),
#  ('PAP', 'DISCONNECT'),
#  ('PAP', 'VENTTUBE'),
#  ('PAP', 'VENTLUNG'),
#  ('PAP', 'VENTALV'),
#  ('PAP', 'FIO2'),
#  ('PAP', 'PVSAT'),
#  ('PAP', 'SAO2'),
#  ('PAP', 'INSUFFANESTH'),
#  ('PAP', 'ARTCO2'),
#  ('PAP', 'ANAPHYLAXIS'),
#  ('PAP', 'TPR'),
#  ('PAP', 'CATECHOL'),
#  ('PAP', 'HR'),
#  ('PAP', 'ERRCAUTER'),
#  ('PAP', 'HREKG'),
#  ('PAP', 'HYPOVOLEMIA'),
#  ('PAP', 'LVFAILURE'),
#  ('PAP', 'LVEDVOLUME'),
#  ('PAP', 'CVP'),
#  ('PAP', 'STROKEVOLUME'),
#  ('PAP', 'CO'),
#  ('PAP', 'BP'),
#  ('PAP', 'EXPCO2'),
#  ('PAP', 'ERRLOWOUTPUT'),
#  ('PAP', 'PRESS'),
#  ('PAP', 'HRBP'),
#  ('PAP', 'MINVOL'),
#  ('PAP', 'HISTORY'),
#  ('PAP', 'HRSAT'),
#  ('PAP', 'PCWP'),
#  ('KINKEDTUBE', 'INTUBATION'),
#  ('KINKEDTUBE', 'MINVOLSET'),
#  ('KINKEDTUBE', 'VENTMACH'),
#  ('KINKEDTUBE', 'DISCONNECT'),
#  ('KINKEDTUBE', 'VENTTUBE'),
#  ('KINKEDTUBE', 'SHUNT'),
#  ('KINKEDTUBE', 'FIO2'),
#  ('KINKEDTUBE', 'INSUFFANESTH'),
#  ('KINKEDTUBE', 'ANAPHYLAXIS'),
#  ('KINKEDTUBE', 'TPR'),
#  ('KINKEDTUBE', 'CATECHOL'),
#  ('KINKEDTUBE', 'HR'),
#  ('KINKEDTUBE', 'ERRCAUTER'),
#  ('KINKEDTUBE', 'HREKG'),
#  ('KINKEDTUBE', 'HYPOVOLEMIA'),
#  ('KINKEDTUBE', 'LVFAILURE'),
#  ('KINKEDTUBE', 'LVEDVOLUME'),
#  ('KINKEDTUBE', 'CVP'),
#  ('KINKEDTUBE', 'STROKEVOLUME'),
#  ('KINKEDTUBE', 'CO'),
#  ('KINKEDTUBE', 'BP'),
#  ('KINKEDTUBE', 'ERRLOWOUTPUT'),
#  ('KINKEDTUBE', 'HRBP'),
#  ('KINKEDTUBE', 'HISTORY'),
#  ('KINKEDTUBE', 'HRSAT'),
#  ('KINKEDTUBE', 'PCWP'),
#  ('INTUBATION', 'MINVOLSET'),
#  ('INTUBATION', 'VENTMACH'),
#  ('INTUBATION', 'DISCONNECT'),
#  ('INTUBATION', 'VENTTUBE'),
#  ('INTUBATION', 'FIO2'),
#  ('INTUBATION', 'INSUFFANESTH'),
#  ('INTUBATION', 'ANAPHYLAXIS'),
#  ('INTUBATION', 'TPR'),
#  ('INTUBATION', 'ERRCAUTER'),
#  ('INTUBATION', 'HYPOVOLEMIA'),
#  ('INTUBATION', 'LVFAILURE'),
#  ('INTUBATION', 'LVEDVOLUME'),
#  ('INTUBATION', 'CVP'),
#  ('INTUBATION', 'STROKEVOLUME'),
#  ('INTUBATION', 'CO'),
#  ('INTUBATION', 'BP'),
#  ('INTUBATION', 'ERRLOWOUTPUT'),
#  ('INTUBATION', 'HRBP'),
#  ('INTUBATION', 'HISTORY'),
#  ('INTUBATION', 'PCWP'),
#  ('MINVOLSET', 'DISCONNECT'),
#  ('MINVOLSET', 'SHUNT'),
#  ('MINVOLSET', 'FIO2'),
#  ('MINVOLSET', 'INSUFFANESTH'),
#  ('MINVOLSET', 'ANAPHYLAXIS'),
#  ('MINVOLSET', 'TPR'),
#  ('MINVOLSET', 'ERRCAUTER'),
#  ('MINVOLSET', 'HYPOVOLEMIA'),
#  ('MINVOLSET', 'LVFAILURE'),
#  ('MINVOLSET', 'LVEDVOLUME'),
#  ('MINVOLSET', 'CVP'),
#  ('MINVOLSET', 'STROKEVOLUME'),
#  ('MINVOLSET', 'ERRLOWOUTPUT'),
#  ('MINVOLSET', 'HISTORY'),
#  ('MINVOLSET', 'PCWP'),
#  ('VENTMACH', 'DISCONNECT'),
#  ('VENTMACH', 'SHUNT'),
#  ('VENTMACH', 'FIO2'),
#  ('VENTMACH', 'INSUFFANESTH'),
#  ('VENTMACH', 'ANAPHYLAXIS'),
#  ('VENTMACH', 'TPR'),
#  ('VENTMACH', 'ERRCAUTER'),
#  ('VENTMACH', 'HYPOVOLEMIA'),
#  ('VENTMACH', 'LVFAILURE'),
#  ('VENTMACH', 'LVEDVOLUME'),
#  ('VENTMACH', 'CVP'),
#  ('VENTMACH', 'STROKEVOLUME'),
#  ('VENTMACH', 'ERRLOWOUTPUT'),
#  ('VENTMACH', 'HISTORY'),
#  ('VENTMACH', 'PCWP'),
#  ('DISCONNECT', 'SHUNT'),
#  ('DISCONNECT', 'FIO2'),
#  ('DISCONNECT', 'INSUFFANESTH'),
#  ('DISCONNECT', 'ANAPHYLAXIS'),
#  ('DISCONNECT', 'ERRCAUTER'),
#  ('DISCONNECT', 'HYPOVOLEMIA'),
#  ('DISCONNECT', 'LVEDVOLUME'),
#  ('DISCONNECT', 'CVP'),
#  ('DISCONNECT', 'STROKEVOLUME'),
#  ('DISCONNECT', 'ERRLOWOUTPUT'),
#  ('DISCONNECT', 'PCWP'),
#  ('VENTTUBE', 'SHUNT'),
#  ('VENTTUBE', 'FIO2'),
#  ('VENTTUBE', 'INSUFFANESTH'),
#  ('VENTTUBE', 'ANAPHYLAXIS'),
#  ('VENTTUBE', 'ERRCAUTER'),
#  ('VENTTUBE', 'HYPOVOLEMIA'),
#  ('VENTTUBE', 'LVEDVOLUME'),
#  ('VENTTUBE', 'CVP'),
#  ('VENTTUBE', 'STROKEVOLUME'),
#  ('VENTTUBE', 'ERRLOWOUTPUT'),
#  ('VENTTUBE', 'HISTORY'),
#  ('VENTTUBE', 'PCWP'),
#  ('VENTLUNG', 'FIO2'),
#  ('VENTLUNG', 'INSUFFANESTH'),
#  ('VENTLUNG', 'ANAPHYLAXIS'),
#  ('VENTLUNG', 'TPR'),
#  ('VENTLUNG', 'ERRCAUTER'),
#  ('VENTLUNG', 'HYPOVOLEMIA'),
#  ('VENTLUNG', 'LVFAILURE'),
#  ('VENTLUNG', 'LVEDVOLUME'),
#  ('VENTLUNG', 'CVP'),
#  ('VENTLUNG', 'ERRLOWOUTPUT'),
#  ('VENTLUNG', 'HISTORY'),
#  ('VENTLUNG', 'PCWP'),
#  ('SHUNT', 'FIO2'),
#  ('SHUNT', 'INSUFFANESTH'),
#  ('SHUNT', 'ANAPHYLAXIS'),
#  ('SHUNT', 'TPR'),
#  ('SHUNT', 'CATECHOL'),
#  ('SHUNT', 'HYPOVOLEMIA'),
#  ('SHUNT', 'LVFAILURE'),
#  ('SHUNT', 'LVEDVOLUME'),
#  ('SHUNT', 'CVP'),
#  ('SHUNT', 'STROKEVOLUME'),
#  ('SHUNT', 'CO'),
#  ('SHUNT', 'BP'),
#  ('SHUNT', 'ERRLOWOUTPUT'),
#  ('SHUNT', 'HRBP'),
#  ('SHUNT', 'HISTORY'),
#  ('SHUNT', 'HRSAT'),
#  ('SHUNT', 'PCWP'),
#  ('VENTALV', 'FIO2'),
#  ('VENTALV', 'INSUFFANESTH'),
#  ('VENTALV', 'ANAPHYLAXIS'),
#  ('VENTALV', 'TPR'),
#  ('VENTALV', 'ERRCAUTER'),
#  ('VENTALV', 'HYPOVOLEMIA'),
#  ('VENTALV', 'LVEDVOLUME'),
#  ('VENTALV', 'CVP'),
#  ('VENTALV', 'ERRLOWOUTPUT'),
#  ('VENTALV', 'PCWP'),
#  ('FIO2', 'INSUFFANESTH'),
#  ('FIO2', 'ARTCO2'),
#  ('FIO2', 'ANAPHYLAXIS'),
#  ('FIO2', 'TPR'),
#  ('FIO2', 'CATECHOL'),
#  ('FIO2', 'HR'),
#  ('FIO2', 'ERRCAUTER'),
#  ('FIO2', 'HREKG'),
#  ('FIO2', 'HYPOVOLEMIA'),
#  ('FIO2', 'LVFAILURE'),
#  ('FIO2', 'LVEDVOLUME'),
#  ('FIO2', 'CVP'),
#  ('FIO2', 'STROKEVOLUME'),
#  ('FIO2', 'CO'),
#  ('FIO2', 'BP'),
#  ('FIO2', 'EXPCO2'),
#  ('FIO2', 'ERRLOWOUTPUT'),
#  ('FIO2', 'PRESS'),
#  ('FIO2', 'HRBP'),
#  ('FIO2', 'MINVOL'),
#  ('FIO2', 'HISTORY'),
#  ('FIO2', 'HRSAT'),
#  ('FIO2', 'PCWP'),
#  ('PVSAT', 'INSUFFANESTH'),
#  ('PVSAT', 'ANAPHYLAXIS'),
#  ('PVSAT', 'TPR'),
#  ('PVSAT', 'ERRCAUTER'),
#  ('PVSAT', 'HYPOVOLEMIA'),
#  ('PVSAT', 'LVFAILURE'),
#  ('PVSAT', 'LVEDVOLUME'),
#  ('PVSAT', 'CVP'),
#  ('PVSAT', 'STROKEVOLUME'),
#  ('PVSAT', 'ERRLOWOUTPUT'),
#  ('PVSAT', 'HISTORY'),
#  ('PVSAT', 'PCWP'),
#  ('SAO2', 'INSUFFANESTH'),
#  ('SAO2', 'ANAPHYLAXIS'),
#  ('SAO2', 'TPR'),
#  ('SAO2', 'ERRCAUTER'),
#  ('SAO2', 'HYPOVOLEMIA'),
#  ('SAO2', 'LVFAILURE'),
#  ('SAO2', 'LVEDVOLUME'),
#  ('SAO2', 'CVP'),
#  ('SAO2', 'STROKEVOLUME'),
#  ('SAO2', 'ERRLOWOUTPUT'),
#  ('SAO2', 'HISTORY'),
#  ('SAO2', 'PCWP'),
#  ('INSUFFANESTH', 'ARTCO2'),
#  ('INSUFFANESTH', 'ANAPHYLAXIS'),
#  ('INSUFFANESTH', 'TPR'),
#  ('INSUFFANESTH', 'CATECHOL'),
#  ('INSUFFANESTH', 'HR'),
#  ('INSUFFANESTH', 'ERRCAUTER'),
#  ('INSUFFANESTH', 'HREKG'),
#  ('INSUFFANESTH', 'HYPOVOLEMIA'),
#  ('INSUFFANESTH', 'LVFAILURE'),
#  ('INSUFFANESTH', 'LVEDVOLUME'),
#  ('INSUFFANESTH', 'CVP'),
#  ('INSUFFANESTH', 'STROKEVOLUME'),
#  ('INSUFFANESTH', 'CO'),
#  ('INSUFFANESTH', 'BP'),
#  ('INSUFFANESTH', 'EXPCO2'),
#  ('INSUFFANESTH', 'ERRLOWOUTPUT'),
#  ('INSUFFANESTH', 'PRESS'),
#  ('INSUFFANESTH', 'HRBP'),
#  ('INSUFFANESTH', 'MINVOL'),
#  ('INSUFFANESTH', 'HISTORY'),
#  ('INSUFFANESTH', 'HRSAT'),
#  ('INSUFFANESTH', 'PCWP'),
#  ('ARTCO2', 'ANAPHYLAXIS'),
#  ('ARTCO2', 'TPR'),
#  ('ARTCO2', 'ERRCAUTER'),
#  ('ARTCO2', 'HYPOVOLEMIA'),
#  ('ARTCO2', 'LVFAILURE'),
#  ('ARTCO2', 'LVEDVOLUME'),
#  ('ARTCO2', 'CVP'),
#  ('ARTCO2', 'ERRLOWOUTPUT'),
#  ('ARTCO2', 'PCWP'),
#  ('ANAPHYLAXIS', 'ERRCAUTER'),
#  ('ANAPHYLAXIS', 'HYPOVOLEMIA'),
#  ('ANAPHYLAXIS', 'LVFAILURE'),
#  ('ANAPHYLAXIS', 'LVEDVOLUME'),
#  ('ANAPHYLAXIS', 'CVP'),
#  ('ANAPHYLAXIS', 'STROKEVOLUME'),
#  ('ANAPHYLAXIS', 'CO'),
#  ('ANAPHYLAXIS', 'EXPCO2'),
#  ('ANAPHYLAXIS', 'ERRLOWOUTPUT'),
#  ('ANAPHYLAXIS', 'PRESS'),
#  ('ANAPHYLAXIS', 'MINVOL'),
#  ('ANAPHYLAXIS', 'HISTORY'),
#  ('ANAPHYLAXIS', 'HRSAT'),
#  ('ANAPHYLAXIS', 'PCWP'),
#  ('TPR', 'ERRCAUTER'),
#  ('TPR', 'HYPOVOLEMIA'),
#  ('TPR', 'LVFAILURE'),
#  ('TPR', 'LVEDVOLUME'),
#  ('TPR', 'CVP'),
#  ('TPR', 'STROKEVOLUME'),
#  ('TPR', 'EXPCO2'),
#  ('TPR', 'ERRLOWOUTPUT'),
#  ('TPR', 'PRESS'),
#  ('TPR', 'MINVOL'),
#  ('TPR', 'HISTORY'),
#  ('TPR', 'PCWP'),
#  ('CATECHOL', 'ERRCAUTER'),
#  ('CATECHOL', 'HYPOVOLEMIA'),
#  ('CATECHOL', 'LVFAILURE'),
#  ('CATECHOL', 'LVEDVOLUME'),
#  ('CATECHOL', 'CVP'),
#  ('CATECHOL', 'STROKEVOLUME'),
#  ('CATECHOL', 'ERRLOWOUTPUT'),
#  ('CATECHOL', 'HISTORY'),
#  ('CATECHOL', 'PCWP'),
#  ('HR', 'ERRCAUTER'),
#  ('HR', 'HYPOVOLEMIA'),
#  ('HR', 'LVFAILURE'),
#  ('HR', 'LVEDVOLUME'),
#  ('HR', 'CVP'),
#  ('HR', 'STROKEVOLUME'),
#  ('HR', 'ERRLOWOUTPUT'),
#  ('HR', 'HISTORY'),
#  ('HR', 'PCWP'),
#  ('ERRCAUTER', 'HYPOVOLEMIA'),
#  ('ERRCAUTER', 'LVFAILURE'),
#  ('ERRCAUTER', 'LVEDVOLUME'),
#  ('ERRCAUTER', 'CVP'),
#  ('ERRCAUTER', 'STROKEVOLUME'),
#  ('ERRCAUTER', 'CO'),
#  ('ERRCAUTER', 'BP'),
#  ('ERRCAUTER', 'EXPCO2'),
#  ('ERRCAUTER', 'ERRLOWOUTPUT'),
#  ('ERRCAUTER', 'PRESS'),
#  ('ERRCAUTER', 'HRBP'),
#  ('ERRCAUTER', 'MINVOL'),
#  ('ERRCAUTER', 'HISTORY'),
#  ('ERRCAUTER', 'PCWP'),
#  ('HREKG', 'HYPOVOLEMIA'),
#  ('HREKG', 'LVFAILURE'),
#  ('HREKG', 'LVEDVOLUME'),
#  ('HREKG', 'CVP'),
#  ('HREKG', 'STROKEVOLUME'),
#  ('HREKG', 'ERRLOWOUTPUT'),
#  ('HREKG', 'HISTORY'),
#  ('HREKG', 'PCWP'),
#  ('HYPOVOLEMIA', 'LVFAILURE'),
#  ('HYPOVOLEMIA', 'EXPCO2'),
#  ('HYPOVOLEMIA', 'ERRLOWOUTPUT'),
#  ('HYPOVOLEMIA', 'PRESS'),
#  ('HYPOVOLEMIA', 'HRBP'),
#  ('HYPOVOLEMIA', 'MINVOL'),
#  ('HYPOVOLEMIA', 'HISTORY'),
#  ('HYPOVOLEMIA', 'HRSAT'),
#  ('LVFAILURE', 'EXPCO2'),
#  ('LVFAILURE', 'ERRLOWOUTPUT'),
#  ('LVFAILURE', 'PRESS'),
#  ('LVFAILURE', 'HRBP'),
#  ('LVFAILURE', 'MINVOL'),
#  ('LVFAILURE', 'HRSAT'),
#  ('LVEDVOLUME', 'EXPCO2'),
#  ('LVEDVOLUME', 'ERRLOWOUTPUT'),
#  ('LVEDVOLUME', 'PRESS'),
#  ('LVEDVOLUME', 'HRBP'),
#  ('LVEDVOLUME', 'MINVOL'),
#  ('LVEDVOLUME', 'HRSAT'),
#  ('CVP', 'EXPCO2'),
#  ('CVP', 'ERRLOWOUTPUT'),
#  ('CVP', 'PRESS'),
#  ('CVP', 'HRBP'),
#  ('CVP', 'MINVOL'),
#  ('CVP', 'HRSAT'),
#  ('STROKEVOLUME', 'EXPCO2'),
#  ('STROKEVOLUME', 'ERRLOWOUTPUT'),
#  ('STROKEVOLUME', 'PRESS'),
#  ('STROKEVOLUME', 'HRBP'),
#  ('STROKEVOLUME', 'MINVOL'),
#  ('STROKEVOLUME', 'HRSAT'),
#  ('CO', 'ERRLOWOUTPUT'),
#  ('CO', 'PRESS'),
#  ('BP', 'ERRLOWOUTPUT'),
#  ('BP', 'PRESS'),
#  ('EXPCO2', 'ERRLOWOUTPUT'),
#  ('EXPCO2', 'HISTORY'),
#  ('EXPCO2', 'PCWP'),
#  ('ERRLOWOUTPUT', 'PRESS'),
#  ('ERRLOWOUTPUT', 'MINVOL'),
#  ('ERRLOWOUTPUT', 'HISTORY'),
#  ('ERRLOWOUTPUT', 'HRSAT'),
#  ('ERRLOWOUTPUT', 'PCWP'),
#  ('PRESS', 'HISTORY'),
#  ('PRESS', 'PCWP'),
#  ('HRBP', 'HISTORY'),
#  ('HRBP', 'PCWP'),
#  ('MINVOL', 'HISTORY'),
#  ('MINVOL', 'PCWP'),
#  ('HISTORY', 'HRSAT'),
#  ('HRSAT', 'PCWP'),
#  ('PULMEMBOLUS', 'SAO2'),
#  ('PAP', 'SHUNT'),
#  ('KINKEDTUBE', 'PVSAT'),
#  ('KINKEDTUBE', 'SAO2'),
#  ('KINKEDTUBE', 'ARTCO2'),
#  ('KINKEDTUBE', 'EXPCO2'),
#  ('INTUBATION', 'PVSAT'),
#  ('INTUBATION', 'ARTCO2'),
#  ('INTUBATION', 'CATECHOL'),
#  ('INTUBATION', 'HR'),
#  ('INTUBATION', 'HREKG'),
#  ('INTUBATION', 'HRSAT'),
#  ('MINVOLSET', 'VENTLUNG'),
#  ('MINVOLSET', 'VENTALV'),
#  ('MINVOLSET', 'PVSAT'),
#  ('MINVOLSET', 'SAO2'),
#  ('MINVOLSET', 'ARTCO2'),
#  ('MINVOLSET', 'CATECHOL'),
#  ('MINVOLSET', 'HR'),
#  ('MINVOLSET', 'HREKG'),
#  ('MINVOLSET', 'CO'),
#  ('MINVOLSET', 'BP'),
#  ('MINVOLSET', 'EXPCO2'),
#  ('MINVOLSET', 'PRESS'),
#  ('MINVOLSET', 'HRBP'),
#  ('MINVOLSET', 'MINVOL'),
#  ('MINVOLSET', 'HRSAT'),
#  ('VENTMACH', 'VENTLUNG'),
#  ('VENTMACH', 'VENTALV'),
#  ('VENTMACH', 'PVSAT'),
#  ('VENTMACH', 'SAO2'),
#  ('VENTMACH', 'ARTCO2'),
#  ('VENTMACH', 'CATECHOL'),
#  ('VENTMACH', 'HR'),
#  ('VENTMACH', 'HREKG'),
#  ('VENTMACH', 'CO'),
#  ('VENTMACH', 'BP'),
#  ('VENTMACH', 'EXPCO2'),
#  ('VENTMACH', 'PRESS'),
#  ('VENTMACH', 'HRBP'),
#  ('VENTMACH', 'MINVOL'),
#  ('VENTMACH', 'HRSAT'),
#  ('DISCONNECT', 'VENTLUNG'),
#  ('DISCONNECT', 'VENTALV'),
#  ('DISCONNECT', 'PVSAT'),
#  ('DISCONNECT', 'SAO2'),
#  ('DISCONNECT', 'ARTCO2'),
#  ('DISCONNECT', 'TPR'),
#  ('DISCONNECT', 'CATECHOL'),
#  ('DISCONNECT', 'HR'),
#  ('DISCONNECT', 'HREKG'),
#  ('DISCONNECT', 'LVFAILURE'),
#  ('DISCONNECT', 'CO'),
#  ('DISCONNECT', 'BP'),
#  ('DISCONNECT', 'EXPCO2'),
#  ('DISCONNECT', 'PRESS'),
#  ('DISCONNECT', 'HRBP'),
#  ('DISCONNECT', 'MINVOL'),
#  ('DISCONNECT', 'HISTORY'),
#  ('DISCONNECT', 'HRSAT'),
#  ('VENTTUBE', 'PVSAT'),
#  ('VENTTUBE', 'SAO2'),
#  ('VENTTUBE', 'ARTCO2'),
#  ('VENTTUBE', 'TPR'),
#  ('VENTTUBE', 'CATECHOL'),
#  ('VENTTUBE', 'HR'),
#  ('VENTTUBE', 'HREKG'),
#  ('VENTTUBE', 'LVFAILURE'),
#  ('VENTTUBE', 'CO'),
#  ('VENTTUBE', 'BP'),
#  ('VENTTUBE', 'HRBP'),
#  ('VENTTUBE', 'HRSAT'),
#  ('VENTLUNG', 'SHUNT'),
#  ('VENTLUNG', 'PVSAT'),
#  ('VENTLUNG', 'SAO2'),
#  ('VENTLUNG', 'ARTCO2'),
#  ('VENTLUNG', 'CATECHOL'),
#  ('VENTLUNG', 'HR'),
#  ('VENTLUNG', 'HREKG'),
#  ('VENTLUNG', 'STROKEVOLUME'),
#  ('VENTLUNG', 'CO'),
#  ('VENTLUNG', 'BP'),
#  ('VENTLUNG', 'HRBP'),
#  ('VENTLUNG', 'HRSAT'),
#  ('SHUNT', 'VENTALV'),
#  ('SHUNT', 'PVSAT'),
#  ('SHUNT', 'ARTCO2'),
#  ('SHUNT', 'HR'),
#  ('SHUNT', 'ERRCAUTER'),
#  ('SHUNT', 'HREKG'),
#  ('SHUNT', 'EXPCO2'),
#  ('SHUNT', 'MINVOL'),
#  ('VENTALV', 'CATECHOL'),
#  ('VENTALV', 'HR'),
#  ('VENTALV', 'HREKG'),
#  ('VENTALV', 'LVFAILURE'),
#  ('VENTALV', 'STROKEVOLUME'),
#  ('VENTALV', 'CO'),
#  ('VENTALV', 'BP'),
#  ('VENTALV', 'HRBP'),
#  ('VENTALV', 'HISTORY'),
#  ('VENTALV', 'HRSAT'),
#  ('FIO2', 'SAO2'),
#  ('PVSAT', 'ARTCO2'),
#  ('PVSAT', 'CATECHOL'),
#  ('PVSAT', 'HR'),
#  ('PVSAT', 'HREKG'),
#  ('PVSAT', 'CO'),
#  ('PVSAT', 'BP'),
#  ('PVSAT', 'EXPCO2'),
#  ('PVSAT', 'PRESS'),
#  ('PVSAT', 'HRBP'),
#  ('PVSAT', 'MINVOL'),
#  ('PVSAT', 'HRSAT'),
#  ('SAO2', 'ARTCO2'),
#  ('SAO2', 'HR'),
#  ('SAO2', 'HREKG'),
#  ('SAO2', 'CO'),
#  ('SAO2', 'BP'),
#  ('SAO2', 'EXPCO2'),
#  ('SAO2', 'PRESS'),
#  ('SAO2', 'HRBP'),
#  ('SAO2', 'HRSAT'),
#  ('ARTCO2', 'HR'),
#  ('ARTCO2', 'HREKG'),
#  ('ARTCO2', 'STROKEVOLUME'),
#  ('ARTCO2', 'CO'),
#  ('ARTCO2', 'BP'),
#  ('ARTCO2', 'PRESS'),
#  ('ARTCO2', 'HRBP'),
#  ('ARTCO2', 'MINVOL'),
#  ('ARTCO2', 'HISTORY'),
#  ('ARTCO2', 'HRSAT'),
#  ('ANAPHYLAXIS', 'CATECHOL'),
#  ('ANAPHYLAXIS', 'HR'),
#  ('ANAPHYLAXIS', 'HREKG'),
#  ('ANAPHYLAXIS', 'BP'),
#  ('ANAPHYLAXIS', 'HRBP'),
#  ('TPR', 'HR'),
#  ('TPR', 'HREKG'),
#  ('TPR', 'CO'),
#  ('TPR', 'HRBP'),
#  ('TPR', 'HRSAT'),
#  ('CATECHOL', 'HREKG'),
#  ('CATECHOL', 'CO'),
#  ('CATECHOL', 'EXPCO2'),
#  ('CATECHOL', 'PRESS'),
#  ('CATECHOL', 'HRBP'),
#  ('HR', 'EXPCO2'),
#  ('HR', 'PRESS'),
#  ('HR', 'MINVOL'),
#  ('HREKG', 'CO'),
#  ('HREKG', 'BP'),
#  ('HREKG', 'EXPCO2'),
#  ('HREKG', 'PRESS'),
#  ('HREKG', 'HRBP'),
#  ('HREKG', 'MINVOL'),
#  ('HYPOVOLEMIA', 'CVP'),
#  ('HYPOVOLEMIA', 'CO'),
#  ('HYPOVOLEMIA', 'BP'),
#  ('HYPOVOLEMIA', 'PCWP'),
#  ('LVFAILURE', 'CVP'),
#  ('LVFAILURE', 'CO'),
#  ('LVFAILURE', 'BP'),
#  ('LVFAILURE', 'PCWP'),
#  ('LVEDVOLUME', 'CO'),
#  ('LVEDVOLUME', 'BP'),
#  ('LVEDVOLUME', 'HISTORY'),
#  ('CVP', 'STROKEVOLUME'),
#  ('CVP', 'CO'),
#  ('CVP', 'BP'),
#  ('CVP', 'HISTORY'),
#  ('STROKEVOLUME', 'HISTORY'),
#  ('CO', 'EXPCO2'),
#  ('CO', 'HRBP'),
#  ('CO', 'MINVOL'),
#  ('CO', 'HISTORY'),
#  ('CO', 'HRSAT'),
#  ('CO', 'PCWP'),
#  ('BP', 'EXPCO2'),
#  ('BP', 'HRBP'),
#  ('BP', 'MINVOL'),
#  ('BP', 'HRSAT'),
#  ('BP', 'PCWP'),
#  ('EXPCO2', 'HRBP'),
#  ('EXPCO2', 'HRSAT'),
#  ('PRESS', 'HRBP'),
#  ('PRESS', 'HRSAT'),
#  ('HRBP', 'MINVOL'),
#  ('HRBP', 'HRSAT'),
#  ('MINVOL', 'HRSAT'),
#  ('HISTORY', 'PCWP')]

# %%
print(new_g)
nx.draw(new_g, with_labels=True)
# Out:
# Graph with 37 nodes and 50 edges

# %%
nx.draw(g_0, with_labels=True)

# %% [markdown]
# ### small network

# %%
# %%time
m = Gobnilp()
m.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat')
# Out:
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -105226.51191678003
# **********
# ANAPHYLAXIS<- -578.587070487134
# ARTCO2<-VENTALV -1816.018107669981
# VENTALV<-INTUBATION,VENTLUNG -1785.1568955858384
# BP<-CO,TPR -4927.804606748883
# CO<-HR,STROKEVOLUME -2678.9117199075117
# TPR<-ANAPHYLAXIS -10794.813215814676
# CATECHOL<-ARTCO2,TPR -1521.301873422577
# STROKEVOLUME<-HYPOVOLEMIA,LVFAILURE -4437.288938131547
# HR<-CATECHOL -3744.599767304855
# CVP<-LVEDVOLUME -3006.615302132195
# LVEDVOLUME<-HYPOVOLEMIA,LVFAILURE -3613.5057310384145
# DISCONNECT<- -3295.031743080661
# ERRCAUTER<- -3222.5768222310726
# ERRLOWOUTPUT<- -1972.2788189759885
# EXPCO2<-ARTCO2,VENTLUNG -1772.659127224848
# VENTLUNG<-INTUBATION,KINKEDTUBE,VENTTUBE -3618.0085247885727
# FIO2<- -1888.628670533668
# HISTORY<-LVFAILURE -637.4903136947833
# LVFAILURE<- -2010.5432102550985
# HRBP<-ERRLOWOUTPUT,HR -1331.6218853034952
# HREKG<-ERRCAUTER,HR -1507.9736736634222
# HRSAT<-ERRCAUTER,HR -1452.0851029207115
# HYPOVOLEMIA<- -4990.780506105162
# INSUFFANESTH<- -3303.7325344726705
# INTUBATION<- -3428.3602719444025
# KINKEDTUBE<- -1558.2831144287338
# MINVOL<-INTUBATION,VENTLUNG -2061.90574142267
# MINVOLSET<-VENTMACH -946.5564916227886
# VENTMACH<- -6169.083417643327
# PAP<- -4194.791057672555
# PCWP<-LVEDVOLUME -2233.6875379606645
# PRESS<-INTUBATION,KINKEDTUBE,VENTTUBE -8478.131859909474
# VENTTUBE<-DISCONNECT,VENTMACH -1814.1386675404356
# PULMEMBOLUS<-PAP -396.61118678582716
# PVSAT<-FIO2,VENTALV -846.3768118197477
# SAO2<-PVSAT,SHUNT -1137.5909747223923
# SHUNT<-INTUBATION,PULMEMBOLUS -2052.9806218132435
# **********
# bnlearn modelstring =
# [ANAPHYLAXIS][ARTCO2|VENTALV][VENTALV|INTUBATION:VENTLUNG][BP|CO:TPR][CO|STROKEVOLUME:HR][TPR|ANAPHYLAXIS][CATECHOL|ARTCO2:TPR][STROKEVOLUME|LVFAILURE:HYPOVOLEMIA][HR|CATECHOL][CVP|LVEDVOLUME][LVEDVOLUME|LVFAILURE:HYPOVOLEMIA][DISCONNECT][ERRCAUTER][ERRLOWOUTPUT][EXPCO2|VENTLUNG:ARTCO2][VENTLUNG|INTUBATION:KINKEDTUBE:VENTTUBE][FIO2][HISTORY|LVFAILURE][LVFAILURE][HRBP|HR:ERRLOWOUTPUT][HREKG|HR:ERRCAUTER][HRSAT|HR:ERRCAUTER][HYPOVOLEMIA][INSUFFANESTH][INTUBATION][KINKEDTUBE][MINVOL|INTUBATION:VENTLUNG][MINVOLSET|VENTMACH][VENTMACH][PAP][PCWP|LVEDVOLUME][PRESS|INTUBATION:KINKEDTUBE:VENTTUBE][VENTTUBE|VENTMACH:DISCONNECT][PULMEMBOLUS|PAP][PVSAT|FIO2:VENTALV][SAO2|SHUNT:PVSAT][SHUNT|INTUBATION:PULMEMBOLUS]
# **********
# CPDAG:
# Vertices: ANAPHYLAXIS,ARTCO2,VENTALV,BP,CO,TPR,CATECHOL,STROKEVOLUME,HR,CVP,LVEDVOLUME,DISCONNECT,ERRCAUTER,ERRLOWOUTPUT,EXPCO2,VENTLUNG,FIO2,HISTORY,LVFAILURE,HRBP,HREKG,HRSAT,HYPOVOLEMIA,INSUFFANESTH,INTUBATION,KINKEDTUBE,MINVOL,MINVOLSET,VENTMACH,PAP,PCWP,PRESS,VENTTUBE,PULMEMBOLUS,PVSAT,SAO2,SHUNT
# ANAPHYLAXIS-TPR
# ARTCO2->CATECHOL
# ARTCO2->EXPCO2
# VENTALV->ARTCO2
# VENTALV->PVSAT
# CO->BP
# TPR->BP
# TPR->CATECHOL
# CATECHOL->HR
# STROKEVOLUME->CO
# HR->CO
# HR->HRBP
# HR->HREKG
# HR->HRSAT
# LVEDVOLUME->CVP
# LVEDVOLUME->PCWP
# DISCONNECT->VENTTUBE
# ERRCAUTER->HREKG
# ERRCAUTER->HRSAT
# ERRLOWOUTPUT->HRBP
# VENTLUNG->EXPCO2
# VENTLUNG->MINVOL
# VENTLUNG->VENTALV
# FIO2->PVSAT
# LVFAILURE-HISTORY
# LVFAILURE->LVEDVOLUME
# LVFAILURE->STROKEVOLUME
# HYPOVOLEMIA->LVEDVOLUME
# HYPOVOLEMIA->STROKEVOLUME
# INTUBATION-MINVOL
# INTUBATION->PRESS
# INTUBATION->SHUNT
# INTUBATION-VENTALV
# INTUBATION->VENTLUNG
# KINKEDTUBE->PRESS
# KINKEDTUBE->VENTLUNG
# VENTMACH-MINVOLSET
# VENTMACH->VENTTUBE
# PAP-PULMEMBOLUS
# VENTTUBE->PRESS
# VENTTUBE->VENTLUNG
# PULMEMBOLUS->SHUNT
# PVSAT->SAO2
# SHUNT->SAO2
# CPU times: total: 8min 17s
# Wall time: 2min 36s

# %%
# %%time
k = Gobnilp()
for i,j in ind:
    k.add_forbidden_adjacency((i,j))
k.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat')
# Out:
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -105226.51191678003
# **********
# ANAPHYLAXIS<- -578.587070487134
# ARTCO2<-VENTALV -1816.018107669981
# VENTALV<-INTUBATION,VENTLUNG -1785.1568955858384
# BP<-CO,TPR -4927.804606748883
# CO<-HR,STROKEVOLUME -2678.9117199075117
# TPR<-ANAPHYLAXIS -10794.813215814676
# CATECHOL<-ARTCO2,TPR -1521.301873422577
# STROKEVOLUME<-HYPOVOLEMIA,LVFAILURE -4437.288938131547
# HR<-CATECHOL -3744.599767304855
# CVP<-LVEDVOLUME -3006.615302132195
# LVEDVOLUME<-HYPOVOLEMIA,LVFAILURE -3613.5057310384145
# DISCONNECT<- -3295.031743080661
# ERRCAUTER<- -3222.5768222310726
# ERRLOWOUTPUT<- -1972.2788189759885
# EXPCO2<-ARTCO2,VENTLUNG -1772.659127224848
# VENTLUNG<-INTUBATION,KINKEDTUBE,VENTTUBE -3618.0085247885727
# FIO2<- -1888.628670533668
# HISTORY<- -2091.7769199432078
# HRBP<-ERRLOWOUTPUT,HR -1331.6218853034952
# HREKG<-ERRCAUTER,HR -1507.9736736634222
# HRSAT<-ERRCAUTER,HR -1452.0851029207115
# HYPOVOLEMIA<- -4990.780506105162
# INSUFFANESTH<- -3303.7325344726705
# INTUBATION<- -3428.3602719444025
# KINKEDTUBE<- -1558.2831144287338
# LVFAILURE<-HISTORY -556.256604006674
# MINVOL<-INTUBATION,VENTLUNG -2061.90574142267
# MINVOLSET<-VENTMACH -946.5564916227886
# VENTMACH<- -6169.083417643327
# PAP<-PULMEMBOLUS -4008.2548091456993
# PULMEMBOLUS<- -583.1474353126832
# PCWP<-LVEDVOLUME -2233.6875379606645
# PRESS<-INTUBATION,KINKEDTUBE,VENTTUBE -8478.131859909474
# VENTTUBE<-DISCONNECT,VENTMACH -1814.1386675404356
# PVSAT<-FIO2,VENTALV -846.3768118197477
# SAO2<-PVSAT,SHUNT -1137.5909747223923
# SHUNT<-INTUBATION,PULMEMBOLUS -2052.9806218132435
# **********
# bnlearn modelstring =
# [ANAPHYLAXIS][ARTCO2|VENTALV][VENTALV|INTUBATION:VENTLUNG][BP|CO:TPR][CO|STROKEVOLUME:HR][TPR|ANAPHYLAXIS][CATECHOL|ARTCO2:TPR][STROKEVOLUME|LVFAILURE:HYPOVOLEMIA][HR|CATECHOL][CVP|LVEDVOLUME][LVEDVOLUME|LVFAILURE:HYPOVOLEMIA][DISCONNECT][ERRCAUTER][ERRLOWOUTPUT][EXPCO2|VENTLUNG:ARTCO2][VENTLUNG|INTUBATION:KINKEDTUBE:VENTTUBE][FIO2][HISTORY][HRBP|HR:ERRLOWOUTPUT][HREKG|HR:ERRCAUTER][HRSAT|HR:ERRCAUTER][HYPOVOLEMIA][INSUFFANESTH][INTUBATION][KINKEDTUBE][LVFAILURE|HISTORY][MINVOL|INTUBATION:VENTLUNG][MINVOLSET|VENTMACH][VENTMACH][PAP|PULMEMBOLUS][PULMEMBOLUS][PCWP|LVEDVOLUME][PRESS|INTUBATION:KINKEDTUBE:VENTTUBE][VENTTUBE|VENTMACH:DISCONNECT][PVSAT|FIO2:VENTALV][SAO2|SHUNT:PVSAT][SHUNT|INTUBATION:PULMEMBOLUS]
# **********
# CPDAG:
# Vertices: ANAPHYLAXIS,ARTCO2,VENTALV,BP,CO,TPR,CATECHOL,STROKEVOLUME,HR,CVP,LVEDVOLUME,DISCONNECT,ERRCAUTER,ERRLOWOUTPUT,EXPCO2,VENTLUNG,FIO2,HISTORY,HRBP,HREKG,HRSAT,HYPOVOLEMIA,INSUFFANESTH,INTUBATION,KINKEDTUBE,LVFAILURE,MINVOL,MINVOLSET,VENTMACH,PAP,PULMEMBOLUS,PCWP,PRESS,VENTTUBE,PVSAT,SAO2,SHUNT
# ANAPHYLAXIS-TPR
# ARTCO2->CATECHOL
# ARTCO2->EXPCO2
# VENTALV->ARTCO2
# VENTALV->PVSAT
# CO->BP
# TPR->BP
# TPR->CATECHOL
# CATECHOL->HR
# STROKEVOLUME->CO
# HR->CO
# HR->HRBP
# HR->HREKG
# HR->HRSAT
# LVEDVOLUME->CVP
# LVEDVOLUME->PCWP
# DISCONNECT->VENTTUBE
# ERRCAUTER->HREKG
# ERRCAUTER->HRSAT
# ERRLOWOUTPUT->HRBP
# VENTLUNG->EXPCO2
# VENTLUNG->MINVOL
# VENTLUNG->VENTALV
# FIO2->PVSAT
# HISTORY-LVFAILURE
# HYPOVOLEMIA->LVEDVOLUME
# HYPOVOLEMIA->STROKEVOLUME
# INTUBATION-MINVOL
# INTUBATION->PRESS
# INTUBATION->SHUNT
# INTUBATION-VENTALV
# INTUBATION->VENTLUNG
# KINKEDTUBE->PRESS
# KINKEDTUBE->VENTLUNG
# LVFAILURE->LVEDVOLUME
# LVFAILURE->STROKEVOLUME
# VENTMACH-MINVOLSET
# VENTMACH->VENTTUBE
# PULMEMBOLUS-PAP
# PULMEMBOLUS->SHUNT
# VENTTUBE->PRESS
# VENTTUBE->VENTLUNG
# PVSAT->SAO2
# SHUNT->SAO2
# CPU times: total: 4 s
# Wall time: 2.93 s
