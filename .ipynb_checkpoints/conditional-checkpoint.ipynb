# %%
import pandas as pd
import numpy as np
from pygobnilp.gobnilp import Gobnilp
import pgmpy
import itertools
from pgmpy.estimators.CITests import pearsonr
from pgmpy.estimators.CITests import chi_square
from pgmpy.estimators import PC
from pgmpy.base import DAG
from pgmpy.independencies import Independencies
import time
import collections

# %%
def csv_format_discrete(csv_file):
    df = pd.read_csv(csv_file, sep="\s+")
    return df.drop([0])

#returns the csv_file in a pandas dataframe, formatted properly, discrete dataset only

# %%
#small network : n <= 20 nodes, medium network: 20 <= n <= 50 , large: 50 <= n <= 100, ... 
df_small = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat")
df_medium = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat")
# df_large = csv_format_discrete(r"")

# %% [markdown]
# ### chi-squared test

# %%
df_small
# Out:
#        One  Two  Three  Four  Five  Six  Seven  Eight
# 1        1    1      0     0     0    1      0      1
# 2        1    0      0     0     0    0      1      0
# 3        0    0      1     0     0    0      1      0
# 4        1    0      1     0     0    0      1      0
# 5        1    0      1     0     0    0      0      1
# ...    ...  ...    ...   ...   ...  ...    ...    ...
# 9996     0    0      1     0     0    0      0      0
# 9997     1    0      1     0     0    0      1      1
# 9998     0    0      0     0     0    0      1      0
# 9999     1    0      0     0     0    0      1      0
# 10000    1    0      1     0     0    0      1      0
#
# [10000 rows x 8 columns]

# %%
#0th order chi2 test
def chi2bool(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    chi2 = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        chi = chi_square(X=i, Y=j, Z=[], data=df, significance_level=rho)
        chi2.append((i,j,chi))
    true_0 = [x for x in chi2 if True in x]
    false_0 = [x for x in chi2 if False in x]
    return true_0, false_0

# %% [markdown]
# ### Pearson's Product Moment Correlation Coefficient

# %%
df_gaus = pd.read_csv(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\gaussian.dat", sep="\s+")
df_gaus
# Out:
#              A          B          C          D         E          F         G
# 0     1.113083   1.932164   7.074806   8.660411  0.881591  24.719501  9.216382
# 1    -0.247948  11.334343  24.347372  23.355432  7.040113  36.812996  3.678833
# 2     1.854508   3.032020  11.086473  11.055891  3.834530  22.017182  2.424513
# 3     0.833911   3.857970  11.224775  11.937471  1.005624  23.285643  6.085473
# 4     0.488614   4.512613  10.000476  12.537179  4.084746  24.537596  5.117575
# ...        ...        ...        ...        ...       ...        ...       ...
# 4995  0.625860   1.587941   5.952431   8.516822  4.894385  16.950123  2.558535
# 4996  0.241723  -0.497071   1.695681   5.563204  7.454081  21.165266  4.867241
# 4997  2.527720  -2.706339   0.984988   1.597447  3.692427  18.808892  5.598200
# 4998  1.484585   1.468603   7.206672   8.486116  2.611856  21.528922  5.106188
# 4999 -0.306881   1.783709   4.603075   8.550474  5.044690  23.063591  6.511988
#
# [5000 rows x 7 columns]

# %%
#0th order chi2 test
def PMCC(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    R_list = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        R = pearsonr(X=i, Y=j, Z=[], data=df, significance_level=rho)
        R_list.append((i,j,R))
    true_0 = [x for x in R_list if True in x]
    false_0 = [x for x in R_list if False in x]
    return true_0, false_0

# %% [markdown]
# ### Sorting Functions

# %%
def create_permutations(my_list):
    '''
    takes in a list, remove extra permutations from the list and only creates a pair of permutations
    '''
    p_permutations = []
    new_list = list(set(tuple(sorted(l[:2])) for l in my_list))
    for items in new_list:
        new_list_0 = list(itertools.permutations(items[:2],2))[1]
        p_permutations.append(new_list_0)
    return new_list + p_permutations

# %%
#given 2 lists, append them together and remove duplicates
def remove_permutations(list_):
    '''
    returns a sorted list without permutation
    '''
    return sorted(list(set(tuple(sorted(l[:2])) for l in list_)))

# %% [markdown]
# ### 1st order CI

# %%
#1st order CI
def cond_1_generate(df, rho):
    v = list(df)
    p_permutations = list(itertools.permutations(v,3))
    order_0 = create_permutations(chi2bool(df, rho)[0])
    generated = [x for x in p_permutations if x[:2] not in order_0]
    generated_0 = set(tuple(sorted(items[:2])) for items in generated)
    generate_return = [x for x in generated if x[:2] in generated_0]
    return generate_return

# %%
def cond_1_test(df, rho):
    chi2_data = []
    phi = cond_1_generate(df, rho)
    for i,j,k in phi:
        chi2 = chi_square(X=i, Y=j, Z=[k], data=df, significance_level=rho)
        chi2_data.append((i,j,k,chi2))
    true_list = [x for x in chi2_data if True in x]
    false_list = [x for x in chi2_data if False in x]
    return true_list, false_list

# %% [markdown]
# ### CONDITIONAL MAIN CODE

# %%
def PC_(df, n, rho):
    '''
    Note:
    This function will start from at least 0th order CI
    
    Parameters:
    df (pandas dataframe)
    n an integer, the stopping point of the while loop
    rho (the significance level, only accepts values between 0 and 1 inclusive)
    
    Returns:
    A list which contains every independent X and Y
    '''
    N = 3
    v = list(df)
    # remove_list = [x for x in p_permute]
    remove_list = create_permutations([x[:2] for x in chi2bool(df, rho)[0]])
    #x[:2] for 0th order and its permutations, so we can later remove it 
    empty_list = []
    while N <= n:
        list_permutations = [x for x in itertools.permutations(v, N) if x[:2] not in remove_list]
        p_1, p_2, p_3 = [x[:1] for x in list_permutations], [x[1:2] for x in list_permutations], [x[2:] for x in list_permutations]
        for i,j,k in zip(p_1, p_2, p_3):
            chi2 = chi_square(X=i[0], Y=j[0], Z=k, data=df, significance_level=rho)
            empty_list.append((i[0],j[0],k,chi2))
        true_list = create_permutations([x[:2] for x in empty_list if True in x])
        #create_permutations ensures only 1 set of permutations of (X,Y) and (Y,X) and removes dupes
        remove_list = remove_list + create_permutations(true_list)
        remove_list = create_permutations(remove_list)
        N += 1
        
    return remove_permutations(remove_list) #returns 1 set of permutations

#ON MEDIUM SIZED NETWORKS:
#1st order CI takes 2minutes to run
#2nd order CI 9-15minutes to run
#nP5 takes ??? minutes to run
#nP6 not doable

# %% [markdown]
# ### small network

# %%
k_list
# Out:
# [['Six', 'Eight'],
#  ['Three', 'Eight'],
#  ['Five', 'Four'],
#  ['Five', 'Six'],
#  ['One', 'Three'],
#  ['One', 'Two'],
#  ['Six', 'Seven'],
#  ['Six', 'Two']]

# %%
# %%time
n = 0
N = 1
chi_list = []
m = Gobnilp()
while n < N:
    empty_list = []
    m.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat')
    for i,j in m.adjacency.items():
        if j.X == 1.0: #j.X == 1.0 implies there is an edge between the nodes
            empty_list.append(i)
    #chi2 test
    empty_list = [list(x) for x in empty_list]
    phi_0, phi_1 = [x[0] for x in empty_list], [x[1] for x in empty_list]
    for i,j in zip(phi_0, phi_1):
        chi2 = chi_square(X=i, Y=j, Z=[], data=df_small, significance_level=0.05)
        chi_list.append((i,j,chi2))
    true_list = [x[:2] for x in chi_list if True in x]
    for i,j in true_list:
        m.add_obligatory_independence([i],[j])
    n += 1
# Out:
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -105226.51191678003
# **********
# ANAPHYLAXIS<- -578.587070487134
# ARTCO2<-VENTALV -1816.018107669981
# VENTALV<-INTUBATION,VENTLUNG -1785.1568955858384
# BP<-CO,TPR -4927.804606748883
# TPR<-ANAPHYLAXIS -10794.813215814676
# CO<-HR,STROKEVOLUME -2678.9117199075117
# CATECHOL<-ARTCO2,TPR -1521.301873422577
# STROKEVOLUME<-HYPOVOLEMIA,LVFAILURE -4437.288938131547
# HR<-CATECHOL -3744.599767304855
# CVP<-LVEDVOLUME -3006.615302132195
# LVEDVOLUME<-HYPOVOLEMIA,LVFAILURE -3613.5057310384145
# DISCONNECT<- -3295.031743080661
# ERRCAUTER<- -3222.5768222310726
# ERRLOWOUTPUT<- -1972.2788189759885
# EXPCO2<-ARTCO2,VENTLUNG -1772.659127224848
# VENTLUNG<-INTUBATION,KINKEDTUBE,VENTTUBE -3618.0085247885727
# FIO2<- -1888.628670533668
# HISTORY<-LVFAILURE -637.4903136947833
# LVFAILURE<- -2010.5432102550985
# HRBP<-ERRLOWOUTPUT,HR -1331.6218853034952
# HREKG<-ERRCAUTER,HR -1507.9736736634222
# HRSAT<-ERRCAUTER,HR -1452.0851029207115
# HYPOVOLEMIA<- -4990.780506105162
# INSUFFANESTH<- -3303.7325344726705
# INTUBATION<- -3428.3602719444025
# KINKEDTUBE<- -1558.2831144287338
# MINVOL<-INTUBATION,VENTLUNG -2061.90574142267
# MINVOLSET<-VENTMACH -946.5564916227886
# VENTMACH<- -6169.083417643327
# PAP<- -4194.791057672555
# PCWP<-LVEDVOLUME -2233.6875379606645
# PRESS<-INTUBATION,KINKEDTUBE,VENTTUBE -8478.131859909474
# VENTTUBE<-DISCONNECT,VENTMACH -1814.1386675404356
# PULMEMBOLUS<-PAP -396.61118678582716
# PVSAT<-FIO2,VENTALV -846.3768118197477
# SAO2<-PVSAT,SHUNT -1137.5909747223923
# SHUNT<-INTUBATION,PULMEMBOLUS -2052.9806218132435
# **********
# bnlearn modelstring =
# [ANAPHYLAXIS][ARTCO2|VENTALV][VENTALV|VENTLUNG:INTUBATION][BP|TPR:CO][TPR|ANAPHYLAXIS][CO|STROKEVOLUME:HR][CATECHOL|TPR:ARTCO2][STROKEVOLUME|HYPOVOLEMIA:LVFAILURE][HR|CATECHOL][CVP|LVEDVOLUME][LVEDVOLUME|HYPOVOLEMIA:LVFAILURE][DISCONNECT][ERRCAUTER][ERRLOWOUTPUT][EXPCO2|ARTCO2:VENTLUNG][VENTLUNG|INTUBATION:KINKEDTUBE:VENTTUBE][FIO2][HISTORY|LVFAILURE][LVFAILURE][HRBP|ERRLOWOUTPUT:HR][HREKG|ERRCAUTER:HR][HRSAT|ERRCAUTER:HR][HYPOVOLEMIA][INSUFFANESTH][INTUBATION][KINKEDTUBE][MINVOL|VENTLUNG:INTUBATION][MINVOLSET|VENTMACH][VENTMACH][PAP][PCWP|LVEDVOLUME][PRESS|INTUBATION:KINKEDTUBE:VENTTUBE][VENTTUBE|DISCONNECT:VENTMACH][PULMEMBOLUS|PAP][PVSAT|FIO2:VENTALV][SAO2|SHUNT:PVSAT][SHUNT|INTUBATION:PULMEMBOLUS]
# **********
# CPDAG:
# Vertices: ANAPHYLAXIS,ARTCO2,VENTALV,BP,TPR,CO,CATECHOL,STROKEVOLUME,HR,CVP,LVEDVOLUME,DISCONNECT,ERRCAUTER,ERRLOWOUTPUT,EXPCO2,VENTLUNG,FIO2,HISTORY,LVFAILURE,HRBP,HREKG,HRSAT,HYPOVOLEMIA,INSUFFANESTH,INTUBATION,KINKEDTUBE,MINVOL,MINVOLSET,VENTMACH,PAP,PCWP,PRESS,VENTTUBE,PULMEMBOLUS,PVSAT,SAO2,SHUNT
# ANAPHYLAXIS-TPR
# ARTCO2->CATECHOL
# ARTCO2->EXPCO2
# VENTALV->ARTCO2
# VENTALV->PVSAT
# TPR->BP
# TPR->CATECHOL
# CO->BP
# CATECHOL->HR
# STROKEVOLUME->CO
# HR->CO
# HR->HRBP
# HR->HREKG
# HR->HRSAT
# LVEDVOLUME->CVP
# LVEDVOLUME->PCWP
# DISCONNECT->VENTTUBE
# ERRCAUTER->HREKG
# ERRCAUTER->HRSAT
# ERRLOWOUTPUT->HRBP
# VENTLUNG->EXPCO2
# VENTLUNG->MINVOL
# VENTLUNG->VENTALV
# FIO2->PVSAT
# LVFAILURE-HISTORY
# LVFAILURE->LVEDVOLUME
# LVFAILURE->STROKEVOLUME
# HYPOVOLEMIA->LVEDVOLUME
# HYPOVOLEMIA->STROKEVOLUME
# INTUBATION-MINVOL
# INTUBATION->PRESS
# INTUBATION->SHUNT
# INTUBATION-VENTALV
# INTUBATION->VENTLUNG
# KINKEDTUBE->PRESS
# KINKEDTUBE->VENTLUNG
# VENTMACH-MINVOLSET
# VENTMACH->VENTTUBE
# PAP-PULMEMBOLUS
# VENTTUBE->PRESS
# VENTTUBE->VENTLUNG
# PULMEMBOLUS->SHUNT
# PVSAT->SAO2
# SHUNT->SAO2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:15
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:95, in chi_square(X, Y, Z, data, boolean, **kwargs)
#      35 def chi_square(X, Y, Z, data, boolean=True, **kwargs):
#      36     r"""
#      37     Chi-square conditional independence test.
#      38     Tests the null hypothesis that X is independent from Y given Zs.
#    (...)
#      93     False
#      94     """
# ---> 95     return power_divergence(
#      96         X=X, Y=Y, Z=Z, data=data, boolean=boolean, lambda_="pearson", **kwargs
#      97     )
#
# File ~\anaconda3\lib\site-packages\pgmpy\estimators\CITests.py:540, in power_divergence(X, Y, Z, data, boolean, lambda_, **kwargs)
#     537 # Step 2: Do a simple contingency test if there are no conditional variables.
#     538 if len(Z) == 0:
#     539     chi, p_value, dof, expected = stats.chi2_contingency(
# --> 540         data.groupby([X, Y]).size().unstack(Y, fill_value=0), lambda_=lambda_
#     541     )
#     543 # Step 3: If there are conditionals variables, iterate over unique states and do
#     544 #         the contingency test.
#     545 else:
#     546     chi = 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7721, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7716 axis = self._get_axis_number(axis)
#    7718 # https://github.com/python/mypy/issues/7642
#    7719 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720 # "Union[bool, NoDefault]"; expected "bool"
# -> 7721 return DataFrameGroupBy(
#    7722     obj=self,
#    7723     keys=by,
#    7724     axis=axis,
#    7725     level=level,
#    7726     as_index=as_index,
#    7727     sort=sort,
#    7728     group_keys=group_keys,
#    7729     squeeze=squeeze,  # type: ignore[arg-type]
#    7730     observed=observed,
#    7731     dropna=dropna,
#    7732 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: 'TPR'

# %%
m.adjacency
# Out:
# {frozenset({'ANAPHYLAXIS',
#             'BP'}): <gurobi.Var ANAPHYLAXIS-BP (value 5.711229429000656e-08)>,
#  frozenset({'ANAPHYLAXIS',
#             'CATECHOL'}): <gurobi.Var ANAPHYLAXIS-CATECHOL (value -6.014042308902161e-08)>,
#  frozenset({'ANAPHYLAXIS',
#             'HYPOVOLEMIA'}): <gurobi.Var ANAPHYLAXIS-HYPOVOLEMIA (value -0.0)>,
#  frozenset({'ANAPHYLAXIS', 'TPR'}): <gurobi.Var ANAPHYLAXIS-TPR (value 1.0)>,
#  frozenset({'ARTCO2', 'BP'}): <gurobi.Var ARTCO2-BP (value -0.0)>,
#  frozenset({'ARTCO2',
#             'CATECHOL'}): <gurobi.Var ARTCO2-CATECHOL (value 0.9999999999999982)>,
#  frozenset({'ARTCO2', 'CO'}): <gurobi.Var ARTCO2-CO (value 0.0)>,
#  frozenset({'ARTCO2',
#             'DISCONNECT'}): <gurobi.Var ARTCO2-DISCONNECT (value -0.0)>,
#  frozenset({'ARTCO2', 'EXPCO2'}): <gurobi.Var ARTCO2-EXPCO2 (value 1.0)>,
#  frozenset({'ARTCO2', 'FIO2'}): <gurobi.Var ARTCO2-FIO2 (value 0.0)>,
#  frozenset({'ARTCO2', 'HR'}): <gurobi.Var ARTCO2-HR (value 0.0)>,
#  frozenset({'ARTCO2', 'HRBP'}): <gurobi.Var ARTCO2-HRBP (value 0.0)>,
#  frozenset({'ARTCO2', 'HREKG'}): <gurobi.Var ARTCO2-HREKG (value 0.0)>,
#  frozenset({'ARTCO2', 'HRSAT'}): <gurobi.Var ARTCO2-HRSAT (value -0.0)>,
#  frozenset({'ARTCO2',
#             'INTUBATION'}): <gurobi.Var ARTCO2-INTUBATION (value 0.0)>,
#  frozenset({'ARTCO2',
#             'KINKEDTUBE'}): <gurobi.Var ARTCO2-KINKEDTUBE (value 0.0)>,
#  frozenset({'ARTCO2', 'MINVOL'}): <gurobi.Var ARTCO2-MINVOL (value -0.0)>,
#  frozenset({'ARTCO2',
#             'MINVOLSET'}): <gurobi.Var ARTCO2-MINVOLSET (value -0.0)>,
#  frozenset({'ARTCO2', 'PRESS'}): <gurobi.Var ARTCO2-PRESS (value -0.0)>,
#  frozenset({'ARTCO2', 'PVSAT'}): <gurobi.Var ARTCO2-PVSAT (value 0.0)>,
#  frozenset({'ARTCO2', 'SAO2'}): <gurobi.Var ARTCO2-SAO2 (value -0.0)>,
#  frozenset({'ARTCO2', 'SHUNT'}): <gurobi.Var ARTCO2-SHUNT (value 0.0)>,
#  frozenset({'ARTCO2',
#             'STROKEVOLUME'}): <gurobi.Var ARTCO2-STROKEVOLUME (value -0.0)>,
#  frozenset({'ARTCO2', 'TPR'}): <gurobi.Var ARTCO2-TPR (value 0.0)>,
#  frozenset({'ARTCO2', 'VENTALV'}): <gurobi.Var ARTCO2-VENTALV (value 1.0)>,
#  frozenset({'ARTCO2', 'VENTLUNG'}): <gurobi.Var ARTCO2-VENTLUNG (value 0.0)>,
#  frozenset({'ARTCO2', 'VENTMACH'}): <gurobi.Var ARTCO2-VENTMACH (value -0.0)>,
#  frozenset({'ARTCO2', 'VENTTUBE'}): <gurobi.Var ARTCO2-VENTTUBE (value 0.0)>,
#  frozenset({'BP',
#             'CATECHOL'}): <gurobi.Var BP-CATECHOL (value -1.0352049217843273e-08)>,
#  frozenset({'BP', 'CO'}): <gurobi.Var BP-CO (value 1.0)>,
#  frozenset({'BP', 'CVP'}): <gurobi.Var BP-CVP (value -0.0)>,
#  frozenset({'BP', 'HISTORY'}): <gurobi.Var BP-HISTORY (value 0.0)>,
#  frozenset({'BP', 'HR'}): <gurobi.Var BP-HR (value -1.0352048662731761e-08)>,
#  frozenset({'BP', 'HRBP'}): <gurobi.Var BP-HRBP (value -0.0)>,
#  frozenset({'BP', 'HREKG'}): <gurobi.Var BP-HREKG (value -0.0)>,
#  frozenset({'BP', 'HRSAT'}): <gurobi.Var BP-HRSAT (value -0.0)>,
#  frozenset({'BP',
#             'HYPOVOLEMIA'}): <gurobi.Var BP-HYPOVOLEMIA (value -1.2816823824479684e-08)>,
#  frozenset({'BP', 'LVEDVOLUME'}): <gurobi.Var BP-LVEDVOLUME (value 0.0)>,
#  frozenset({'BP', 'LVFAILURE'}): <gurobi.Var BP-LVFAILURE (value -0.0)>,
#  frozenset({'BP', 'MINVOL'}): <gurobi.Var BP-MINVOL (value -0.0)>,
#  frozenset({'BP', 'PCWP'}): <gurobi.Var BP-PCWP (value 0.0)>,
#  frozenset({'BP', 'PVSAT'}): <gurobi.Var BP-PVSAT (value -0.0)>,
#  frozenset({'BP', 'SAO2'}): <gurobi.Var BP-SAO2 (value -0.0)>,
#  frozenset({'BP', 'STROKEVOLUME'}): <gurobi.Var BP-STROKEVOLUME (value 0.0)>,
#  frozenset({'BP', 'TPR'}): <gurobi.Var BP-TPR (value 1.0)>,
#  frozenset({'BP', 'VENTALV'}): <gurobi.Var BP-VENTALV (value -0.0)>,
#  frozenset({'CATECHOL',
#             'CO'}): <gurobi.Var CATECHOL-CO (value -1.2816821853279326e-08)>,
#  frozenset({'CATECHOL',
#             'DISCONNECT'}): <gurobi.Var CATECHOL-DISCONNECT (value 0.0)>,
#  frozenset({'CATECHOL',
#             'ERRCAUTER'}): <gurobi.Var CATECHOL-ERRCAUTER (value 8.04133268700012e-08)>,
#  frozenset({'CATECHOL',
#             'ERRLOWOUTPUT'}): <gurobi.Var CATECHOL-ERRLOWOUTPUT (value -9.701620785646435e-08)>,
#  frozenset({'CATECHOL', 'EXPCO2'}): <gurobi.Var CATECHOL-EXPCO2 (value 0.0)>,
#  frozenset({'CATECHOL', 'FIO2'}): <gurobi.Var CATECHOL-FIO2 (value -0.0)>,
#  frozenset({'CATECHOL',
#             'HISTORY'}): <gurobi.Var CATECHOL-HISTORY (value -0.0)>,
#  frozenset({'CATECHOL', 'HR'}): <gurobi.Var CATECHOL-HR (value 1.0)>,
#  frozenset({'CATECHOL', 'HRBP'}): <gurobi.Var CATECHOL-HRBP (value 0.0)>,
#  frozenset({'CATECHOL',
#             'HREKG'}): <gurobi.Var CATECHOL-HREKG (value -1.2816810612825691e-08)>,
#  frozenset({'CATECHOL',
#             'HRSAT'}): <gurobi.Var CATECHOL-HRSAT (value 1.9355740218682486e-07)>,
#  frozenset({'CATECHOL',
#             'HYPOVOLEMIA'}): <gurobi.Var CATECHOL-HYPOVOLEMIA (value -0.0)>,
#  frozenset({'CATECHOL',
#             'INTUBATION'}): <gurobi.Var CATECHOL-INTUBATION (value -0.0)>,
#  frozenset({'CATECHOL',
#             'LVFAILURE'}): <gurobi.Var CATECHOL-LVFAILURE (value -0.0)>,
#  frozenset({'CATECHOL', 'MINVOL'}): <gurobi.Var CATECHOL-MINVOL (value -0.0)>,
#  frozenset({'CATECHOL',
#             'MINVOLSET'}): <gurobi.Var CATECHOL-MINVOLSET (value -0.0)>,
#  frozenset({'CATECHOL', 'PRESS'}): <gurobi.Var CATECHOL-PRESS (value -0.0)>,
#  frozenset({'CATECHOL', 'PVSAT'}): <gurobi.Var CATECHOL-PVSAT (value 0.0)>,
#  frozenset({'CATECHOL', 'SAO2'}): <gurobi.Var CATECHOL-SAO2 (value 0.0)>,
#  frozenset({'CATECHOL', 'SHUNT'}): <gurobi.Var CATECHOL-SHUNT (value -0.0)>,
#  frozenset({'CATECHOL',
#             'STROKEVOLUME'}): <gurobi.Var CATECHOL-STROKEVOLUME (value -1.971817340809728e-08)>,
#  frozenset({'CATECHOL', 'TPR'}): <gurobi.Var CATECHOL-TPR (value 1.0)>,
#  frozenset({'CATECHOL', 'VENTALV'}): <gurobi.Var CATECHOL-VENTALV (value 0.0)>,
#  frozenset({'CATECHOL',
#             'VENTLUNG'}): <gurobi.Var CATECHOL-VENTLUNG (value -0.0)>,
#  frozenset({'CATECHOL',
#             'VENTMACH'}): <gurobi.Var CATECHOL-VENTMACH (value -0.0)>,
#  frozenset({'CATECHOL',
#             'VENTTUBE'}): <gurobi.Var CATECHOL-VENTTUBE (value 0.0)>,
#  frozenset({'CO', 'CVP'}): <gurobi.Var CO-CVP (value -0.0)>,
#  frozenset({'CO', 'DISCONNECT'}): <gurobi.Var CO-DISCONNECT (value -0.0)>,
#  frozenset({'CO',
#             'ERRCAUTER'}): <gurobi.Var CO-ERRCAUTER (value 1.511833854948463e-07)>,
#  frozenset({'CO',
#             'ERRLOWOUTPUT'}): <gurobi.Var CO-ERRLOWOUTPUT (value 5.699137331244958e-08)>,
#  frozenset({'CO',
#             'HISTORY'}): <gurobi.Var CO-HISTORY (value -2.464774876750354e-09)>,
#  frozenset({'CO', 'HR'}): <gurobi.Var CO-HR (value 1.0)>,
#  frozenset({'CO',
#             'HRBP'}): <gurobi.Var CO-HRBP (value -2.4647714980119417e-09)>,
#  frozenset({'CO',
#             'HREKG'}): <gurobi.Var CO-HREKG (value 7.535943285108902e-08)>,
#  frozenset({'CO',
#             'HRSAT'}): <gurobi.Var CO-HRSAT (value 1.7582038652644296e-08)>,
#  frozenset({'CO',
#             'HYPOVOLEMIA'}): <gurobi.Var CO-HYPOVOLEMIA (value 2.0521824042165449e-07)>,
#  frozenset({'CO',
#             'LVEDVOLUME'}): <gurobi.Var CO-LVEDVOLUME (value -2.464774876750354e-09)>,
#  frozenset({'CO',
#             'LVFAILURE'}): <gurobi.Var CO-LVFAILURE (value -4.140819329245323e-08)>,
#  frozenset({'CO', 'MINVOL'}): <gurobi.Var CO-MINVOL (value -0.0)>,
#  frozenset({'CO', 'MINVOLSET'}): <gurobi.Var CO-MINVOLSET (value -0.0)>,
#  frozenset({'CO',
#             'PCWP'}): <gurobi.Var CO-PCWP (value -1.0056276587743663e-07)>,
#  frozenset({'CO',
#             'PVSAT'}): <gurobi.Var CO-PVSAT (value -4.929546263739993e-09)>,
#  frozenset({'CO', 'SAO2'}): <gurobi.Var CO-SAO2 (value -0.0)>,
#  frozenset({'CO', 'STROKEVOLUME'}): <gurobi.Var CO-STROKEVOLUME (value 1.0)>,
#  frozenset({'CO', 'TPR'}): <gurobi.Var CO-TPR (value -1.2816823715067472e-08)>,
#  frozenset({'CO', 'VENTALV'}): <gurobi.Var CO-VENTALV (value -0.0)>,
#  frozenset({'CO', 'VENTLUNG'}): <gurobi.Var CO-VENTLUNG (value -0.0)>,
#  frozenset({'CO', 'VENTMACH'}): <gurobi.Var CO-VENTMACH (value -0.0)>,
#  frozenset({'CO',
#             'VENTTUBE'}): <gurobi.Var CO-VENTTUBE (value -7.053941118781889e-09)>,
#  frozenset({'CVP', 'HISTORY'}): <gurobi.Var CVP-HISTORY (value -0.0)>,
#  frozenset({'CVP', 'HR'}): <gurobi.Var CVP-HR (value -0.0)>,
#  frozenset({'CVP',
#             'HYPOVOLEMIA'}): <gurobi.Var CVP-HYPOVOLEMIA (value -2.4647750507256205e-09)>,
#  frozenset({'CVP', 'LVEDVOLUME'}): <gurobi.Var CVP-LVEDVOLUME (value 1.0)>,
#  frozenset({'CVP',
#             'LVFAILURE'}): <gurobi.Var CVP-LVFAILURE (value -4.387297036778647e-08)>,
#  frozenset({'CVP', 'PCWP'}): <gurobi.Var CVP-PCWP (value 0.0)>,
#  frozenset({'CVP',
#             'STROKEVOLUME'}): <gurobi.Var CVP-STROKEVOLUME (value -0.0)>,
#  frozenset({'CVP', 'TPR'}): <gurobi.Var CVP-TPR (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'EXPCO2'}): <gurobi.Var DISCONNECT-EXPCO2 (value 0.0)>,
#  frozenset({'DISCONNECT', 'FIO2'}): <gurobi.Var DISCONNECT-FIO2 (value -0.0)>,
#  frozenset({'DISCONNECT', 'HR'}): <gurobi.Var DISCONNECT-HR (value -0.0)>,
#  frozenset({'DISCONNECT', 'HRBP'}): <gurobi.Var DISCONNECT-HRBP (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'HREKG'}): <gurobi.Var DISCONNECT-HREKG (value -0.0)>,
#  frozenset({'DISCONNECT', 'HRSAT'}): <gurobi.Var DISCONNECT-HRSAT (value 0.0)>,
#  frozenset({'DISCONNECT',
#             'INTUBATION'}): <gurobi.Var DISCONNECT-INTUBATION (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'KINKEDTUBE'}): <gurobi.Var DISCONNECT-KINKEDTUBE (value 0.0)>,
#  frozenset({'DISCONNECT',
#             'MINVOL'}): <gurobi.Var DISCONNECT-MINVOL (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'MINVOLSET'}): <gurobi.Var DISCONNECT-MINVOLSET (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'PRESS'}): <gurobi.Var DISCONNECT-PRESS (value -0.0)>,
#  frozenset({'DISCONNECT', 'PVSAT'}): <gurobi.Var DISCONNECT-PVSAT (value 0.0)>,
#  frozenset({'DISCONNECT', 'SAO2'}): <gurobi.Var DISCONNECT-SAO2 (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'SHUNT'}): <gurobi.Var DISCONNECT-SHUNT (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'VENTALV'}): <gurobi.Var DISCONNECT-VENTALV (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'VENTLUNG'}): <gurobi.Var DISCONNECT-VENTLUNG (value -0.0)>,
#  frozenset({'DISCONNECT',
#             'VENTMACH'}): <gurobi.Var DISCONNECT-VENTMACH (value 0.0)>,
#  frozenset({'DISCONNECT',
#             'VENTTUBE'}): <gurobi.Var DISCONNECT-VENTTUBE (value 1.0)>,
#  frozenset({'ERRCAUTER',
#             'ERRLOWOUTPUT'}): <gurobi.Var ERRCAUTER-ERRLOWOUTPUT (value -0.0)>,
#  frozenset({'ERRCAUTER',
#             'HR'}): <gurobi.Var ERRCAUTER-HR (value 3.19541814146086e-07)>,
#  frozenset({'ERRCAUTER',
#             'HRBP'}): <gurobi.Var ERRCAUTER-HRBP (value -1.5774534345425195e-08)>,
#  frozenset({'ERRCAUTER', 'HREKG'}): <gurobi.Var ERRCAUTER-HREKG (value 1.0)>,
#  frozenset({'ERRCAUTER', 'HRSAT'}): <gurobi.Var ERRCAUTER-HRSAT (value 1.0)>,
#  frozenset({'ERRCAUTER',
#             'STROKEVOLUME'}): <gurobi.Var ERRCAUTER-STROKEVOLUME (value -0.0)>,
#  frozenset({'ERRLOWOUTPUT',
#             'HR'}): <gurobi.Var ERRLOWOUTPUT-HR (value 5.899261548425805e-09)>,
#  frozenset({'ERRLOWOUTPUT',
#             'HRBP'}): <gurobi.Var ERRLOWOUTPUT-HRBP (value 1.0)>,
#  frozenset({'ERRLOWOUTPUT',
#             'HREKG'}): <gurobi.Var ERRLOWOUTPUT-HREKG (value 0.0)>,
#  frozenset({'ERRLOWOUTPUT',
#             'HRSAT'}): <gurobi.Var ERRLOWOUTPUT-HRSAT (value 7.591498745250626e-08)>,
#  frozenset({'ERRLOWOUTPUT',
#             'STROKEVOLUME'}): <gurobi.Var ERRLOWOUTPUT-STROKEVOLUME (value -0.0)>,
#  frozenset({'EXPCO2', 'HR'}): <gurobi.Var EXPCO2-HR (value -0.0)>,
#  frozenset({'EXPCO2', 'HRBP'}): <gurobi.Var EXPCO2-HRBP (value -0.0)>,
#  frozenset({'EXPCO2', 'HREKG'}): <gurobi.Var EXPCO2-HREKG (value 0.0)>,
#  frozenset({'EXPCO2', 'HRSAT'}): <gurobi.Var EXPCO2-HRSAT (value -0.0)>,
#  frozenset({'EXPCO2',
#             'INTUBATION'}): <gurobi.Var EXPCO2-INTUBATION (value 0.0)>,
#  frozenset({'EXPCO2',
#             'KINKEDTUBE'}): <gurobi.Var EXPCO2-KINKEDTUBE (value -0.0)>,
#  frozenset({'EXPCO2', 'MINVOL'}): <gurobi.Var EXPCO2-MINVOL (value 0.0)>,
#  frozenset({'EXPCO2',
#             'MINVOLSET'}): <gurobi.Var EXPCO2-MINVOLSET (value -0.0)>,
#  frozenset({'EXPCO2', 'PRESS'}): <gurobi.Var EXPCO2-PRESS (value -0.0)>,
#  frozenset({'EXPCO2', 'PVSAT'}): <gurobi.Var EXPCO2-PVSAT (value 0.0)>,
#  frozenset({'EXPCO2', 'SAO2'}): <gurobi.Var EXPCO2-SAO2 (value 0.0)>,
#  frozenset({'EXPCO2', 'SHUNT'}): <gurobi.Var EXPCO2-SHUNT (value 0.0)>,
#  frozenset({'EXPCO2', 'VENTALV'}): <gurobi.Var EXPCO2-VENTALV (value 0.0)>,
#  frozenset({'EXPCO2', 'VENTLUNG'}): <gurobi.Var EXPCO2-VENTLUNG (value 1.0)>,
#  frozenset({'EXPCO2', 'VENTMACH'}): <gurobi.Var EXPCO2-VENTMACH (value -0.0)>,
#  frozenset({'EXPCO2', 'VENTTUBE'}): <gurobi.Var EXPCO2-VENTTUBE (value 0.0)>,
#  frozenset({'FIO2', 'MINVOL'}): <gurobi.Var FIO2-MINVOL (value -0.0)>,
#  frozenset({'FIO2', 'PVSAT'}): <gurobi.Var FIO2-PVSAT (value 1.0)>,
#  frozenset({'FIO2', 'SAO2'}): <gurobi.Var FIO2-SAO2 (value 0.0)>,
#  frozenset({'FIO2', 'SHUNT'}): <gurobi.Var FIO2-SHUNT (value -0.0)>,
#  frozenset({'FIO2', 'VENTALV'}): <gurobi.Var FIO2-VENTALV (value 0.0)>,
#  frozenset({'FIO2', 'VENTLUNG'}): <gurobi.Var FIO2-VENTLUNG (value -0.0)>,
#  frozenset({'FIO2', 'VENTTUBE'}): <gurobi.Var FIO2-VENTTUBE (value -0.0)>,
#  frozenset({'HISTORY', 'HR'}): <gurobi.Var HISTORY-HR (value 0.0)>,
#  frozenset({'HISTORY', 'HRBP'}): <gurobi.Var HISTORY-HRBP (value -0.0)>,
#  frozenset({'HISTORY', 'HREKG'}): <gurobi.Var HISTORY-HREKG (value -0.0)>,
#  frozenset({'HISTORY', 'HRSAT'}): <gurobi.Var HISTORY-HRSAT (value -0.0)>,
#  frozenset({'HISTORY',
#             'HYPOVOLEMIA'}): <gurobi.Var HISTORY-HYPOVOLEMIA (value -1.7239323367108563e-08)>,
#  frozenset({'HISTORY',
#             'LVEDVOLUME'}): <gurobi.Var HISTORY-LVEDVOLUME (value -0.0)>,
#  frozenset({'HISTORY',
#             'LVFAILURE'}): <gurobi.Var HISTORY-LVFAILURE (value 1.0)>,
#  frozenset({'HISTORY',
#             'PCWP'}): <gurobi.Var HISTORY-PCWP (value -1.1479885291013865e-07)>,
#  frozenset({'HISTORY',
#             'STROKEVOLUME'}): <gurobi.Var HISTORY-STROKEVOLUME (value -9.563321623495824e-08)>,
#  frozenset({'HISTORY', 'TPR'}): <gurobi.Var HISTORY-TPR (value -0.0)>,
#  frozenset({'HR', 'HRBP'}): <gurobi.Var HR-HRBP (value 1.0)>,
#  frozenset({'HR', 'HREKG'}): <gurobi.Var HR-HREKG (value 1.0)>,
#  frozenset({'HR', 'HRSAT'}): <gurobi.Var HR-HRSAT (value 0.9999999955634097)>,
#  frozenset({'HR', 'HYPOVOLEMIA'}): <gurobi.Var HR-HYPOVOLEMIA (value -0.0)>,
#  frozenset({'HR', 'LVEDVOLUME'}): <gurobi.Var HR-LVEDVOLUME (value -0.0)>,
#  frozenset({'HR',
#             'LVFAILURE'}): <gurobi.Var HR-LVFAILURE (value -3.246828764013697e-08)>,
#  frozenset({'HR', 'MINVOL'}): <gurobi.Var HR-MINVOL (value -0.0)>,
#  frozenset({'HR', 'MINVOLSET'}): <gurobi.Var HR-MINVOLSET (value -0.0)>,
#  frozenset({'HR',
#             'PCWP'}): <gurobi.Var HR-PCWP (value -1.0444060371211707e-07)>,
#  frozenset({'HR', 'PVSAT'}): <gurobi.Var HR-PVSAT (value -0.0)>,
#  frozenset({'HR', 'SAO2'}): <gurobi.Var HR-SAO2 (value -0.0)>,
#  frozenset({'HR', 'SHUNT'}): <gurobi.Var HR-SHUNT (value -0.0)>,
#  frozenset({'HR',
#             'STROKEVOLUME'}): <gurobi.Var HR-STROKEVOLUME (value 4.568626933250649e-08)>,
#  frozenset({'HR', 'TPR'}): <gurobi.Var HR-TPR (value -1.0352048662731761e-08)>,
#  frozenset({'HR', 'VENTALV'}): <gurobi.Var HR-VENTALV (value -0.0)>,
#  frozenset({'HR', 'VENTLUNG'}): <gurobi.Var HR-VENTLUNG (value -0.0)>,
#  frozenset({'HR', 'VENTMACH'}): <gurobi.Var HR-VENTMACH (value -0.0)>,
#  frozenset({'HR', 'VENTTUBE'}): <gurobi.Var HR-VENTTUBE (value -0.0)>,
#  frozenset({'HRBP',
#             'HREKG'}): <gurobi.Var HRBP-HREKG (value -6.408405139879392e-09)>,
#  frozenset({'HRBP',
#             'HRSAT'}): <gurobi.Var HRBP-HRSAT (value 1.2707029808560412e-07)>,
#  frozenset({'HRBP',
#             'HYPOVOLEMIA'}): <gurobi.Var HRBP-HYPOVOLEMIA (value -0.0)>,
#  frozenset({'HRBP', 'LVEDVOLUME'}): <gurobi.Var HRBP-LVEDVOLUME (value -0.0)>,
#  frozenset({'HRBP', 'LVFAILURE'}): <gurobi.Var HRBP-LVFAILURE (value -0.0)>,
#  frozenset({'HRBP', 'MINVOL'}): <gurobi.Var HRBP-MINVOL (value -0.0)>,
#  frozenset({'HRBP', 'MINVOLSET'}): <gurobi.Var HRBP-MINVOLSET (value -0.0)>,
#  frozenset({'HRBP', 'PCWP'}): <gurobi.Var HRBP-PCWP (value -0.0)>,
#  frozenset({'HRBP', 'PVSAT'}): <gurobi.Var HRBP-PVSAT (value -0.0)>,
#  frozenset({'HRBP', 'SAO2'}): <gurobi.Var HRBP-SAO2 (value -0.0)>,
#  frozenset({'HRBP',
#             'STROKEVOLUME'}): <gurobi.Var HRBP-STROKEVOLUME (value -2.4647714980119417e-09)>,
#  frozenset({'HRBP', 'TPR'}): <gurobi.Var HRBP-TPR (value -0.0)>,
#  frozenset({'HRBP', 'VENTALV'}): <gurobi.Var HRBP-VENTALV (value -0.0)>,
#  frozenset({'HRBP', 'VENTLUNG'}): <gurobi.Var HRBP-VENTLUNG (value -0.0)>,
#  frozenset({'HRBP', 'VENTMACH'}): <gurobi.Var HRBP-VENTMACH (value -0.0)>,
#  frozenset({'HRBP', 'VENTTUBE'}): <gurobi.Var HRBP-VENTTUBE (value -0.0)>,
#  frozenset({'HREKG',
#             'HRSAT'}): <gurobi.Var HREKG-HRSAT (value -1.9718147953431724e-09)>,
#  frozenset({'HREKG',
#             'HYPOVOLEMIA'}): <gurobi.Var HREKG-HYPOVOLEMIA (value 2.163789128720382e-07)>,
#  frozenset({'HREKG',
#             'LVEDVOLUME'}): <gurobi.Var HREKG-LVEDVOLUME (value -0.0)>,
#  frozenset({'HREKG', 'LVFAILURE'}): <gurobi.Var HREKG-LVFAILURE (value -0.0)>,
#  frozenset({'HREKG', 'MINVOL'}): <gurobi.Var HREKG-MINVOL (value -0.0)>,
#  frozenset({'HREKG', 'MINVOLSET'}): <gurobi.Var HREKG-MINVOLSET (value -0.0)>,
#  frozenset({'HREKG', 'PCWP'}): <gurobi.Var HREKG-PCWP (value -0.0)>,
#  frozenset({'HREKG', 'PVSAT'}): <gurobi.Var HREKG-PVSAT (value -0.0)>,
#  frozenset({'HREKG', 'SAO2'}): <gurobi.Var HREKG-SAO2 (value -0.0)>,
#  frozenset({'HREKG',
#             'STROKEVOLUME'}): <gurobi.Var HREKG-STROKEVOLUME (value 0.0)>,
#  frozenset({'HREKG', 'TPR'}): <gurobi.Var HREKG-TPR (value 0.0)>,
#  frozenset({'HREKG', 'VENTALV'}): <gurobi.Var HREKG-VENTALV (value -0.0)>,
#  frozenset({'HREKG', 'VENTLUNG'}): <gurobi.Var HREKG-VENTLUNG (value -0.0)>,
#  frozenset({'HREKG', 'VENTMACH'}): <gurobi.Var HREKG-VENTMACH (value -0.0)>,
#  frozenset({'HREKG', 'VENTTUBE'}): <gurobi.Var HREKG-VENTTUBE (value -0.0)>,
#  frozenset({'HRSAT',
#             'HYPOVOLEMIA'}): <gurobi.Var HRSAT-HYPOVOLEMIA (value -0.0)>,
#  frozenset({'HRSAT',
#             'LVEDVOLUME'}): <gurobi.Var HRSAT-LVEDVOLUME (value -0.0)>,
#  frozenset({'HRSAT', 'LVFAILURE'}): <gurobi.Var HRSAT-LVFAILURE (value -0.0)>,
#  frozenset({'HRSAT', 'MINVOL'}): <gurobi.Var HRSAT-MINVOL (value -0.0)>,
#  frozenset({'HRSAT', 'MINVOLSET'}): <gurobi.Var HRSAT-MINVOLSET (value -0.0)>,
#  frozenset({'HRSAT', 'PVSAT'}): <gurobi.Var HRSAT-PVSAT (value -0.0)>,
#  frozenset({'HRSAT', 'SAO2'}): <gurobi.Var HRSAT-SAO2 (value -0.0)>,
#  frozenset({'HRSAT',
#             'STROKEVOLUME'}): <gurobi.Var HRSAT-STROKEVOLUME (value -0.0)>,
#  frozenset({'HRSAT', 'TPR'}): <gurobi.Var HRSAT-TPR (value 0.0)>,
#  frozenset({'HRSAT', 'VENTALV'}): <gurobi.Var HRSAT-VENTALV (value -0.0)>,
#  frozenset({'HRSAT', 'VENTLUNG'}): <gurobi.Var HRSAT-VENTLUNG (value -0.0)>,
#  frozenset({'HRSAT', 'VENTMACH'}): <gurobi.Var HRSAT-VENTMACH (value -0.0)>,
#  frozenset({'HRSAT', 'VENTTUBE'}): <gurobi.Var HRSAT-VENTTUBE (value -0.0)>,
#  frozenset({'HYPOVOLEMIA',
#             'LVEDVOLUME'}): <gurobi.Var HYPOVOLEMIA-LVEDVOLUME (value 1.0)>,
#  frozenset({'HYPOVOLEMIA',
#             'LVFAILURE'}): <gurobi.Var HYPOVOLEMIA-LVFAILURE (value -9.859395392792722e-10)>,
#  frozenset({'HYPOVOLEMIA',
#             'PCWP'}): <gurobi.Var HYPOVOLEMIA-PCWP (value -2.5633647648959368e-08)>,
#  frozenset({'HYPOVOLEMIA',
#             'STROKEVOLUME'}): <gurobi.Var HYPOVOLEMIA-STROKEVOLUME (value 1.0)>,
#  frozenset({'HYPOVOLEMIA',
#             'TPR'}): <gurobi.Var HYPOVOLEMIA-TPR (value -1.2816823872549022e-08)>,
#  frozenset({'INTUBATION',
#             'KINKEDTUBE'}): <gurobi.Var INTUBATION-KINKEDTUBE (value 0.0)>,
#  frozenset({'INTUBATION',
#             'MINVOL'}): <gurobi.Var INTUBATION-MINVOL (value 1.0)>,
#  frozenset({'INTUBATION',
#             'MINVOLSET'}): <gurobi.Var INTUBATION-MINVOLSET (value -0.0)>,
#  frozenset({'INTUBATION', 'PRESS'}): <gurobi.Var INTUBATION-PRESS (value 1.0)>,
#  frozenset({'INTUBATION',
#             'PULMEMBOLUS'}): <gurobi.Var INTUBATION-PULMEMBOLUS (value 0.0)>,
#  frozenset({'INTUBATION',
#             'PVSAT'}): <gurobi.Var INTUBATION-PVSAT (value -0.0)>,
#  frozenset({'INTUBATION', 'SAO2'}): <gurobi.Var INTUBATION-SAO2 (value 0.0)>,
#  frozenset({'INTUBATION', 'SHUNT'}): <gurobi.Var INTUBATION-SHUNT (value 1.0)>,
#  frozenset({'INTUBATION',
#             'VENTALV'}): <gurobi.Var INTUBATION-VENTALV (value 1.0)>,
#  frozenset({'INTUBATION',
#             'VENTLUNG'}): <gurobi.Var INTUBATION-VENTLUNG (value 1.0)>,
#  frozenset({'INTUBATION',
#             'VENTMACH'}): <gurobi.Var INTUBATION-VENTMACH (value 0.0)>,
#  frozenset({'INTUBATION',
#             'VENTTUBE'}): <gurobi.Var INTUBATION-VENTTUBE (value 0.0)>,
#  frozenset({'KINKEDTUBE',
#             'MINVOL'}): <gurobi.Var KINKEDTUBE-MINVOL (value 0.0)>,
#  frozenset({'KINKEDTUBE',
#             'MINVOLSET'}): <gurobi.Var KINKEDTUBE-MINVOLSET (value -0.0)>,
#  frozenset({'KINKEDTUBE', 'PRESS'}): <gurobi.Var KINKEDTUBE-PRESS (value 1.0)>,
#  frozenset({'KINKEDTUBE',
#             'PVSAT'}): <gurobi.Var KINKEDTUBE-PVSAT (value -0.0)>,
#  frozenset({'KINKEDTUBE', 'SAO2'}): <gurobi.Var KINKEDTUBE-SAO2 (value 0.0)>,
#  frozenset({'KINKEDTUBE',
#             'VENTALV'}): <gurobi.Var KINKEDTUBE-VENTALV (value -0.0)>,
#  frozenset({'KINKEDTUBE',
#             'VENTLUNG'}): <gurobi.Var KINKEDTUBE-VENTLUNG (value 1.0)>,
#  frozenset({'KINKEDTUBE',
#             'VENTMACH'}): <gurobi.Var KINKEDTUBE-VENTMACH (value -0.0)>,
#  frozenset({'KINKEDTUBE',
#             'VENTTUBE'}): <gurobi.Var KINKEDTUBE-VENTTUBE (value 0.0)>,
#  frozenset({'LVEDVOLUME',
#             'LVFAILURE'}): <gurobi.Var LVEDVOLUME-LVFAILURE (value 1.0)>,
#  frozenset({'LVEDVOLUME', 'PCWP'}): <gurobi.Var LVEDVOLUME-PCWP (value 1.0)>,
#  frozenset({'LVEDVOLUME',
#             'STROKEVOLUME'}): <gurobi.Var LVEDVOLUME-STROKEVOLUME (value -0.0)>,
#  frozenset({'LVEDVOLUME', 'TPR'}): <gurobi.Var LVEDVOLUME-TPR (value -0.0)>,
#  frozenset({'LVFAILURE',
#             'PCWP'}): <gurobi.Var LVFAILURE-PCWP (value -1.1633731422655558e-07)>,
#  frozenset({'LVFAILURE',
#             'STROKEVOLUME'}): <gurobi.Var LVFAILURE-STROKEVOLUME (value 1.000000036478647)>,
#  frozenset({'LVFAILURE', 'TPR'}): <gurobi.Var LVFAILURE-TPR (value 0.0)>,
#  frozenset({'MINVOL', 'MINVOLSET'}): <gurobi.Var MINVOL-MINVOLSET (value 0.0)>,
#  frozenset({'MINVOL', 'PRESS'}): <gurobi.Var MINVOL-PRESS (value -0.0)>,
#  frozenset({'MINVOL',
#             'PULMEMBOLUS'}): <gurobi.Var MINVOL-PULMEMBOLUS (value -0.0)>,
#  frozenset({'MINVOL', 'PVSAT'}): <gurobi.Var MINVOL-PVSAT (value -0.0)>,
#  frozenset({'MINVOL', 'SAO2'}): <gurobi.Var MINVOL-SAO2 (value 0.0)>,
#  frozenset({'MINVOL', 'SHUNT'}): <gurobi.Var MINVOL-SHUNT (value -0.0)>,
#  frozenset({'MINVOL', 'TPR'}): <gurobi.Var MINVOL-TPR (value -0.0)>,
#  frozenset({'MINVOL', 'VENTALV'}): <gurobi.Var MINVOL-VENTALV (value 0.0)>,
#  frozenset({'MINVOL', 'VENTLUNG'}): <gurobi.Var MINVOL-VENTLUNG (value 1.0)>,
#  frozenset({'MINVOL', 'VENTMACH'}): <gurobi.Var MINVOL-VENTMACH (value 0.0)>,
#  frozenset({'MINVOL', 'VENTTUBE'}): <gurobi.Var MINVOL-VENTTUBE (value -0.0)>,
#  frozenset({'MINVOLSET', 'PRESS'}): <gurobi.Var MINVOLSET-PRESS (value -0.0)>,
#  frozenset({'MINVOLSET', 'PVSAT'}): <gurobi.Var MINVOLSET-PVSAT (value -0.0)>,
#  frozenset({'MINVOLSET', 'SAO2'}): <gurobi.Var MINVOLSET-SAO2 (value 0.0)>,
#  frozenset({'MINVOLSET', 'SHUNT'}): <gurobi.Var MINVOLSET-SHUNT (value -0.0)>,
#  frozenset({'MINVOLSET',
#             'VENTALV'}): <gurobi.Var MINVOLSET-VENTALV (value 0.0)>,
#  frozenset({'MINVOLSET',
#             'VENTLUNG'}): <gurobi.Var MINVOLSET-VENTLUNG (value -0.0)>,
#  frozenset({'MINVOLSET',
#             'VENTMACH'}): <gurobi.Var MINVOLSET-VENTMACH (value 1.0)>,
#  frozenset({'MINVOLSET',
#             'VENTTUBE'}): <gurobi.Var MINVOLSET-VENTTUBE (value 0.0)>,
#  frozenset({'PAP', 'PULMEMBOLUS'}): <gurobi.Var PAP-PULMEMBOLUS (value 1.0)>,
#  frozenset({'PAP', 'SHUNT'}): <gurobi.Var PAP-SHUNT (value 0.0)>,
#  frozenset({'PCWP',
#             'STROKEVOLUME'}): <gurobi.Var PCWP-STROKEVOLUME (value -6.211229498411676e-08)>,
#  frozenset({'PCWP', 'TPR'}): <gurobi.Var PCWP-TPR (value 0.0)>,
#  frozenset({'PRESS', 'PVSAT'}): <gurobi.Var PRESS-PVSAT (value -0.0)>,
#  frozenset({'PRESS', 'SAO2'}): <gurobi.Var PRESS-SAO2 (value -0.0)>,
#  frozenset({'PRESS', 'SHUNT'}): <gurobi.Var PRESS-SHUNT (value -0.0)>,
#  frozenset({'PRESS', 'VENTALV'}): <gurobi.Var PRESS-VENTALV (value -0.0)>,
#  frozenset({'PRESS', 'VENTLUNG'}): <gurobi.Var PRESS-VENTLUNG (value -0.0)>,
#  frozenset({'PRESS', 'VENTMACH'}): <gurobi.Var PRESS-VENTMACH (value 0.0)>,
#  frozenset({'PRESS', 'VENTTUBE'}): <gurobi.Var PRESS-VENTTUBE (value 1.0)>,
#  frozenset({'PULMEMBOLUS',
#             'PVSAT'}): <gurobi.Var PULMEMBOLUS-PVSAT (value -0.0)>,
#  frozenset({'PULMEMBOLUS',
#             'SAO2'}): <gurobi.Var PULMEMBOLUS-SAO2 (value -0.0)>,
#  frozenset({'PULMEMBOLUS',
#             'SHUNT'}): <gurobi.Var PULMEMBOLUS-SHUNT (value 1.0)>,
#  frozenset({'PULMEMBOLUS',
#             'VENTALV'}): <gurobi.Var PULMEMBOLUS-VENTALV (value 0.0)>,
#  frozenset({'PVSAT', 'SAO2'}): <gurobi.Var PVSAT-SAO2 (value 1.0)>,
#  frozenset({'PVSAT', 'SHUNT'}): <gurobi.Var PVSAT-SHUNT (value 0.0)>,
#  frozenset({'PVSAT', 'TPR'}): <gurobi.Var PVSAT-TPR (value -0.0)>,
#  frozenset({'PVSAT', 'VENTALV'}): <gurobi.Var PVSAT-VENTALV (value 1.0)>,
#  frozenset({'PVSAT', 'VENTLUNG'}): <gurobi.Var PVSAT-VENTLUNG (value -0.0)>,
#  frozenset({'PVSAT', 'VENTMACH'}): <gurobi.Var PVSAT-VENTMACH (value -0.0)>,
#  frozenset({'PVSAT', 'VENTTUBE'}): <gurobi.Var PVSAT-VENTTUBE (value 0.0)>,
#  frozenset({'SAO2', 'SHUNT'}): <gurobi.Var SAO2-SHUNT (value 1.0)>,
#  frozenset({'SAO2', 'TPR'}): <gurobi.Var SAO2-TPR (value -0.0)>,
#  frozenset({'SAO2', 'VENTALV'}): <gurobi.Var SAO2-VENTALV (value 0.0)>,
#  frozenset({'SAO2', 'VENTLUNG'}): <gurobi.Var SAO2-VENTLUNG (value -0.0)>,
#  frozenset({'SAO2', 'VENTMACH'}): <gurobi.Var SAO2-VENTMACH (value -0.0)>,
#  frozenset({'SAO2', 'VENTTUBE'}): <gurobi.Var SAO2-VENTTUBE (value -0.0)>,
#  frozenset({'SHUNT', 'VENTALV'}): <gurobi.Var SHUNT-VENTALV (value 0.0)>,
#  frozenset({'SHUNT', 'VENTLUNG'}): <gurobi.Var SHUNT-VENTLUNG (value -0.0)>,
#  frozenset({'SHUNT', 'VENTMACH'}): <gurobi.Var SHUNT-VENTMACH (value -0.0)>,
#  frozenset({'SHUNT', 'VENTTUBE'}): <gurobi.Var SHUNT-VENTTUBE (value 0.0)>,
#  frozenset({'STROKEVOLUME', 'TPR'}): <gurobi.Var STROKEVOLUME-TPR (value 0.0)>,
#  frozenset({'TPR', 'VENTALV'}): <gurobi.Var TPR-VENTALV (value -0.0)>,
#  frozenset({'TPR', 'VENTLUNG'}): <gurobi.Var TPR-VENTLUNG (value -0.0)>,
#  frozenset({'TPR', 'VENTMACH'}): <gurobi.Var TPR-VENTMACH (value -0.0)>,
#  frozenset({'TPR', 'VENTTUBE'}): <gurobi.Var TPR-VENTTUBE (value -0.0)>,
#  frozenset({'VENTALV', 'VENTLUNG'}): <gurobi.Var VENTALV-VENTLUNG (value 1.0)>,
#  frozenset({'VENTALV',
#             'VENTMACH'}): <gurobi.Var VENTALV-VENTMACH (value -0.0)>,
#  frozenset({'VENTALV',
#             'VENTTUBE'}): <gurobi.Var VENTALV-VENTTUBE (value -0.0)>,
#  frozenset({'VENTLUNG',
#             'VENTMACH'}): <gurobi.Var VENTLUNG-VENTMACH (value -0.0)>,
#  frozenset({'VENTLUNG',
#             'VENTTUBE'}): <gurobi.Var VENTLUNG-VENTTUBE (value 1.0)>,
#  frozenset({'VENTMACH',
#             'VENTTUBE'}): <gurobi.Var VENTMACH-VENTTUBE (value 1.0)>}

# %%
k_list = []
for i,j in m.adjacency.items():
        if j.X >= 0.9: #j.X == 1.0 implies there is an edge between the nodes
            k_list.append(i)
k_list = [list(x) for x in k_list]
n = 0
N = len(k_list)
X_adjacent = []
Y_adjacent = []
XY_adjacent = []
while n < N:
    
    ##X##
    empty_X = []
    t_0, t_1 = k_list[n][0], k_list[n][1]
    p_x = [x for x in k_list if t_0 in x and t_1 not in x]
    for i in p_x:
        h_x = [x for x in i if t_0 not in x]
        empty_X.append(h_x)
    X_adjacent.append((k_list[n], empty_X, len(empty_X)))
    ##X##
    
    ##Y##
    empty_Y = []
    t_0, t_1 = k_list[n][0], k_list[n][1]
    p_y = [x for x in k_list if t_1 in x and t_0 not in x]
    for i in p_y:
        h_y = [x for x in i if t_1 not in x]
        empty_Y.append(h_y)
    Y_adjacent.append((k_list[n], empty_Y, len(empty_Y)))
    ##Y##
    
    
    X_Y_adjacent = []
    t_ = X_adjacent[n][1] + Y_adjacent[n][1]
    h1 = set(tuple(x) for x in t_)
    h2 = [list(x) for x in h1]
    XY_adjacent.append((k_list[n], h2, len(h2)))
    
    n += 1

# %%
XY_adjacent
# Out:
# [(['TPR', 'ANAPHYLAXIS'], [['CATECHOL'], ['BP']], 2),
#  (['ARTCO2', 'CATECHOL'], [['EXPCO2'], ['VENTALV'], ['HR'], ['TPR']], 4),
#  (['ARTCO2', 'EXPCO2'], [['VENTLUNG'], ['VENTALV'], ['CATECHOL']], 3),
#  (['ARTCO2', 'VENTALV'],
#   [['PVSAT'], ['INTUBATION'], ['EXPCO2'], ['CATECHOL'], ['VENTLUNG']],
#   5),
#  (['BP', 'CO'], [['STROKEVOLUME'], ['HR'], ['TPR']], 3),
#  (['BP', 'TPR'], [['CO'], ['CATECHOL'], ['ANAPHYLAXIS']], 3),
#  (['CATECHOL', 'HR'], [['ARTCO2'], [], ['CO'], ['TPR']], 4),
#  (['TPR', 'CATECHOL'], [['ARTCO2'], ['HR'], ['BP'], ['ANAPHYLAXIS']], 4),
#  (['CO', 'HR'], [['STROKEVOLUME'], [], ['CATECHOL'], ['BP']], 4),
#  (['CO', 'STROKEVOLUME'], [['HYPOVOLEMIA'], ['LVFAILURE'], ['HR'], ['BP']], 4),
#  (['LVEDVOLUME', 'CVP'], [['HYPOVOLEMIA'], ['LVFAILURE'], ['PCWP']], 3),
#  (['DISCONNECT', 'VENTTUBE'], [['PRESS'], ['VENTLUNG'], ['VENTMACH']], 3),
#  (['ERRCAUTER', 'HREKG'], [['HRSAT'], ['HR']], 2),
#  (['ERRCAUTER', 'HRSAT'], [['HR'], ['HREKG']], 2),
#  (['HRBP', 'ERRLOWOUTPUT'], [['HR']], 1),
#  (['VENTLUNG', 'EXPCO2'],
#   [['MINVOL'],
#    ['INTUBATION'],
#    ['VENTALV'],
#    ['ARTCO2'],
#    ['KINKEDTUBE'],
#    ['VENTTUBE']],
#   6),
#  (['FIO2', 'PVSAT'], [['VENTALV'], ['SAO2']], 2),
#  (['LVFAILURE', 'HISTORY'], [['LVEDVOLUME'], ['STROKEVOLUME']], 2),
#  (['HRBP', 'HR'], [['ERRLOWOUTPUT'], [], ['CO'], ['CATECHOL']], 4),
#  (['HREKG', 'HR'], [['ERRCAUTER'], ['CO'], ['CATECHOL'], []], 4),
#  (['HRSAT', 'HR'], [['ERRCAUTER'], ['CO'], ['CATECHOL'], []], 4),
#  (['HYPOVOLEMIA', 'LVEDVOLUME'],
#   [['CVP'], ['STROKEVOLUME'], ['LVFAILURE'], ['PCWP']],
#   4),
#  (['HYPOVOLEMIA', 'STROKEVOLUME'], [['LVEDVOLUME'], ['LVFAILURE'], ['CO']], 3),
#  (['INTUBATION', 'MINVOL'],
#   [['PRESS'], ['VENTLUNG'], ['VENTALV'], ['SHUNT']],
#   4),
#  (['PRESS', 'INTUBATION'],
#   [['MINVOL'],
#    ['VENTALV'],
#    ['VENTLUNG'],
#    ['KINKEDTUBE'],
#    ['VENTTUBE'],
#    ['SHUNT']],
#   6),
#  (['INTUBATION', 'SHUNT'],
#   [['PRESS'],
#    ['MINVOL'],
#    ['SAO2'],
#    ['VENTALV'],
#    ['VENTLUNG'],
#    ['PULMEMBOLUS']],
#   6),
#  (['INTUBATION', 'VENTALV'],
#   [['PRESS'], ['MINVOL'], ['PVSAT'], ['ARTCO2'], ['VENTLUNG'], ['SHUNT']],
#   6),
#  (['VENTLUNG', 'INTUBATION'],
#   [['PRESS'],
#    ['MINVOL'],
#    ['VENTALV'],
#    ['EXPCO2'],
#    ['KINKEDTUBE'],
#    ['VENTTUBE'],
#    ['SHUNT']],
#   7),
#  (['PRESS', 'KINKEDTUBE'], [['VENTLUNG'], ['INTUBATION'], ['VENTTUBE']], 3),
#  (['VENTLUNG', 'KINKEDTUBE'],
#   [['PRESS'],
#    ['MINVOL'],
#    ['INTUBATION'],
#    ['VENTALV'],
#    ['EXPCO2'],
#    ['VENTTUBE']],
#   6),
#  (['LVEDVOLUME', 'LVFAILURE'],
#   [['CVP'], ['HYPOVOLEMIA'], ['PCWP'], ['STROKEVOLUME'], ['HISTORY']],
#   5),
#  (['LVEDVOLUME', 'PCWP'], [['CVP'], ['HYPOVOLEMIA'], ['LVFAILURE']], 3),
#  (['LVFAILURE', 'STROKEVOLUME'],
#   [['LVEDVOLUME'], ['HISTORY'], ['CO'], ['HYPOVOLEMIA']],
#   4),
#  (['VENTLUNG', 'MINVOL'],
#   [['INTUBATION'], ['VENTALV'], ['EXPCO2'], ['KINKEDTUBE'], ['VENTTUBE']],
#   5),
#  (['MINVOLSET', 'VENTMACH'], [['VENTTUBE']], 1),
#  (['PAP', 'PULMEMBOLUS'], [['SHUNT']], 1),
#  (['PRESS', 'VENTTUBE'],
#   [['DISCONNECT'], ['INTUBATION'], ['VENTMACH'], ['VENTLUNG'], ['KINKEDTUBE']],
#   5),
#  (['SHUNT', 'PULMEMBOLUS'], [['INTUBATION'], ['PAP'], ['SAO2']], 3),
#  (['SAO2', 'PVSAT'], [['FIO2'], ['VENTALV'], ['SHUNT']], 3),
#  (['VENTALV', 'PVSAT'],
#   [['FIO2'], ['INTUBATION'], ['SAO2'], ['ARTCO2'], ['VENTLUNG']],
#   5),
#  (['SAO2', 'SHUNT'], [['INTUBATION'], ['PVSAT'], ['PULMEMBOLUS']], 3),
#  (['VENTLUNG', 'VENTALV'],
#   [['MINVOL'],
#    ['PVSAT'],
#    ['INTUBATION'],
#    ['ARTCO2'],
#    ['EXPCO2'],
#    ['KINKEDTUBE'],
#    ['VENTTUBE']],
#   7),
#  (['VENTLUNG', 'VENTTUBE'],
#   [['PRESS'],
#    ['MINVOL'],
#    ['DISCONNECT'],
#    ['INTUBATION'],
#    ['VENTALV'],
#    ['VENTMACH'],
#    ['EXPCO2'],
#    ['KINKEDTUBE']],
#   8),
#  (['VENTMACH', 'VENTTUBE'],
#   [['PRESS'], ['VENTLUNG'], ['MINVOLSET'], ['DISCONNECT']],
#   4)]

# %%
test_list = [x[1] for x in XY_adjacent]
for i in test_list:
    test_2 = set(tuple(x) for x in i)
    test_3 = [list(x) for x in test_2]
    print(test_3)
# Out:
# [['CATECHOL'], ['BP']]
# [['EXPCO2'], ['VENTALV'], ['HR'], ['TPR']]
# [['VENTLUNG'], ['VENTALV'], ['CATECHOL']]
# [['PVSAT'], ['INTUBATION'], ['EXPCO2'], ['CATECHOL'], ['VENTLUNG']]
# [['STROKEVOLUME'], ['HR'], ['TPR']]
# [['CO'], ['CATECHOL'], ['ANAPHYLAXIS']]
# [['ARTCO2'], [], ['CO'], ['TPR']]
# [['ARTCO2'], ['HR'], ['BP'], ['ANAPHYLAXIS']]
# [['STROKEVOLUME'], [], ['CATECHOL'], ['BP']]
# [['HYPOVOLEMIA'], ['LVFAILURE'], ['HR'], ['BP']]
# [['HYPOVOLEMIA'], ['LVFAILURE'], ['PCWP']]
# [['PRESS'], ['VENTLUNG'], ['VENTMACH']]
# [['HRSAT'], ['HR']]
# [['HR'], ['HREKG']]
# [['HR']]
# [['MINVOL'], ['INTUBATION'], ['VENTALV'], ['ARTCO2'], ['KINKEDTUBE'], ['VENTTUBE']]
# [['VENTALV'], ['SAO2']]
# [['LVEDVOLUME'], ['STROKEVOLUME']]
# [['ERRLOWOUTPUT'], [], ['CO'], ['CATECHOL']]
# [['ERRCAUTER'], ['CO'], ['CATECHOL'], []]
# [['ERRCAUTER'], ['CO'], ['CATECHOL'], []]
# [['CVP'], ['STROKEVOLUME'], ['LVFAILURE'], ['PCWP']]
# [['LVEDVOLUME'], ['LVFAILURE'], ['CO']]
# [['PRESS'], ['VENTLUNG'], ['VENTALV'], ['SHUNT']]
# [['MINVOL'], ['VENTALV'], ['VENTLUNG'], ['KINKEDTUBE'], ['VENTTUBE'], ['SHUNT']]
# [['PRESS'], ['MINVOL'], ['SAO2'], ['VENTALV'], ['VENTLUNG'], ['PULMEMBOLUS']]
# [['PRESS'], ['MINVOL'], ['PVSAT'], ['ARTCO2'], ['VENTLUNG'], ['SHUNT']]
# [['PRESS'], ['MINVOL'], ['VENTALV'], ['EXPCO2'], ['KINKEDTUBE'], ['VENTTUBE'], ['SHUNT']]
# [['VENTLUNG'], ['INTUBATION'], ['VENTTUBE']]
# [['PRESS'], ['MINVOL'], ['INTUBATION'], ['VENTALV'], ['EXPCO2'], ['VENTTUBE']]
# [['CVP'], ['HYPOVOLEMIA'], ['PCWP'], ['STROKEVOLUME'], ['HISTORY']]
# [['CVP'], ['HYPOVOLEMIA'], ['LVFAILURE']]
# [['LVEDVOLUME'], ['HISTORY'], ['CO'], ['HYPOVOLEMIA']]
# [['INTUBATION'], ['VENTALV'], ['EXPCO2'], ['KINKEDTUBE'], ['VENTTUBE']]
# [['VENTTUBE']]
# [['SHUNT']]
# [['DISCONNECT'], ['INTUBATION'], ['VENTMACH'], ['VENTLUNG'], ['KINKEDTUBE']]
# [['INTUBATION'], ['PAP'], ['SAO2']]
# [['FIO2'], ['VENTALV'], ['SHUNT']]
# [['FIO2'], ['INTUBATION'], ['SAO2'], ['ARTCO2'], ['VENTLUNG']]
# [['INTUBATION'], ['PVSAT'], ['PULMEMBOLUS']]
# [['MINVOL'], ['PVSAT'], ['INTUBATION'], ['ARTCO2'], ['EXPCO2'], ['KINKEDTUBE'], ['VENTTUBE']]
# [['PRESS'], ['MINVOL'], ['DISCONNECT'], ['INTUBATION'], ['VENTALV'], ['VENTMACH'], ['EXPCO2'], ['KINKEDTUBE']]
# [['PRESS'], ['VENTLUNG'], ['MINVOLSET'], ['DISCONNECT']]

# %%
k_list
# Out:
# [['Six', 'Eight'],
#  ['Three', 'Eight'],
#  ['Five', 'Four'],
#  ['Five', 'Six'],
#  ['One', 'Three'],
#  ['One', 'Two'],
#  ['Six', 'Seven'],
#  ['Six', 'Two']]

# %%
V = [x[:2] for x in chi2bool(df_medium, 0.05)[0]]
V_0 = [x[0] for x in V]
V_1 = [x[1] for x in V]

# %%
# %%time
n = 0
N = 1
chi_list = []
m = Gobnilp()
while n < N:
    empty_list = []
    m.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat')
    for i,j in m.adjacency.items():
        if j.X == 1.0: #j.X == 1.0 implies there is an edge between the nodes
            empty_list.append(i)
    #chi2 test
    empty_list = [list(x) for x in empty_list]
    phi_0, phi_1 = [x[0] for x in empty_list], [x[1] for x in empty_list]
    for i,j in zip(phi_0, phi_1):
        chi2 = chi_square(X=i, Y=j, Z=[], data=df_small, significance_level=0.05)
        chi_list.append((i,j,chi2))
    true_list = [x[:2] for x in chi_list if True in x]
    for i,j in true_list:
        m.add_obligatory_independence([i],[j])
    n += 1
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-21
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -22466.396546491495
# **********
# Eight<-Six,Three -4150.291729106073
# Six<-Five,Two -5.611578690688475
# Three<- -6901.1493808303785
# Five<-Four -633.8404777927353
# Four<- -527.7536882896093
# One<-Three -6460.081285708176
# Seven<-Six -1881.452188461728
# Two<-One -1906.2162176121055
# **********
# bnlearn modelstring =
# [Eight|Six:Three][Six|Five:Two][Three][Five|Four][Four][One|Three][Seven|Six][Two|One]
# **********
# CPDAG:
# Vertices: Eight,Six,Three,Five,Four,One,Seven,Two
# Six->Eight
# Six->Seven
# Three->Eight
# Three-One
# Five->Six
# Four-Five
# One-Two
# Two->Six
# CPU times: total: 3 s
# Wall time: 2.51 s

# %%
phi
# Out:
# set()

# %%
n = 0
N = 1
chi_list = []
m = Gobnilp()
empty_list = []
m.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat')
for i,j in m.adjacency.items():
    if j.X == 1.0: #j.X == 1.0 implies there is an edge between the nodes
        empty_list.append(i)
empty_list = [list(x) for x in empty_list]
# Out:
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -22466.396546491495
# **********
# Eight<-Six,Three -4150.291729106073
# Six<-Five,Two -5.611578690688475
# Three<- -6901.1493808303785
# Five<-Four -633.8404777927353
# Four<- -527.7536882896093
# One<-Three -6460.081285708176
# Seven<-Six -1881.452188461728
# Two<-One -1906.2162176121055
# **********
# bnlearn modelstring =
# [Eight|Six:Three][Six|Five:Two][Three][Five|Four][Four][One|Three][Seven|Six][Two|One]
# **********
# CPDAG:
# Vertices: Eight,Six,Three,Five,Four,One,Seven,Two
# Six->Eight
# Six->Seven
# Three->Eight
# Three-One
# Five->Six
# Four-Five
# One-Two
# Two->Six

# %%
empty_list
# Out:
# [['Six', 'Eight'],
#  ['Three', 'Eight'],
#  ['Five', 'Four'],
#  ['Five', 'Six'],
#  ['One', 'Three'],
#  ['One', 'Two'],
#  ['Six', 'Seven'],
#  ['Six', 'Two']]

# %% [markdown]
# ### medium-sized network

# %%
m_medium = Gobnilp()

# %%
# %%time 
y_medium = PC_(df_medium, 2, 0.05)
for i,j in y_medium:
        m_medium.add_obligatory_independence([i],[j])

# %%
# %%time
# m_medium.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_100.dat')

# %%
# %%time
m_medium.learn(start='MIP solution')

# %%
m0 = Gobnilp()

# %%
# %%time
m0.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat')

# %%
# %%time
m.learn(start='MIP solution', palim=10)

# %%
(list(m.forbidden_arrows))

# %% [markdown]
# ### PC Algorithm

# %%
c = PC(data=df_small)

# %%
# %%time
s = Gobnilp()
V = [x[:2] for x in chi2bool(df_medium, 0.01)[0]]
V_0 = [x[0] for x in V]
V_1 = [x[1] for x in V]
for x,y in zip(V_0, V_1):
    s.add_obligatory_independence([x], [y])
s.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat', palim=5)
#start 1500

# %%
s.forbidden_arrows

# %%
# %%time
kprime = Gobnilp()
kprime.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat')
