# %%
import pandas as pd
import numpy as np
from pygobnilp.gobnilp import Gobnilp
import pgmpy
import itertools
from pgmpy.estimators.CITests import pearsonr
from pgmpy.estimators.CITests import chi_square
import networkx as nx
import time
import collections

# %%
def csv_format_discrete(csv_file):
    df = pd.read_csv(csv_file, sep="\s+")
    return df.drop([0])

#returns the csv_file in a pandas dataframe, formatted properly, discrete dataset only

# %%
#small network : n <= 20 nodes, medium network: 20 <= n <= 50 , large: 50 <= n <= 100, ... 
df_small = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat")
df_medium = csv_format_discrete(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\alarm_10000.dat")
# df_large = csv_format_discrete(r"")

# %% [markdown]
# ### chi-squared test

# %%
df_small
# Out:
#        One  Two  Three  Four  Five  Six  Seven  Eight
# 1        1    1      0     0     0    1      0      1
# 2        1    0      0     0     0    0      1      0
# 3        0    0      1     0     0    0      1      0
# 4        1    0      1     0     0    0      1      0
# 5        1    0      1     0     0    0      0      1
# ...    ...  ...    ...   ...   ...  ...    ...    ...
# 9996     0    0      1     0     0    0      0      0
# 9997     1    0      1     0     0    0      1      1
# 9998     0    0      0     0     0    0      1      0
# 9999     1    0      0     0     0    0      1      0
# 10000    1    0      1     0     0    0      1      0
#
# [10000 rows x 8 columns]

# %%
#0th order chi2 test
def chi2bool(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    chi2 = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        chi = chi_square(X=i, Y=j, Z=[], data=df, significance_level=rho)
        chi2.append((i,j,chi))
    true_0 = [x for x in chi2 if True in x]
    false_0 = [x for x in chi2 if False in x]
    return true_0, false_0

# %% [markdown]
# ### Pearson's Product Moment Correlation Coefficient

# %%
df_gaus = pd.read_csv(r"C:\Users\User\Documents\GitHub\ML_FYP\dataset\gaussian.dat", sep="\s+")
df_gaus
# Out:
#              A          B          C          D         E          F         G
# 0     1.113083   1.932164   7.074806   8.660411  0.881591  24.719501  9.216382
# 1    -0.247948  11.334343  24.347372  23.355432  7.040113  36.812996  3.678833
# 2     1.854508   3.032020  11.086473  11.055891  3.834530  22.017182  2.424513
# 3     0.833911   3.857970  11.224775  11.937471  1.005624  23.285643  6.085473
# 4     0.488614   4.512613  10.000476  12.537179  4.084746  24.537596  5.117575
# ...        ...        ...        ...        ...       ...        ...       ...
# 4995  0.625860   1.587941   5.952431   8.516822  4.894385  16.950123  2.558535
# 4996  0.241723  -0.497071   1.695681   5.563204  7.454081  21.165266  4.867241
# 4997  2.527720  -2.706339   0.984988   1.597447  3.692427  18.808892  5.598200
# 4998  1.484585   1.468603   7.206672   8.486116  2.611856  21.528922  5.106188
# 4999 -0.306881   1.783709   4.603075   8.550474  5.044690  23.063591  6.511988
#
# [5000 rows x 7 columns]

# %%
#0th order chi2 test
def PMCC(df, rho):
    '''
    0th order CI test
    
    Parameters:
    df -> pandas dataframe
    rho -> significance level, only accept 0 <= rho <= 1.0
    '''
    R_list = []
    v = list(df)
    my_list = list(itertools.combinations(v,2))
    y_0, y_1 = [x[0] for x in my_list], [x[1] for x in my_list]
    for i,j in zip(y_0, y_1):
        R = pearsonr(X=i, Y=j, Z=[], data=df, significance_level=rho)
        R_list.append((i,j,R))
    true_0 = [x for x in R_list if True in x]
    false_0 = [x for x in R_list if False in x]
    return true_0, false_0

# %% [markdown]
# ### Sorting Functions

# %%
def create_permutations(my_list):
    '''
    takes in a list, remove extra permutations from the list and only creates a pair of permutations
    '''
    p_permutations = []
    new_list = list(set(tuple(sorted(l[:2])) for l in my_list))
    for items in new_list:
        new_list_0 = list(itertools.permutations(items[:2],2))[1]
        p_permutations.append(new_list_0)
    return new_list + p_permutations

# %%
#given 2 lists, append them together and remove duplicates
def remove_permutations(list_):
    '''
    returns a sorted list without permutation
    '''
    return sorted(list(set(tuple(sorted(l[:2])) for l in list_)))

# %% [markdown]
# ### 1st order CI

# %%
#1st order CI
def cond_1_generate(df, rho):
    v = list(df)
    p_permutations = list(itertools.permutations(v,3))
    order_0 = create_permutations(chi2bool(df, rho)[0])
    generated = [x for x in p_permutations if x[:2] not in order_0]
    generated_0 = set(tuple(sorted(items[:2])) for items in generated)
    generate_return = [x for x in generated if x[:2] in generated_0]
    return generate_return

# %%
def cond_1_test(df, rho):
    chi2_data = []
    phi = cond_1_generate(df, rho)
    for i,j,k in phi:
        chi2 = chi_square(X=i, Y=j, Z=[k], data=df, significance_level=rho)
        chi2_data.append((i,j,k,chi2))
    true_list = [x for x in chi2_data if True in x]
    false_list = [x for x in chi2_data if False in x]
    return true_list, false_list

# %% [markdown]
# ### CONDITIONAL MAIN CODE

# %%
def PC_(df, n, rho):
    '''
    Note:
    This function will start from at least 0th order CI
    
    Parameters:
    df (pandas dataframe)
    n an integer, the stopping point of the while loop
    rho (the significance level, only accepts values between 0 and 1 inclusive)
    
    Returns:
    A list which contains every independent X and Y
    '''
    N = 3
    v = list(df)
    # remove_list = [x for x in p_permute]
    remove_list = create_permutations([x[:2] for x in chi2bool(df, rho)[0]])
    #x[:2] for 0th order and its permutations, so we can later remove it 
    empty_list = []
    while N <= n:
        list_permutations = [x for x in itertools.permutations(v, N) if x[:2] not in remove_list]
        p_1, p_2, p_3 = [x[:1] for x in list_permutations], [x[1:2] for x in list_permutations], [x[2:] for x in list_permutations]
        for i,j,k in zip(p_1, p_2, p_3):
            chi2 = chi_square(X=i[0], Y=j[0], Z=k, data=df, significance_level=rho)
            empty_list.append((i[0],j[0],k,chi2))
        true_list = create_permutations([x[:2] for x in empty_list if True in x])
        #create_permutations ensures only 1 set of permutations of (X,Y) and (Y,X) and removes dupes
        remove_list = remove_list + create_permutations(true_list)
        remove_list = create_permutations(remove_list)
        N += 1
        
    return remove_permutations(remove_list) #returns 1 set of permutations

#ON MEDIUM SIZED NETWORKS:
#1st order CI takes 2minutes to run
#2nd order CI 9-15minutes to run
#nP5 takes ??? minutes to run
#nP6 not doable

# %%
PC_(df_small, 5, 0.05)
# Out:
# [('Eight', 'Five'),
#  ('Eight', 'Four'),
#  ('Eight', 'One'),
#  ('Eight', 'Seven'),
#  ('Eight', 'Two'),
#  ('Five', 'Four'),
#  ('Five', 'One'),
#  ('Five', 'Seven'),
#  ('Five', 'Three'),
#  ('Five', 'Two'),
#  ('Four', 'One'),
#  ('Four', 'Seven'),
#  ('Four', 'Six'),
#  ('Four', 'Three'),
#  ('Four', 'Two'),
#  ('One', 'Seven'),
#  ('One', 'Six'),
#  ('One', 'Two'),
#  ('Seven', 'Three'),
#  ('Seven', 'Two'),
#  ('Six', 'Three'),
#  ('Three', 'Two')]

# %%
G = nx.Graph()
v = list(df_small)
for i in v:
    G.add_node(i)
print(G)
# Out:
# Graph with 8 nodes and 0 edges

# %%
k = list(itertools.combinations(v,2))
for i,j in k:
    G.add_edge(i,j)

# %%
print(G)
nx.draw(G, with_labels = True)
# Out:
# Graph with 8 nodes and 28 edges

# %%
ind_0 = [x[:2] for x in chi2bool(df_small, 0.05)[0]]
# ind_0

# %%
for i,j in ind_0:
    G.remove_edge(i,j)

# %%
print(G)
nx.draw(G, with_labels = True)
# Out:
# Graph with 8 nodes and 20 edges

# %%
false_list = [x[:2] for x in chi2bool(df_small, 0.05)[1]]

# %%
test_list = []
for i,j in false_list:
    test_list.append((i, j, list(G.edges(i)), list(G.edges(j))))

# %%
len(test_list)
# Out:
# 20

# %%
n = 0
N = len(test_list)
output = []
edge_XY_test = []
while n < N:
    ##
    adjacent_X = []
    adjacent_Y = []
    edge_XY = []
    X, Y = test_list[n][0], test_list[n][1]
    k_X, k_Y = test_list[n][2], test_list[n][3]
    edge_X = [x for x in k_X if x[1] != Y]
    edge_Y = [x for x in k_Y if x[1] not in (y[1] for y in k_X) and x[1] != X]
    for x in edge_X:
        adjacent_X.append(x[1])
    for y in edge_Y:
        adjacent_Y.append(y[1])
    adjacent_XY = adjacent_X + adjacent_Y
    len_XY = len(adjacent_XY)
    edge_XY.append((X, Y, adjacent_XY, len_XY))
    edge_XY_test.append((X, Y, adjacent_XY, len_XY))
#     print(edge_XY)

    ##
    chi2_list = []
    z = []
    for i in edge_XY:
        val = 1
        value = i[3]
        while val <= value:
            combinations = list(itertools.combinations(i[2], val))
            z.append(combinations)
            val += 1
    print(z)
#     for i,j in zip(edge_XY, z):
#         while n_z <=  n_stop:
#             chi2 = chi_square(X=i[0], Y=i[1], Z=j[n_z], data=df_small, significance_level=0.05)
#             if chi2 == True:
#                 chi2_list.append((i[0], i[1], j[n_z], chi2))
#                 print(n_z, chi2_list)
#                 break
#             n_z += 1
        
        
    output.append((chi2_list))
    n += 1
output = [x for x in output if x != []]
# Out:
# [[('Three',), ('Six',), ('Seven',), ('Eight',)], [('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Eight'), ('Six', 'Seven'), ('Six', 'Eight'), ('Seven', 'Eight')], [('Three', 'Six', 'Seven'), ('Three', 'Six', 'Eight'), ('Three', 'Seven', 'Eight'), ('Six', 'Seven', 'Eight')], [('Three', 'Six', 'Seven', 'Eight')]]
# [[('Two',), ('Six',), ('Seven',), ('Eight',), ('Five',)], [('Two', 'Six'), ('Two', 'Seven'), ('Two', 'Eight'), ('Two', 'Five'), ('Six', 'Seven'), ('Six', 'Eight'), ('Six', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')], [('Two', 'Six', 'Seven'), ('Two', 'Six', 'Eight'), ('Two', 'Six', 'Five'), ('Two', 'Seven', 'Eight'), ('Two', 'Seven', 'Five'), ('Two', 'Eight', 'Five'), ('Six', 'Seven', 'Eight'), ('Six', 'Seven', 'Five'), ('Six', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')], [('Two', 'Six', 'Seven', 'Eight'), ('Two', 'Six', 'Seven', 'Five'), ('Two', 'Six', 'Eight', 'Five'), ('Two', 'Seven', 'Eight', 'Five'), ('Six', 'Seven', 'Eight', 'Five')], [('Two', 'Six', 'Seven', 'Eight', 'Five')]]
# [[('Two',), ('Three',), ('Seven',), ('Eight',), ('Five',)], [('Two', 'Three'), ('Two', 'Seven'), ('Two', 'Eight'), ('Two', 'Five'), ('Three', 'Seven'), ('Three', 'Eight'), ('Three', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')], [('Two', 'Three', 'Seven'), ('Two', 'Three', 'Eight'), ('Two', 'Three', 'Five'), ('Two', 'Seven', 'Eight'), ('Two', 'Seven', 'Five'), ('Two', 'Eight', 'Five'), ('Three', 'Seven', 'Eight'), ('Three', 'Seven', 'Five'), ('Three', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')], [('Two', 'Three', 'Seven', 'Eight'), ('Two', 'Three', 'Seven', 'Five'), ('Two', 'Three', 'Eight', 'Five'), ('Two', 'Seven', 'Eight', 'Five'), ('Three', 'Seven', 'Eight', 'Five')], [('Two', 'Three', 'Seven', 'Eight', 'Five')]]
# [[('Two',), ('Three',), ('Six',), ('Eight',), ('Five',)], [('Two', 'Three'), ('Two', 'Six'), ('Two', 'Eight'), ('Two', 'Five'), ('Three', 'Six'), ('Three', 'Eight'), ('Three', 'Five'), ('Six', 'Eight'), ('Six', 'Five'), ('Eight', 'Five')], [('Two', 'Three', 'Six'), ('Two', 'Three', 'Eight'), ('Two', 'Three', 'Five'), ('Two', 'Six', 'Eight'), ('Two', 'Six', 'Five'), ('Two', 'Eight', 'Five'), ('Three', 'Six', 'Eight'), ('Three', 'Six', 'Five'), ('Three', 'Eight', 'Five'), ('Six', 'Eight', 'Five')], [('Two', 'Three', 'Six', 'Eight'), ('Two', 'Three', 'Six', 'Five'), ('Two', 'Three', 'Eight', 'Five'), ('Two', 'Six', 'Eight', 'Five'), ('Three', 'Six', 'Eight', 'Five')], [('Two', 'Three', 'Six', 'Eight', 'Five')]]
# [[('Two',), ('Three',), ('Six',), ('Seven',), ('Five',)], [('Two', 'Three'), ('Two', 'Six'), ('Two', 'Seven'), ('Two', 'Five'), ('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Five'), ('Six', 'Seven'), ('Six', 'Five'), ('Seven', 'Five')], [('Two', 'Three', 'Six'), ('Two', 'Three', 'Seven'), ('Two', 'Three', 'Five'), ('Two', 'Six', 'Seven'), ('Two', 'Six', 'Five'), ('Two', 'Seven', 'Five'), ('Three', 'Six', 'Seven'), ('Three', 'Six', 'Five'), ('Three', 'Seven', 'Five'), ('Six', 'Seven', 'Five')], [('Two', 'Three', 'Six', 'Seven'), ('Two', 'Three', 'Six', 'Five'), ('Two', 'Three', 'Seven', 'Five'), ('Two', 'Six', 'Seven', 'Five'), ('Three', 'Six', 'Seven', 'Five')], [('Two', 'Three', 'Six', 'Seven', 'Five')]]
# [[('One',), ('Six',), ('Seven',), ('Eight',), ('Five',)], [('One', 'Six'), ('One', 'Seven'), ('One', 'Eight'), ('One', 'Five'), ('Six', 'Seven'), ('Six', 'Eight'), ('Six', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')], [('One', 'Six', 'Seven'), ('One', 'Six', 'Eight'), ('One', 'Six', 'Five'), ('One', 'Seven', 'Eight'), ('One', 'Seven', 'Five'), ('One', 'Eight', 'Five'), ('Six', 'Seven', 'Eight'), ('Six', 'Seven', 'Five'), ('Six', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')], [('One', 'Six', 'Seven', 'Eight'), ('One', 'Six', 'Seven', 'Five'), ('One', 'Six', 'Eight', 'Five'), ('One', 'Seven', 'Eight', 'Five'), ('Six', 'Seven', 'Eight', 'Five')], [('One', 'Six', 'Seven', 'Eight', 'Five')]]
# [[('One',), ('Three',), ('Seven',), ('Eight',), ('Five',)], [('One', 'Three'), ('One', 'Seven'), ('One', 'Eight'), ('One', 'Five'), ('Three', 'Seven'), ('Three', 'Eight'), ('Three', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five
# [[('One',), ('Two',), ('Five',), ('Seven',), ('Eight',)], [('One', 'Two'), ('One', 'Five'), ('One', 'Seven'), ('One', 'Eight'), ('Two', 'Five'), ('Two', 'Seven'), ('Two', 'Eight'), ('Five', 'Seven'), ('Five', 'Eight'), ('Seven', 'Eight')], [('One', 'Two', 'Five'), ('One', 'Two', 'Seven'), ('One', 'Two', 'Eight'), ('One', 'Five', 'Seven'), ('One', 'Five', 'Eight'), ('One', 'Seven', 'Eight'), ('Two', 'Five', 'Seven'), ('Two', 'Five', 'Eight'), ('Two', 'Seven', 'Eight'), ('Five', 'Seven', 'Eight')], [('One', 'Two', 'Five', 'Seven'), ('One', 'Two', 'Five', 'Eight'), ('One', 'Two', 'Seven', 'Eight'), ('One', 'Five', 'Seven', 'Eight'), ('Two', 'Five', 'Seven', 'Eight')], [('One', 'Two', 'Five', 'Seven', 'Eight')]]
# [[('One',), ('Two',), ('Five',), ('Six',), ('Eight',)], [('One', 'Two'), ('One', 'Five'), ('One', 'Six'), ('One', 'Eight'), ('Two', 'Five'), ('Two', 'Six'), ('Two', 'Eight'), ('Five', 'Six'), ('Five', 'Eight'), ('Six', 'Eight')], [('One', 'Two', 'Five'), ('One', 'Two', 'Six'), ('One', 'Two', 'Eight'), ('One', 'Five', 'Six'), ('One', 'Five', 'Eight'), ('One', 'Six', 'Eight'), ('Two', 'Five', 'Six'), ('Two', 'Five', 'Eight'), ('Two', 'Six', 'Eight'), ('Five', 'Six', 'Eight')], [('One', 'Two', 'Five', 'Six'), ('One', 'Two', 'Five', 'Eight'), ('One', 'Two', 'Six', 'Eight'), ('One', 'Five', 'Six', 'Eight'), ('Two', 'Five', 'Six', 'Eight')], [('One', 'Two', 'Five', 'Six', 'Eight')]]
# [[('One',), ('Two',), ('Five',), ('Six',), ('Seven',)], [('One', 'Two'), ('One', 'Five'), ('One', 'Six'), ('One', 'Seven'), ('Two', 'Five'), ('Two', 'Six'), ('Two', 'Seven'), ('Five', 'Six'), ('Five', 'Seven'), ('Six', 'Seven')], [('One', 'Two', 'Five'), ('One', 'Two', 'Six'), ('One', 'Two', 'Seven'), ('One', 'Five', 'Six'), ('One', 'Five', 'Seven'), ('One', 'Six', 'Seven'), ('Two', 'Five', 'Six'), ('Two', 'Five', 'Seven'), ('Two', 'Six', 'Seven'), ('Five', 'Six', 'Seven')], [('One', 'Two', 'Five', 'Six'), ('One', 'Two', 'Five', 'Seven'), ('One', 'Two', 'Six', 'Seven'), ('One', 'Five', 'Six', 'Seven'), ('Two', 'Five', 'Six', 'Seven')], [('One', 'Two', 'Five', 'Six', 'Seven')]]
# [[('Three',), ('Six',), ('Seven',), ('Eight',)], [('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Eight'), ('Six', 'Seven'), ('Six', 'Eight'), ('Seven', 'Eight')], [('Three', 'Six', 'Seven'), ('Three', 'Six', 'Eight'), ('Three', 'Seven', 'Eight'), ('Six', 'Seven', 'Eight')], [('Three', 'Six', 'Seven', 'Eight')]]
# [[('Three',), ('Four',), ('Seven',), ('Eight',), ('One',), ('Two',)], [('Three', 'Four'), ('Three', 'Seven'), ('Three', 'Eight'), ('Three', 'One'), ('Three', 'Two'), ('Four', '
('One', 'Two'), ('One', 'Three'), ('One', 'Five'), ('One', 'Six'), ('Two', 'Three'), ('Two', 'Five'), ('Two', 'Six'), ('Three', 'Five'), ('Three', 'Six'), ('Five', 'Six')], [('One', 'Two', 'Three'), ('One', 'Two', 'Five'), ('One', 'Two', 'Six'), ('One', 'Three', 'Five'), ('One', 'Three', 'Six'), ('One', 'Five', 'Six'), ('Two', 'Three', 'Five'), ('Two', 'Three', 'Six'), ('Two', 'Five', 'Six'), ('Three', 'Five', 'Six')], [('One', 'Two', 'Three', 'Five'), ('One', 'Two', 'Three', 'Six'), ('One', 'Two', 'Five', 'Six'), ('One', 'Three', 'Five', 'Six'), ('Two', 'Three', 'Five', 'Six')], [('One', 'Two', 'Three', 'Five', 'Six')]]

# %%
edge_XY_test
# Out:
# [('One', 'Two', ['Three', 'Six', 'Seven', 'Eight'], 4),
#  ('One', 'Three', ['Two', 'Six', 'Seven', 'Eight', 'Five'], 5),
#  ('One', 'Six', ['Two', 'Three', 'Seven', 'Eight', 'Five'], 5),
#  ('One', 'Seven', ['Two', 'Three', 'Six', 'Eight', 'Five'], 5),
#  ('One', 'Eight', ['Two', 'Three', 'Six', 'Seven', 'Five'], 5),
#  ('Two', 'Three', ['One', 'Six', 'Seven', 'Eight', 'Five'], 5),
#  ('Two', 'Six', ['One', 'Three', 'Seven', 'Eight', 'Five'], 5),
#  ('Two', 'Seven', ['One', 'Three', 'Six', 'Eight', 'Five'], 5),
#  ('Two', 'Eight', ['One', 'Three', 'Six', 'Seven', 'Five'], 5),
#  ('Three', 'Five', ['One', 'Two', 'Six', 'Seven', 'Eight', 'Four'], 6),
#  ('Three', 'Six', ['One', 'Two', 'Five', 'Seven', 'Eight'], 5),
#  ('Three', 'Seven', ['One', 'Two', 'Five', 'Six', 'Eight'], 5),
#  ('Three', 'Eight', ['One', 'Two', 'Five', 'Six', 'Seven'], 5),
#  ('Four', 'Five', ['Three', 'Six', 'Seven', 'Eight'], 4),
#  ('Five', 'Six', ['Three', 'Four', 'Seven', 'Eight', 'One', 'Two'], 6),
#  ('Five', 'Seven', ['Three', 'Four', 'Six', 'Eight', 'One', 'Two'], 6),
#  ('Five', 'Eight', ['Three', 'Four', 'Six', 'Seven', 'One', 'Two'], 6),
#  ('Six', 'Seven', ['One', 'Two', 'Three', 'Five', 'Eight'], 5),
#  ('Six', 'Eight', ['One', 'Two', 'Three', 'Five', 'Seven'], 5),
#  ('Seven', 'Eight', ['One', 'Two', 'Three', 'Five', 'Six'], 5)]

# %%
# %%time
k = []
for i in edge_XY_test:
#     print(i[3])
#     print(i)
    val = 1
    value = i[3]
    while val <= value:
        combinations = list(itertools.combinations(i[2], val))
        k.append(combinations)
        print(i[0], i[1], combinations, len(combinations))
        print('break')
        val += 1
# Out:
# One Two [('Three',), ('Six',), ('Seven',), ('Eight',)] 4
# break
# One Two [('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Eight'), ('Six', 'Seven'), ('Six', 'Eight'), ('Seven', 'Eight')] 6
# break
# One Two [('Three', 'Six', 'Seven'), ('Three', 'Six', 'Eight'), ('Three', 'Seven', 'Eight'), ('Six', 'Seven', 'Eight')] 4
# break
# One Two [('Three', 'Six', 'Seven', 'Eight')] 1
# break
# One Three [('Two',), ('Six',), ('Seven',), ('Eight',), ('Five',)] 5
# break
# One Three [('Two', 'Six'), ('Two', 'Seven'), ('Two', 'Eight'), ('Two', 'Five'), ('Six', 'Seven'), ('Six', 'Eight'), ('Six', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')] 10
# break
# One Three [('Two', 'Six', 'Seven'), ('Two', 'Six', 'Eight'), ('Two', 'Six', 'Five'), ('Two', 'Seven', 'Eight'), ('Two', 'Seven', 'Five'), ('Two', 'Eight', 'Five'), ('Six', 'Seven', 'Eight'), ('Six', 'Seven', 'Five'), ('Six', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')] 10
# break
# One Three [('Two', 'Six', 'Seven', 'Eight'), ('Two', 'Six', 'Seven', 'Five'), ('Two', 'Six', 'Eight', 'Five'), ('Two', 'Seven', 'Eight', 'Five'), ('Six', 'Seven', 'Eight', 'Five')] 5
# break
# One Three [('Two', 'Six', 'Seven', 'Eight', 'Five')] 1
# break
# One Six [('Two',), ('Three',), ('Seven',), ('Eight',), ('Five',)] 5
# break
# One Six [('Two', 'Three'), ('Two', 'Seven'), ('Two', 'Eight'), ('Two', 'Five'), ('Three', 'Seven'), ('Three', 'Eight'), ('Three', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')] 10
# break
# One Six [('Two', 'Three', 'Seven'), ('Two', 'Three', 'Eight'), ('Two', 'Three', 'Five'), ('Two', 'Seven', 'Eight'), ('Two', 'Seven', 'Five'), ('Two', 'Eight', 'Five'), ('Three', 'Seven', 'Eight'), ('Three', 'Seven', 'Five'), ('Three', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')] 10
# break
# One Six [('Two', 'Three', 'Seven', 'Eight'), ('Two', 'Three', 'Seven', 'Five'), ('Two', 'Three', 'Eight', 'Five'), ('Two', 'Seven', 'Eight', 'Five'), ('Three', 'Seven', 'Eight', 'Five')] 5
# break
# One Six [('Two', 'Three', 'Seven', 'Eight', 'Five')] 1
# break
# One Seven [('Two',), ('Three',), ('Six',), ('Eight',), ('Five',)] 5
# break
# One Seven [('Two', 'Three'), ('Two', 'Six'), ('Two', 'Eight'), ('Two', 'Five'), ('Three', 'Six'), ('Three', 'Eight'), ('Three', 'Five'), ('Six', 'Eight'), ('Six', 'Five'), ('Eight', 'Five')] 10
# break
# One Seven [('Two', 'Three', 'Six'), ('Two', 'Three', 'Eight'), ('Two', 'Three', 'Five'), ('Two', 'Six', 'Eight'), ('Two', 'Six', 'Five'), ('Two', 'Eight', 'Five'), ('Three', 'Six', 'Eight'), ('Three', 'Six', 'Five'), ('Three', 'Eight', 'Five'), ('Six', 'Eight', 'Five')] 10
# break
# One Seven [('Two', 'Three', 'Six', 'Eight'), ('Two', 'Three', 'Six', 'Five'), ('Two', 'Three', 'Eight', 'Five'), ('Two', 'Six', 'Eight', 'Five'), ('Three', 'Six', 'Eight', 'Five')] 5
# break
# One Seven [('Two', 'Three', 'Six', 'Eight', 'Five')] 1
# break
# One Eight [('Two',), ('Three',), ('Six',), ('Seven',), ('Five',)] 5
# break
# One Eight [('Two', 'Three'), ('Two', 'Six'), ('Two', 'Seven'), ('Two', 'Five'), ('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Five'), ('Six', 'Seven'), ('Six', 'Five'), ('Seven', 'Five')] 10
# break
# One Eight [('Two', 'Three', 'Six'), ('Two', 'Three', 'Seven'), ('Two', 'Three', 'Five'), ('Two', 'Six', 'Seven'), ('Two', 'Six', 'Five'), ('Two', 'Seven', 'Five'), ('Three', 'Six', 'Seven'), ('Three', 'Six', 'Five'), ('Three', 'Seven', 'Five'), ('Six', 'Seven', 'Five')] 10
# break
# One Eight [('Two', 'Three', 'Six', 'Seven'), ('Two', 'Three', 'Six', 'Five'), ('Two', 'Three', 'Seven', 'Five'), ('Two', 'Six', 'Seven', 'Five'), ('Three', 'Six', 'Seven', 'Five')] 5
# break
# One Eight [('Two', 'Three', 'Six', 'Seven', 'Five')] 1
# break
# Two Three [('One',), ('Six',), ('Seven',), ('Eight',), ('Five',)] 5
# break
# Two Three [('One', 'Six'), ('One', 'Seven'), ('One', 'Eight'), ('One', 'Five'), ('Six', 'Seven'), ('Six', 'Eight'), ('Six', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')] 10
# break
# Two Three [('One', 'Six', 'Seven'), ('One', 'Six', 'Eight'), ('One', 'Six', 'Five'), ('One', 'Seven', 'Eight'), ('One', 'Seven', 'Five'), ('One', 'Eight', 'Five'), ('Six', 'Seven', 'Eight'), ('Six', 'Seven', 'Five'), ('Six', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')] 10
# break
# Two Three [('One', 'Six', 'Seven', 'Eight'), ('One', 'Six', 'Seven', 'Five'), ('One', 'Six', 'Eight', 'Five'), ('One', 'Seven', 'Eight', 'Five'), ('Six', 'Seven', 'Eight', 'Five')] 5
# break
# Two Three [('One', 'Six', 'Seven', 'Eight', 'Five')] 1
# break
# Two Six [('One',), ('Three',), ('Seven',), ('Eight',), ('Five',)] 5
# break
# Two Six [('One', 'Three'), ('One', 'Seven'), ('One', 'Eight'), ('One', 'Five'), ('Three', 'Seven'), ('Three', 'Eight'), ('Three', 'Five'), ('Seven', 'Eight'), ('Seven', 'Five'), ('Eight', 'Five')] 10
# break
# Two Six [('One', 'Three', 'Seven'), ('One', 'Three', 'Eight'), ('One', 'Three', 'Five'), ('One', 'Seven', 'Eight'), ('One', 'Seven', 'Five'), ('One', 'Eight', 'Five'), ('Three', 'Seven', 'Eight'), ('Three', 'Seven', 'Five'), ('Three', 'Eight', 'Five'), ('Seven', 'Eight', 'Five')] 10
# break
# Two Six [('One', 'Three', 'Seven', 'Eight'), ('One', 'Three', 'Seven', 'Five'), ('One', 'Three', 'Eight', 'Five'), ('One', 'Seven', 'Eight', 'Five'), ('Three', 'Seven', 'Eight', 'Five')] 5
# break
# Two Six [('One', 'Three', 'Seven', 'Eight', 'Five')] 1
# break
# Two Seven [('One',), ('Three',), ('Six',), ('Eight',), ('Five',)] 5
# break
# Two Seven [('One', 'Three'), ('One', 'Six'), ('One', 'Eight'), ('One', 'Five'), ('Three', 'Six'), ('Three', 'Eight'), ('Three', 'Five'), ('Six', 'Eight'), ('Six', 'Five'), ('Eight', 'Five')] 10
# break
# Two Seven [('One', 'Three', 'Six'), ('One', 'Three', 'Eight'), ('One', 'Three', 'Five'), ('One', 'Six', 'Eight'), ('One', 'Six', 'Five'), ('One', 'Eight', 'Five'), ('Three', 'Six', 'Eight'), ('Three', 'Six', 'Five'), ('Three', 'Eight', 'Five'), ('Six', 'Eight', 'Five')] 10
# break
# Two Seven [('One', 'Three', 'Six', 'Eight'), ('One', 'Three', 'Six', 'Five'), ('One', 'Three', 'Eight', 'Five'), ('One', 'Six', 'Eight', 'Five'), ('Three', 'Six', 'Eight', 'Five')] 5
# break
# Two Seven [('One', 'Three', 'Six', 'Eight', 'Five')] 1
# break
# Two Eight [('One',), ('Three',), ('Six',), ('Seven',), ('Five',)] 5
# break
# Two Eight [('One', 'Three'), ('One', 'Six'), ('One', 'Seven'), ('One', 'Five'), ('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Five'), ('Six', 'Seven'), ('Six', 'Five'), ('Seven', 'Five')] 10
# break
# Two Eight [('One', 'Three', 'Six'), ('One', 'Three', 'Seven'), ('One', 'Three', 'Five'), ('One', 'Six', 'Seven'), ('One', 'Six', 'Five'), ('One', 'Seven', 'Five'), ('Three', 'Six', 'Seven'), ('Three', 'Six', 'Five'), ('Three', 'Seven', 'Five'), ('Six', 'Seven', 'Five')] 10
# break
# Two Eight [('One', 'Three', 'Six', 'Seven'), ('One', 'Three', 'Six', 'Five'), ('One', 'Three', 'Seven', 'Five'), ('One', 'Six', 'Seven', 'Five'), ('Three', 'Six', 'Seven', 'Five')] 5
# break
# Two Eight [('One', 'Three', 'Six', 'Seven', 'Five')] 1
# break
# Three Five [('One',), ('Two',), ('Six',), ('Seven',), ('Eight',), ('Four',)] 6
# break
# Three Five [('One', 'Two'), ('One', 'Six'), ('One', 'Seven'), ('One', 'Eight'), ('One', 'Four'), ('Two', 'Six'), ('Two', 'Seven'), ('Two', 'Eight'), ('Two', 'Four'), ('Six', 'Seven'), ('Six', 'Eight'), ('Six', 'Four'), ('Seven', 'Eight'), ('Seven', 'Four'), ('Eight', 'Four')] 15
# break
One', 'Two', 'Five'), ('One', 'Two', 'Six'), ('One', 'Two', 'Eight'), ('One', 'Five', 'Six'), ('One', 'Five', 'Eight'), ('One', 'Six', 'Eight'), ('Two', 'Five', 'Six'), ('Two', 'Five', 'Eight'), ('Two', 'Six', 'Eight'), ('Five', 'Six', 'Eight')] 10
# break
# Three Seven [('One', 'Two', 'Five', 'Six'), ('One', 'Two', 'Five', 'Eight'), ('One', 'Two', 'Six', 'Eight'), ('One', 'Five', 'Six', 'Eight'), ('Two', 'Five', 'Six', 'Eight')] 5
# break
# Three Seven [('One', 'Two', 'Five', 'Six', 'Eight')] 1
# break
# Three Eight [('One',), ('Two',), ('Five',), ('Six',), ('Seven',)] 5
# break
# Three Eight [('One', 'Two'), ('One', 'Five'), ('One', 'Six'), ('One', 'Seven'), ('Two', 'Five'), ('Two', 'Six'), ('Two', 'Seven'), ('Five', 'Six'), ('Five', 'Seven'), ('Six', 'Seven')] 10
# break
# Three Eight [('One', 'Two', 'Five'), ('One', 'Two', 'Six'), ('One', 'Two', 'Seven'), ('One', 'Five', 'Six'), ('One', 'Five', 'Seven'), ('One', 'Six', 'Seven'), ('Two', 'Five', 'Six'), ('Two', 'Five', 'Seven'), ('Two', 'Six', 'Seven'), ('Five', 'Six', 'Seven')] 10
# break
# Three Eight [('One', 'Two', 'Five', 'Six'), ('One', 'Two', 'Five', 'Seven'), ('One', 'Two', 'Six', 'Seven'), ('One', 'Five', 'Six', 'Seven'), ('Two', 'Five', 'Six', 'Seven')] 5
# break
# Three Eight [('One', 'Two', 'Five', 'Six', 'Seven')] 1
# break
# Four Five [('Three',), ('Six',), ('Seven',), ('Eight',)] 4
# break
# Four Five [('Three', 'Six'), ('Three', 'Seven'), ('Three', 'Eight'), ('Six', 'Seven'), ('Six', 'Eight'), ('Seven', 'Eight')] 6
# break
# Four Five [('Three', 'Six', 'Seven'), ('Three', 'Six', 'Eight'), ('Three', 'Seven', 'Eight'), ('Six', 'Seven', 'Eight')] 4
# break
# Four Five [('Three', 'Six', 'Seven', 'Eight')] 1
# break
# Five Six [('Three',), ('Four',), ('Seven',), ('Eight',), ('One',), ('Two',)] 6
# break
# Five Six [('Three', 'Four'), ('Three', 'Seven'), ('Three', 'Eight'), ('Three', 'One'), ('Three', 'Two'), ('Four', 'Seven'), ('Four', 'Eight'), ('Four', 'One'), ('Four', 'Two'), ('Seven', 'Eight'), ('Seven', 'One'), ('Seven', 'Two'), ('Eight', 'One'), ('Eight', 'Two'), ('One', 'Two')] 15
# break
# Five Six [('Three', 'Four', 'Seven'), ('Three', 'Four', 'Eight'), ('Three', 'Four', 'One'), ('Three', 'Four', 'Two'), ('Three', 'Seven', 'Eight'), ('Three', 'Seven', 'One'), ('Three', 'Seven', 'Two'), ('Three', 'Eight', 'One'), ('Three', 'Eight', 'Two'), ('Three', 'One', 'Two'), ('Four', 'Seven', 'Eight'), ('Four', 'Seven', 'One'), ('Four', 'Seven', 'Two'), ('Four', 'Eight', 'One'), ('Four', 'Eight', 'Two'), ('Four', 'One', 'Two'), ('Seven', 'Eight', 'One'), ('Seven', 'Eight', 'Two'), ('Seven', 'One', 'Two'), ('Eight', 'One', 'Two')] 20
# break
# Five Six [('Three', 'Four', 'Seven', 'Eight'), ('Three', 'Four', 'Seven', 'One'), ('Three', 'Four', 'Seven', 'Two'), ('Three', 'Four', 'Eight', 'One'), ('Three', 'Four', 'Eight', 'Two'), ('Three', 'Four', 'One', 'Two'), ('Three', '
# break
# Five Eight [('Three', 'Four', 'Six'), ('Three', 'Four', 'Seven'), ('Three', 'Four', 'One'), ('Three', 'Four', 'Two'), ('Three', 'Six', 'Seven'), ('Three', 'Six', 'One'), ('Three', 'Six', 'Two'), ('Three', 'Seven', 'One'), ('Three', 'Seven', 'Two'), ('Three', 'One', 'Two'), ('Four', 'Six', 'Seven'), ('Four', 'Six', 'One'), ('Four', 'Six', 'Two'), ('Four', 'Seven', 'One'), ('Four', 'Seven', 'Two'), ('Four', 'One', 'Two'), ('Six', 'Seven', 'One'), ('Six', 'Seven', 'Two'), ('Six', 'One', 'Two'), ('Seven', 'One', 'Two')] 20
# break
# Five Eight [('Three', 'Four', 'Six', 'Seven'), ('Three', 'Four', 'Six', 'One'), ('Three', 'Four', 'Six', 'Two'), ('Three', 'Four', 'Seven', 'One'), ('Three', 'Four', 'Seven', 'Two'), ('Three', 'Four', 'One', 'Two'), ('Three', 'Six', 'Seven', 'One'), ('Three', 'Six', 'Seven', 'Two'), ('Three', 'Six', 'One', 'Two'), ('Three', 'Seven', 'One', 'Two'), ('Four', 'Six', 'Seven', 'One'), ('Four', 'Six', 'Seven', 'Two'), ('Four', 'Six', 'One', 'Two'), ('Four', 'Seven', 'One', 'Two'), ('Six', 'Seven', 'One', 'Two')] 15
# break
# Five Eight [('Three', 'Four', 'Six', 'Seven', 'One'), ('Three', 'Four', 'Six', 'Seven', 'Two'), ('Three', 'Four', 'Six', 'One', 'Two'), ('Three', 'Four', 'Seven', 'One', 'Two'), ('Three', 'Six', 'Seven', 'One', 'Two'), ('Four', 'Six', 'Seven', 'One', 'Two')] 6
# break
# Five Eight [('Three', 'Four', 'Six', 'Seven', 'One', 'Two')] 1
# break
# Six Seven [('One',), ('Two',), ('Three',), ('Five',), ('Eight',)] 5
# break
# Six Seven [('One', 'Two'), ('One', 'Three'), ('One', 'Five'), ('One', 'Eight'), ('Two', 'Three'), ('Two', 'Five'), ('Two', 'Eight'), ('Three', 'Five'), ('Three', 'Eight'), ('Five', 'Eight')] 10
# break
# Six Seven [('One', 'Two', 'Three'), ('One', 'Two', 'Five'), ('One', 'Two', 'Eight'), ('One', 'Three', 'Five'), ('One', 'Three', 'Eight'), ('One', 'Five', 'Eight'), ('Two', 'Three', 'Five'), ('Two', 'Three', 'Eight'), ('Two', 'Five', 'Eight'), ('Three', 'Five', 'Eight')] 10
# break
# Six Seven [('One', 'Two', 'Three', 'Five'), ('One', 'Two', 'Three', 'Eight'), ('One', 'Two', 'Five', 'Eight'), ('One', 'Three', 'Five', 'Eight'), ('Two', 'Three', 'Five', 'Eight')] 5
# break
# Six Seven [('One', 'Two', 'Three', 'Five', 'Eight')] 1
# break
# Six Eight [('One',), ('Two',), ('Three',), ('Five',), ('Seven',)] 5
# break
# Six Eight [('One', 'Two'), ('One', 'Three'), ('One', 'Five'), ('One', 'Seven'), ('Two', 'Three'), ('Two', 'Five'), ('Two', 'Seven'), ('Three', 'Five'), ('Three', 'Seven'), ('Five', 'Seven')] 10
# break
# Six Eight [('One', 'Two', 'Three'), ('One', 'Two', 'Five'), ('One', 'Two', 'Seven'), ('One', 'Three', 'Five'), ('One', 'Three', 'Seven'), ('One', 'Five', 'Seven'), ('Two', 'Three', 'Five'), ('Two', 'Three', 'Seven'), ('Two', 'Five', 'Seven'), ('Three', 'Five', 'Seven')] 10
# break
# Six Eight [('One', 'Two', 'Three', 'Five'), ('One', 'Two', 'Three', 'Seven'), ('One', 'Two', 'Five', 'Seven'), ('One', 'Three', 'Five', 'Seven'), ('Two', 'Three', 'Five', 'Seven')] 5
# break
# Six Eight [('One', 'Two', 'Three', 'Five', 'Seven')] 1
# break
# Seven Eight [('One',), ('Two',), ('Three',), ('Five',), ('Six',)] 5
# break
# Seven Eight [('One', 'Two'), ('One', 'Three'), ('One', 'Five'), ('One', 'Six'), ('Two', 'Three'), ('Two', 'Five'), ('Two', 'Six'), ('Three', 'Five'), ('Three', 'Six'), ('Five', 'Six')] 10
# break
# Seven Eight [('One', 'Two', 'Three'), ('One', 'Two', 'Five'), ('One', 'Two', 'Six'), ('One', 'Three', 'Five'), ('One', 'Three', 'Six'), ('One', 'Five', 'Six'), ('Two', 'Three', 'Five'), ('Two', 'Three', 'Six'), ('Two', 'Five', 'Six'), ('Three', 'Five', 'Six')] 10
# break
# Seven Eight [('One', 'Two', 'Three', 'Five'), ('One', 'Two', 'Three', 'Six'), ('One', 'Two', 'Five', 'Six'), ('One', 'Three', 'Five', 'Six'), ('Two', 'Three', 'Five', 'Six')] 5
# break
# Seven Eight [('One', 'Two', 'Three', 'Five', 'Six')] 1
# break
# CPU times: total: 0 ns
# Wall time: 1.08 ms

# %%
for i in output:
    for j in i:
        G.remove_edge(j[0], j[1])

# %%
print(G)
nx.draw(G, with_labels = True)
# Out:
# Graph with 8 nodes and 8 edges

# %%
list(G.edges)
# Out:
# [('One', 'Two'),
#  ('One', 'Three'),
#  ('Two', 'Six'),
#  ('Two', 'Seven'),
#  ('Two', 'Eight'),
#  ('Three', 'Five'),
#  ('Three', 'Six'),
#  ('Three', 'Seven'),
#  ('Three', 'Eight'),
#  ('Four', 'Five'),
#  ('Five', 'Six'),
#  ('Five', 'Seven'),
#  ('Five', 'Eight'),
#  ('Six', 'Seven'),
#  ('Six', 'Eight'),
#  ('Seven', 'Eight')]

# %%
z_0 = []
for s,t,u,v in edge_XY:
    z = list(itertools.combinations(u,2))
    z_0.append(z)
#     c2 = chi_square(X=s, Y=t, Z=list(itertools.combinations(u,2)), data=df_small, significance_level=0.05)

# %%
edge_XY

# %% [markdown]
# ### small network

# %%
m = Gobnilp()
m.learn(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\asia_10000.dat')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-21
# Set parameter PreCrush to value 1
# Set parameter CutPasses to value 100000
# Set parameter GomoryPasses to value 100000
# Set parameter MIPFocus to value 2
# Set parameter ZeroHalfCuts to value 2
# Set parameter MIPGap to value 0
# Set parameter MIPGapAbs to value 0
# **********
# BN has score -22466.396546491495
# **********
# Eight<-Six,Three -4150.291729106073
# Six<-Five,Two -5.611578690688475
# Three<- -6901.1493808303785
# Five<-Four -633.8404777927353
# Four<- -527.7536882896093
# One<-Three -6460.081285708176
# Seven<-Six -1881.452188461728
# Two<-One -1906.2162176121055
# **********
# bnlearn modelstring =
# [Eight|Six:Three][Six|Two:Five][Three][Five|Four][Four][One|Three][Seven|Six][Two|One]
# **********
# CPDAG:
# Vertices: Eight,Six,Three,Five,Four,One,Seven,Two
# Six->Eight
# Six->Seven
# Three->Eight
# Three-One
# Five->Six
# Four-Five
# One-Two
# Two->Six
