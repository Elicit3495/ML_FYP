# %%
import pandas as pd
import numpy as np
from pygobnilp.gobnilp import Gobnilp
import pgmpy
import itertools
from pgmpy.estimators.CITests import pearsonr
from pgmpy.estimators.CITests import chi_square
import networkx as nx
import time
import collections

# %%
k = pd.read_csv(r'C:\Users\User\Documents\GitHub\ML_FYP\dataset\FORMED\formed_dataset\trainingData_FORMED_N_1k.csv')

# %%
k
# Out:
#     PCLRfacet3 AbilityToCope Stress ProblematicLifeEvents Victimisation  \
# 0         6to8           Low     No                    No            No
# 1         3to5          High     No                    No            No
# 2         6to8           Low     No                    No            No
# 3         6to8           Low    Yes                    No           Yes
# 4         6to8           Low     No                    No            No
# ..         ...           ...    ...                   ...           ...
# 995       6to8           Low     No                    No            No
# 996       6to8           Low     No                   Yes            No
# 997       3to5          High     No                    No           Yes
# 998       3to5          High    Yes                    No            No
# 999       6to8          High     No                    No            No
#
#     ViolentThoughts Impulsivity  BPD AbuseNeglectAsChild PCLRfactor2  ...  \
# 0                No         Yes  Yes                 Yes      10to14  ...
# 1                No      Partly  Yes                 Yes       15-18  ...
# 2               Yes      Partly   No                  No          <5  ...
# 3                No         Yes   No                 Yes      10to14  ...
# 4               Yes         Yes   No                  No       15-18  ...
# ..              ...         ...  ...                 ...         ...  ...
# 995             Yes         Yes   No                  No        5to9  ...
# 996             Yes      Partly   No                 Yes      10to14  ...
# 997              No      Partly   No                 Yes      10to14  ...
# 998              No      Partly   No                 Yes        5to9  ...
# 999              No      Partly   No                  No      10to14  ...
#
#     Hallucinations HallucinationsPT StrangeExperiences StrangeExperiencesPT  \
# 0              Yes              Yes                 No                   No
# 1              Yes              Yes                 No                   No
# 2               No               No                 No                   No
# 3              Yes               No                 No                   No
# 4              Yes              Yes                 No                   No
# ..             ...              ...                ...                  ...
# 995            Yes              Yes                 No                   No
# 996             No               No                 No                   No
# 997             No               No                 No                   No
# 998             No               No                 No                   No
# 999            Yes              Yes                 No                   No
#
#     ParanoidDelusions ParanoidDelusionsPT PsychiatricTreatment  \
# 0                  No                  No                   No
# 1                  No                  No                   No
# 2                  No                  No                  Yes
# 3                  No                  No                  Yes
# 4                  No                  No                   No
# ..                ...                 ...                  ...
# 995                No                  No                   No
# 996                No                  No                   No
# 997                No                  No                  Yes
# 998               Yes                 Yes                   No
# 999                No                  No                   No
#
#     PsychiatricTreatmentGivenRFAT MentalIllnessSymptomCount MentalIllnessDL
# 0                              No                 MentalNPD            High
# 1                              No                 MentalNPD             Low
# 2                             Yes                      None             Low
# 3                             Yes                      None             Low
# 4                              No                 MentalNPD             Low
# ..                            ...                       ...             ...
# 995                            No                 MentalNPD             Low
# 996                            No                 MentalNPD            High
# 997                            No                      None             Low
# 998                            No         ParanoidDelusions            High
# 999                            No                 MentalNPD             Low
#
# [1000 rows x 88 columns]

# %%
len_v = []
for i in list(k):
    v = set(k[i])
#     print(v, len(v))
    len_v.append(len(v))

# %%
k.loc[-1] = len_v

# %%
k
# Out:
#      PCLRfacet3 AbilityToCope Stress ProblematicLifeEvents Victimisation  \
#  0         6to8           Low     No                    No            No
#  1         3to5          High     No                    No            No
#  2         6to8           Low     No                    No            No
#  3         6to8           Low    Yes                    No           Yes
#  4         6to8           Low     No                    No            No
# ...         ...           ...    ...                   ...           ...
#  996       6to8           Low     No                   Yes            No
#  997       3to5          High     No                    No           Yes
#  998       3to5          High    Yes                    No            No
#  999       6to8          High     No                    No            No
# -1            5             2      2                     2             2
#
#      ViolentThoughts Impulsivity  BPD AbuseNeglectAsChild PCLRfactor2  ...  \
#  0                No         Yes  Yes                 Yes      10to14  ...
#  1                No      Partly  Yes                 Yes       15-18  ...
#  2               Yes      Partly   No                  No          <5  ...
#  3                No         Yes   No                 Yes      10to14  ...
#  4               Yes         Yes   No                  No       15-18  ...
# ...              ...         ...  ...                 ...         ...  ...
#  996             Yes      Partly   No                 Yes      10to14  ...
#  997              No      Partly   No                 Yes      10to14  ...
#  998              No      Partly   No                 Yes        5to9  ...
#  999              No      Partly   No                  No      10to14  ...
# -1                 2           3    2                   2           4  ...
#
#      Hallucinations HallucinationsPT StrangeExperiences StrangeExperiencesPT  \
#  0              Yes              Yes                 No                   No
#  1              Yes              Yes                 No                   No
#  2               No               No                 No                   No
#  3              Yes               No                 No                   No
#  4              Yes              Yes                 No                   No
# ...             ...              ...                ...                  ...
#  996             No               No                 No                   No
#  997             No               No                 No                   No
#  998             No               No                 No                   No
#  999            Yes              Yes                 No                   No
# -1                2                2                  2                    2
#
#      ParanoidDelusions ParanoidDelusionsPT PsychiatricTreatment  \
#  0                  No                  No                   No
#  1                  No                  No                   No
#  2                  No                  No                  Yes
#  3                  No                  No                  Yes
#  4                  No                  No                   No
# ...                ...                 ...                  ...
#  996                No                  No                   No
#  997                No                  No                  Yes
#  998               Yes                 Yes                   No
#  999                No                  No                   No
# -1                   2                   2                    2
#
#      PsychiatricTreatmentGivenRFAT MentalIllnessSymptomCount MentalIllnessDL
#  0                              No                 MentalNPD            High
#  1                              No                 MentalNPD             Low
#  2                             Yes                      None             Low
#  3                             Yes                      None             Low
#  4                              No                 MentalNPD             Low
# ...                            ...                       ...             ...
#  996                            No                 MentalNPD            High
#  997                            No                      None             Low
#  998                            No         ParanoidDelusions            High
#  999                            No                 MentalNPD             Low
# -1                               2                         3               2
#
# [1001 rows x 88 columns]

# %%
k.index = k.index + 1

# %%
k = k.sort_index()

# %%
k.to_csv('testing_formed.csv', index=False)
