# %%
import pandas as pd
from scipy.stats import chi2_contingency
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import bnlearn as bn

# %%
df = pd.read_excel('discrete.xlsx')
df_ = df.drop([0])
df_
# Out:
#       A  B  C  D  E  F
# 1     b  c  b  a  b  b
# 2     b  a  c  a  b  b
# 3     a  a  a  a  a  a
# 4     a  a  a  a  b  b
# 5     a  a  b  c  a  a
# ...  .. .. .. .. .. ..
# 4996  a  a  a  a  a  a
# 4997  c  c  b  b  c  a
# 4998  b  b  a  b  c  b
# 4999  a  c  b  c  c  a
# 5000  a  a  a  a  b  b
#
# [5000 rows x 6 columns]

# %%
df = bn.import_example('water')
# Out:
# [bnlearn] >Downloading example [water] dataset..
# 100% [..............................................................................] 68883 / 68883[bnlearn] >Extracting files..

# %%
df_
# Out:
#       A  B  C  D  E  F
# 1     b  c  b  a  b  b
# 2     b  a  c  a  b  b
# 3     a  a  a  a  a  a
# 4     a  a  a  a  b  b
# 5     a  a  b  c  a  a
# ...  .. .. .. .. .. ..
# 4996  a  a  a  a  a  a
# 4997  c  c  b  b  c  a
# 4998  b  b  a  b  c  b
# 4999  a  c  b  c  c  a
# 5000  a  a  a  a  b  b
#
# [5000 rows x 6 columns]

# %%
# Structure learning
model = bn.structure_learning.fit(df, methodtype='cs')
# Plot detected DAG
G = bn.plot(model)

# Compute edge strength using chi-square independence test
model = bn.independence_test(model, df, alpha=0.05, prune=True)
bn.plot(model, pos=G['pos'])
# Out:
# [bnlearn] >Computing best DAG using [cs]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# [bnlearn] >Compute structure scores ['k2', 'bds', 'bic', 'bdeu'] for model comparison (higher is better).
# [bnlearn] >Warning: Structure scoring could not be computed. Method [cs] not supported.
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Compute edge strength with [chi_square]
# [bnlearn] >Set node properties.
# [bnlearn]> Set edge weights based on the [chi_square] test statistic.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Existing coordinates from <pos> are used.
# {'ax': <Figure size 1500x1000 with 1 Axes>,
#  'pos': {'CKNN_12_30': array([ 0.38019085, -0.21684058]),
#   'CNON_12_45': array([1.        , 0.53840548]),
#   'C_NI_12_30': array([-0.24576543,  0.20285017]),
#   'CBODD_12_45': array([-0.72949393,  0.21924285]),
#   'CKND_12_15': array([-0.20112532,  0.4273248 ]),
#   'CKND_12_30': array([-0.27789488,  0.7910682 ]),
#   'C_NI_12_15': array([0.23569489, 0.18539604]),
#   'CBODD_12_30': array([-0.5034491 ,  0.15364728]),
#   'CBODN_12_15': array([ 0.72938835, -0.43165416]),
#   'CBODN_12_30': array([ 0.74382007, -0.57646225]),
#   'CKNI_12_30': array([-0.54337657, -0.55234348]),
#   'CKNI_12_15': array([-0.5335404 , -0.47251545]),
#   'CKNI_12_45': array([-0.43031768, -0.57485366]),
#   'CNON_12_30': array([0.8316281 , 0.42945966]),
#   'C_NI_12_00': array([0.97238258, 0.21479793]),
#   'CBODN_12_45': array([ 0.7004696 , -0.64844634]),
#   'CKNN_12_45': array([-0.23706172, -0.97318294]),
#   'CKNI_12_00': array([-0.59465928,  0.60463569]),
#   'CNOD_12_30': array([-0.52269517, -0.19721938]),
#   'CNOD_12_45': array([-0.75565836, -0.24332307]),
#   'CBODD_12_15': array([-0.29085998,  0.09011527]),
#   'CKND_12_45': array([-0.35883976,  0.77865045]),
#   'CNOD_12_15': array([-0.46385402, -0.23751149]),
#   'C_NI_12_45': array([-0.1887447 ,  0.25049496]),
#   'CNON_12_15': array([0.8480417 , 0.50258288]),
#   'CKNN_12_15': array([ 0.43572018, -0.26431885])},
#  'G': <networkx.classes.digraph.DiGraph at 0x12ac821d070>,
#  'node_properties': {'CKNN_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'CNON_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'C_NI_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'CBODD_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CKND_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'CKND_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'C_NI_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'CBODD_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'CBODN_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'CBODN_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'CKNI_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'CKNI_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'CKNI_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CNON_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'C_NI_12_00': {'node_color': '#1f456e', 'node_size': 800},
#   'CBODN_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CKNN_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CKNI_12_00': {'node_color': '#1f456e', 'node_size': 800},
#   'CNOD_12_30': {'node_color': '#1f456e', 'node_size': 800},
#   'CNOD_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CBODD_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'CKND_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CNOD_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'C_NI_12_45': {'node_color': '#1f456e', 'node_size': 800},
#   'CNON_12_15': {'node_color': '#1f456e', 'node_size': 800},
#   'CKNN_12_15': {'node_color': '#1f456e', 'node_size': 800}},
#  'edge_properties': {('CBODD_12_30', 'CBODD_12_45'): {'color': '#000000',
#    'weight': 10.0},
#   ('CBODN_12_30', 'CBODN_12_45'): {'color': '#000000', 'weight': 10.0},
#   ('CKND_12_30', 'CKND_12_45'): {'color': '#000000', 'weight': 10.0},
#   ('CKNI_12_30', 'CKNI_12_15'): {'color': '#000000', 'weight': 10.0},
#   ('CKNN_12_30', 'CKNN_12_45'): {'color': '#000000', 'weight': 10.0},
#   ('CKNN_12_30', 'CNON_12_45'): {'color': '#000000', 'weight': 1.0},
#   ('CNOD_12_30', 'CNOD_12_45'): {'color': '#000000', 'weight': 10.0},
#   ('CNON_12_30', 'CNON_12_45'): {'color': '#000000', 'weight': 10.0},
#   ('C_NI_12_15', 'CBODD_12_30'): {'color': '#000000',
#    'weight': 9.957105860925921},
#   ('C_NI_12_15', 'C_NI_12_00'): {'color': '#000000', 'weight': 10.0},
#   ('C_NI_12_30', 'CBODD_12_45'): {'color': '#000000', 'weight': 10.0},
#   ('C_NI_12_30', 'C_NI_12_15'): {'color': '#000000', 'weight': 10.0},
#   ('CBODD_12_15', 'CBODD_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('CBODN_12_15', 'CBODN_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('CKND_12_15', 'CKND_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('CKND_12_15', 'CKNI_12_00'): {'color': '#000000',
#    'weight': 2.0004381568471272},
#   ('CKNI_12_45', 'CKNI_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('CKNN_12_15', 'CKNN_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('CNOD_12_15', 'CNOD_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('CNON_12_15', 'CNON_12_30'): {'color': '#000000', 'weight': 10.0},
#   ('C_NI_12_45', 'C_NI_12_30'): {'color': '#000000', 'weight': 10.0}}}

# %%
# contigency = pd.crosstab([df_['A'], df_['B']], df_['C']) 
# contigency

# %%
c, p, dof, expected = chi2_contingency(contigency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 c, p, dof, expected = chi2_contingency(contigency)
#
# NameError: name 'contigency' is not defined

# %%
p

# %%
read_file = pd.read_csv('discrete.dat', sep='\s+\|\s+')
read_file.to_csv ('discrete.csv', index=None)
