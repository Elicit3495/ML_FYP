# %%
import pandas as pd
from scipy.stats import chi2_contingency
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import bnlearn as bn
from tabulate import tabulate

# %%
df = pd.read_excel('discrete.xlsx')
df_ = df.drop([0])
df_
# Out:
#       A  B  C  D  E  F
# 1     b  c  b  a  b  b
# 2     b  a  c  a  b  b
# 3     a  a  a  a  a  a
# 4     a  a  a  a  b  b
# 5     a  a  b  c  a  a
# ...  .. .. .. .. .. ..
# 4996  a  a  a  a  a  a
# 4997  c  c  b  b  c  a
# 4998  b  b  a  b  c  b
# 4999  a  c  b  c  c  a
# 5000  a  a  a  a  b  b
#
# [5000 rows x 6 columns]

# %%
df = bn.import_example('water')
# Out:
# [bnlearn] >Extracting files..

# %%
df_
# Out:
#       A  B  C  D  E  F
# 1     b  c  b  a  b  b
# 2     b  a  c  a  b  b
# 3     a  a  a  a  a  a
# 4     a  a  a  a  b  b
# 5     a  a  b  c  a  a
# ...  .. .. .. .. .. ..
# 4996  a  a  a  a  a  a
# 4997  c  c  b  b  c  a
# 4998  b  b  a  b  c  b
# 4999  a  c  b  c  c  a
# 5000  a  a  a  a  b  b
#
# [5000 rows x 6 columns]

# %%
# Structure learning
model = bn.structure_learning.fit(df_, methodtype='hc', scoretype='bic')
# Plot detected DAG
G = bn.plot(model)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores ['k2', 'bds', 'bic', 'bdeu'] for model comparison (higher is better).
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model

# %%
# Compute edge strength using chi-square independence test
model = bn.independence_test(model, df_, alpha=0.05, prune=True)
bn.plot(model, pos=G['pos'])
print(tabulate(model['independence_test'], headers="keys"))
# Out:
# [bnlearn] >Compute edge strength with [chi_square]
# [bnlearn] >Set node properties.
# [bnlearn]> Set edge weights based on the [chi_square] test statistic.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# [bnlearn] >Existing coordinates from <pos> are used.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 4
#       2 model = bn.independence_test(model, df_, alpha=0.05, prune=True)
#       3 bn.plot(model, pos=G['pos'])
# ----> 4 print(tabulate(model['independence_test'], headers="keys"))
#
# NameError: name 'tabulate' is not defined

# %%
# contigency = pd.crosstab([df_['A'], df_['B']], df_['C']) 
# contigency

# %%
c, p, dof, expected = chi2_contingency(contigency)

# %%
p

# %%
# Load library
# Load example
df = bn.import_example('sprinkler')
# Structure learning
model = bn.structure_learning.fit(df, methodtype='ex', scoretype='bic')
# Compute edge strength using chi-square independence test and remove (prune) the not-signficant edges
model = bn.independence_test(model, df, alpha=0.05, prune=True)

# Examine the output of the chi-square test. All P values are significant. Nothing is removed.
print(tabulate(model['independence_test'], tablefmt="grid", headers="keys"))
# Out:
# [bnlearn] >Import dataset..
# [bnlearn] >Computing best DAG using [ex]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores ['k2', 'bds', 'bic', 'bdeu'] for model comparison (higher is better).
# [bnlearn] >Compute edge strength with [chi_square]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 10
#       7 model = bn.independence_test(model, df, alpha=0.05, prune=True)
#       9 # Examine the output of the chi-square test. All P values are significant. Nothing is removed.
# ---> 10 print(tabulate(model['independence_test'], tablefmt="grid", headers="keys"))
#
# TypeError: 'module' object is not callable

# %%
print(tabulate(model['independence_test'], tablefmt="grid", headers="keys"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 print(tabulate(model['independence_test'], tablefmt="grid", headers="keys"))
#
# TypeError: 'module' object is not callable

# %%
read_file = pd.read_csv('discrete.dat', sep='\s+\|\s+')
read_file.to_csv ('discrete.csv', index=None)
